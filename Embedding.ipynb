# %%
from transformers import pipeline
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import os
import pandas as pd

# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Title and Abstract Processing

# %%
feature_extracter = pipeline("feature-extraction", model="anferico/bert-for-patents", device = 0)

summarizer = pipeline("summarization", model="sshleifer/distilbart-cnn-12-6", device = 0)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/327 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.38G [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/329k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]

# %%
# Directory to titles+abstracts
dir_titleabstract = "/content/drive/MyDrive/titleabstracttexts1"
# Directory to full texts
dir_fulltext = "/content/drive/MyDrive/descriptiontexts1"
# Load all unique patents
with open("/content/drive/MyDrive/app_ref_doc_numbers1.txt", "r") as f:
  unique_patents = f.read().splitlines()
print(unique_patents)
# Out:
# ['17982807', '17982810', '17982815', '17982828', '17982834', '17982842', '17982863', '17982868', '17982873', '17982876', '17982889', '17982914', '17982922', '17982932', '17982947', '17982973', '17982976', '17982986', '17983007', '17983024', '17983035', '17983047', '17983054', '17983067', '17983088', '17983096', '17983099', '17983108', '17983136', '17983137', '17983140', '17983144', '17983154', '17983199', '17983206', '17983250', '17983251', '17983263', '17983264', '17983273', '17983274', '17983276', '17983280', '17983285', '17983288', '17983291', '17983320', '17983324', '17983397', '17983412', '17983436', '17983449', '17983452', '17983456', '17983459', '17983472', '17983479', '17983481', '17983483', '17983487', '17983510', '17983511', '17983539', '17983545', '17983552', '17983583', '17983585', '17983587', '17983592', '17983603', '17983619', '17983625', '17983662', '17983675', '17983717', '17983719', '17983724', '17983727', '17983734', '17983747', '17983751', '17983824', '17983846', '17983854', '17983867', '17983884', '17983906', '17983910', '17983912', '17983916', '17983950', '17983951', '17983953', '17983998', '17984014', '17984017', '17984028', '17984039', '17984056', '17984074', '17984077', '17984103', '17984127', '17984147', '17984151', '17984170', '17984205', '17984207', '17984248', '17984250', '17984256', '17984257', '17984301', '17984318', '17984329', '17984355', '17984364', '17984406', '17984418', '17984428', '17984429', '17984435', '17984452', '17984469', '17984475', '17984479', '17984481', '17984509', '17984519', '17984527', '17984536', '17984573', '17984587', '17984619', '17984642', '17984649', '17984662', '17984665', '17984676', '17984733', '17984767', '17984769', '17984774', '17984786', '17984796', '17984797', '17984798', '17984805', '17984817', '17984822', '17984825', '17984827', '17984840', '17984842', '17984867', '17984895', '17984904', '17984916', '17984923', '17984924', '17984928', '17984970', '17984981', '17985009', '17985022', '17985026', '17985036', '17985054', '17985061', '17985078', '17985114', '17985128', '17985133', '17985134', '17985146', '17985152', '17985178', '17985186', '17985191', '17985192', '17985196', '17985209', '17985221', '17985222', '17985235', '17985241', '17985250', '17985252', '17985254', '17985272', '17985273', '17985297', '17985311', '17985313', '17985315', '17985320', '17985325', '17985334', '17985344', '17985350', '17985359', '17985374', '17985387', '17985392', '17985396', '17985424', '17985428', '17985454', '17985461', '17985464', '17985467', '17985471', '17985473', '17985482', '17985494', '17985513', '17985515', '17985530', '17985531', '17985533', '17985538', '17985550', '17985552', '17985553', '17985554', '17985555', '17985560', '17985564', '17985565', '17985570', '17985571', '17985575', '17985577', '17985644', '17985647', '17985680', '17985708', '17985724', '17985728', '17985733', '17985743', '17985774', '17985775', '17985778', '17985780', '17985795', '17985815', '17985821', '17985871', '17985924', '17985941', '17985950', '17985956', '17985984', '17985996', '17985998', '17986002', '17986009', '17986025', '17986026', '17986035', '17986043', '17986051', '17986065', '17986074', '17986078', '17986132', '17986167', '17986182', '17986193', '17986205', '17986227', '17986241', '17986244', '17986301', '17986302', '17986318', '17986321', '17986358', '17986379', '17986403', '17986419', '17986423', '17986424', '17986426', '17986434', '17986445', '17986458', '17986466', '17986482', '17986545', '17986563', '17986567', '17986574', '17986578', '17986584', '17986589', '17986595', '17986605', '17986633', '17986664', '17986688', '17986728', '17986743', '17986754', '17986764', '17986784', '17986808', '17986822', '17986831', '17986840', '17986855', '17986857', '17986871', '17986878', '17986884', '17986907', '17986925', '17986932', '17986969', '17987032', '17987040', '17987047', '17987048', '17987076', '17987114', '17987125', '17987140', '17987157', '17987159', '17987189', '17987213', '17987215', '17 ...

# %%
def read_in_texts(directory, ids):
  texts = []
  for id in ids:
    with open(os.path.join(directory,f"{int(id)}.txt"), "r") as reader:
      texts.append(reader.read().replace("\n",""))
  return texts

# %%
def titleabstractloader(batch_size):
  batch_size = batch_size
  for id_set in range(int(round(len(unique_patents)/batch_size+0.5,0))):
    ids = [value for index,value in enumerate(unique_patents) if id_set*batch_size <= index < (id_set+1)*batch_size]
    texts = read_in_texts(dir_titleabstract, ids)
    yield ids, texts

# %%
def fulltextloader(batch_size):
  batch_size = batch_size
  for id_set in range(int(round(len(unique_patents)/batch_size+0.5,0))):
    ids = [value for index,value in enumerate(unique_patents) if id_set*batch_size <= index < (id_set+1)*batch_size]
    texts = read_in_texts(dir_fulltext, ids)
    yield ids, texts

# %%
os.mkdir("/content/drive/MyDrive/batched_indices")
os.mkdir("/content/drive/MyDrive/batched_titleabstracts")

# %%
# Encode the titleabstracts batch by batch and save them
for batch_ind, textinfo in enumerate(titleabstractloader(10)):
  id_set, texts = textinfo
  print(id_set)
  texts = [truncate_to_512_tokens(text) for text in texts]

  # Extract features for each text
  features = feature_extracter(texts)
  squeezed_features = [np.squeeze(np.array(feats), axis=0) for feats in features]

  # Aggregate token embeddings (e.g., using the mean)
  aggregated_features = [np.mean(np.array(feats), axis=0) for feats in squeezed_features]

  # Save indices
  with open(f"/content/drive/MyDrive/batched_indices1/batch_{batch_ind}.txt", "w") as f:
    f.write("\n".join(id_set))
  print(f"Batch {batch_ind} indices saved!")

  # Save embeded titleabstracts
  directory_embedding = os.path.join("/content/drive/MyDrive/batched_titleabstracts1", f"batch_{batch_ind}.npy")
  np.save(directory_embedding, aggregated_features)
  print(f"Batch {batch_ind} embeddings saved!")
# Out:
# ['17982807', '17982810', '17982815', '17982828', '17982834', '17982842', '17982863', '17982868', '17982873', '17982876']
# Batch 0 indices saved!
# Batch 0 embeddings saved!
# ['17982889', '17982914', '17982922', '17982932', '17982947', '17982973', '17982976', '17982986', '17983007', '17983024']
# Batch 1 indices saved!
# Batch 1 embeddings saved!
# ['17983035', '17983047', '17983054', '17983067', '17983088', '17983096', '17983099', '17983108', '17983136', '17983137']
# Batch 2 indices saved!
# Batch 2 embeddings saved!
# ['17983140', '17983144', '17983154', '17983199', '17983206', '17983250', '17983251', '17983263', '17983264', '17983273']
# Batch 3 indices saved!
# Batch 3 embeddings saved!
# ['17983274', '17983276', '17983280', '17983285', '17983288', '17983291', '17983320', '17983324', '17983397', '17983412']
# Batch 4 indices saved!
# Batch 4 embeddings saved!
# ['17983436', '17983449', '17983452', '17983456', '17983459', '17983472', '17983479', '17983481', '17983483', '17983487']
# Batch 5 indices saved!
# Batch 5 embeddings saved!
# ['17983510', '17983511', '17983539', '17983545', '17983552', '17983583', '17983585', '17983587', '17983592', '17983603']
# Batch 6 indices saved!
# Batch 6 embeddings saved!
# ['17983619', '17983625', '17983662', '17983675', '17983717', '17983719', '17983724', '17983727', '17983734', '17983747']
# Batch 7 indices saved!
# Batch 7 embeddings saved!
# ['17983751', '17983824', '17983846', '17983854', '17983867', '17983884', '17983906', '17983910', '17983912', '17983916']
# Batch 8 indices saved!
# Batch 8 embeddings saved!
# ['17983950', '17983951', '17983953', '17983998', '17984014', '17984017', '17984028', '17984039', '17984056', '17984074']
# Batch 9 indices saved!
# Batch 9 embeddings saved!
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# ['17984077', '17984103', '17984127', '17984147', '17984151', '17984170', '17984205', '17984207', '17984248', '17984250']
# Batch 10 indices saved!
# Batch 10 embeddings saved!
# ['17984256', '17984257', '17984301', '17984318', '17984329', '17984355', '17984364', '17984406', '17984418', '17984428']
# Batch 11 indices saved!
# Batch 11 embeddings saved!
# ['17984429', '17984435', '17984452', '17984469', '17984475', '17984479', '17984481', '17984509', '17984519', '17984527']
# Batch 12 indices saved!
# Batch 12 embeddings saved!
# ['17984536', '17984573', '17984587', '17984619', '17984642', '17984649', '17984662', '17984665', '17984676', '17984733']
# Batch 13 indices saved!
# Batch 13 embeddings saved!
# ['17984767', '17984769', '17984774', '17984786', '17984796', '17984797', '17984798', '17984805', '17984817', '17984822']
# Batch 14 indices saved!
# Batch 14 embeddings saved!
# ['17984825', '17984827', '17984840', '17984842', '17984867', '17984895', '17984904', '17984916', '17984923', '17984924']
# Batch 15 indices saved!
# Batch 15 embeddings saved!
# ['17984928', '17984970', '17984981', '17985009', '17985022', '17985026', '17985036', '17985054', '17985061', '17985078']
# Batch 16 indices saved!
# Batch 16 embeddings saved!
# ['17985114', '17985128', '17985133', '17985134', '17985146', '17985152', '17985178', '17985186', '17985191', '17985192']
# Batch 17 indices saved!
# Batch 17 embeddings saved!
# ['17985196', '17985209', '17985221', '17985222', '17985235', '17985241', '17985250', '17985252', '17985254', '17985272']
# Batch 18 indices saved!
# Batch 18 embeddings saved!
# ['17985273', '17985297', '17985311', '17985313', '17985315', '17985320', '17985325', '17985334', '17985344', '17985350']
# Batch 19 indices saved!
# Batch 19 embeddings saved!
# ['17985359', '17985374', '17985387', '17985392', '17985396', '17985424', '17985428', '17985454', '17985461', '17985464']
# Batch 20 indices saved!
# Batch 20 embeddings saved!
# ['17985467', '17985471', '17985473', '17985482', '17985494', '17985513', '17985515', '17985530', '17985531', '17985533']
# Batch 21 indices saved!
# Batch 21 embeddings saved!
# ['17985538', '17985550', '17985552', '17985553', '17985554', '17985555', '17985560', '17985564', '17985565', '17985570']
# Batch 22 indices saved!
# Batch 22 embeddings saved!
# ['17985571', '17985575', '17985577', '17985644', '17985647', '17985680', '17985708', '17985724', '17985728', '17985733']
# Batch 23 indices saved!
# Batch 23 embeddings saved!
# ['17985743', '17985774', '17985775', '17985778', '17985780', '17985795', '17985815', '17985821', '17985871', '17985924']
# Batch 24 indices saved!
# Batch 24 embeddings saved!
# ['17985941', '17985950', '17985956', '17985984', '17985996', '17985998', '17986002', '17986009', '17986025', '17986026']
# Batch 25 indices saved!
# Batch 25 embeddings saved!
# ['17986035', '17986043', '17986051', '17986065', '17986074', '17986078', '17986132', '17986167', '17986182', '17986193']
# Batch 26 indices saved!
# Batch 26 embeddings saved!
# ['17986205', '17986227', '17986241', '17986244', '17986301', '17986302', '17986318', '17986321', '17986358', '17986379']
# Batch 27 indices saved!
# Batch 27 embeddings saved!
# ['17986403', '17986419', '17986423', '17986424', '17986426', '17986434', '17986445', '17986458', '17986466', '17986482']
# Batch 28 indices saved!
# Batch 28 embeddings saved!
# ['17986545', '17986563', '17986567', '17986574', '17986578', '17986584', '17986589', '17986595', '17986605', '17986633']
# Batch 29 indices saved!
# Batch 29 embeddings saved!
# ['17986664', '17986688', '17986728', '17986743', '17986754', '17986764', '17986784', '17986808', '17986822', '17986831']
# Batch 30 indices saved!
# Batch 30 embeddings saved!
# ['17986840', '17986855', '17986857', '17986871', '17986878', '17986884', '17986907', '17986925', '17986932', '17986969']
# Batch 31 indices saved!
# Batch 31 embeddings saved!
# ['17987032', '17987040', '17987047', '17987048', '17987076', '17987114', '17987125', '17987140', '17987157', '17987159']
# Batch 32 indices saved!
# Batch 32 embeddings saved!
# ['17987189', '17987213', '17987215', '17987237', '17987240', '17987243', '17987246', '17987250', '17987261', '17987266']
# Batch 33 indices saved!
# Batch 33 embeddings saved!
# ['17987267', '17987277', '17987279', '17987280', '17987314', '17987315', '17987322', '17987338', '17987354', '17987359']
# Batch 34 indices saved!
# Batch 34 embeddings saved!
# ['17987369', '17987371', '17987381', '17987392', '17987407', '17987428', '17987440', '17987466', '17987473', '17987475']
# Batch 35 indices saved!
# Batch 35 embeddings saved!
# ['17987476', '17987493', '17987506', '17987516', '17987526', '17987545', '17987554', '17987600', '17987603', '17987639']
# Batch 36 indices saved!
# Batch 36 embeddings saved!
# ['17987642', '17987656', '17987668', '17987722', '17987724', '17987729', '17987743', '17987748', '17987758', '17987763']
# Batch 37 indices saved!
# Batch 37 embeddings saved!
# ['17987765', '17987781', '17987786', '17987792', '17987803', '17987806', '17987851', '17987896', '17987900', '17987901']
# Batch 38 indices saved!
# Batch 38 embeddings saved!
# ['17987910', '17987939', '17987971', '17987988', '17987999', '17988003', '17988008', '17988013', '17988045', '17988067']
# Batch 39 indices saved!
# Batch 39 embeddings saved!
# ['17988076', '17988077', '17988091', '17988096', '17988116', '17988158', '17988187', '17988199', '17988226', '17988228']
# Batch 40 indices saved!
# Batch 40 embeddings saved!
# ['17988230', '17988233', '17988260', '17988265', '17988280', '17988306', '17988309', '17988324', '17988401', '17988402']
# Batch 41 indices saved!
# Batch 41 embeddings saved!
# ['17988408', '17988420', '17988434', '17988456', '17988462', '17988491', '17988495', '17988496', '17988521', '17988525']
# Batch 42 indices saved!
# Batch 42 embeddings saved!
# ['17988527', '17988556', '17988560', '17988565', '17988567', '17988579', '17988580', '17988585', '17988605', '17988610']
# Batch 43 indices saved!
# Batch 43 embeddings saved!
# ['17988623', '17988629', '17988664', '17988684', '17988704', '17988708', '17988723', '17988727', '17988728', '17988744']
# Batch 44 indices saved!
# Batch 44 embeddings saved!
# ['17988771', '17988786', '17988809', '17988834', '17988848', '17988856', '17988869', '17988874', '17988883', '17988885']
# Batch 45 indices saved!
# Batch 45 embeddings saved!
# ['17988890', '17988935', '17988966', '17988981', '17988988', '17988993', '17988994', '17989018', '17989023', '17989041']
# Batch 46 indices saved!
# Batch 46 embeddings saved!
# ['17989057', '17989086', '17989090', '17989120', '17989137', '17989149', '17989208', '17989226', '17989247', '17989250']
# Batch 47 indices saved!
# Batch 47 embeddings saved!
# ['17989258', '17989259', '17989265', '17989279', '17989305', '17989308', '17989343', '17989359', '17989369', '17989380']
# Batch 48 indices saved!
# Batch 48 embeddings saved!
# ['17989385', '17989388', '17989409', '17989432', '17989477', '17989497', '17989498', '17989514', '17989524', '17989529']
# Batch 49 indices saved!
# Batch 49 embeddings saved!
# ['17989533', '17989536', '17989542', '17989555', '17989562', '17989571', '17989581', '17989602', '17989607', '17989621']
# Batch 50 indices saved!
# Batch 50 embeddings saved!
# ['17989677', '17989679', '17989680', '17989693', '17989701', '17989702', '17989706', '17989743', '17989746', '17989757']
# Batch 51 indices saved!
# Batch 51 embeddings saved!
# ['17989761', '17989787', '17989794', '17989834', '17989849', '17989877', '17989880', '17989883', '17989926', '17989931']
# Batch 52 indices saved!
# Batch 52 embeddings saved!
# ['17989952', '17989959', '17989975', '17989986', '17989991', '17990007', '17990014', '17990018', '17990046', '17990049']
# Batch 53 indices saved!
# Batch 53 embeddings saved!
# ['17990081', '17990087', '17990163', '17990215', '17990227', '17990231', '17990241', '17990252', '17990265', '17990267']
# Batch 54 indices saved!
# Batch 54 embeddings saved!
# ['17990271', '17990300', '17990311', '17990312', '17990339', '17990360', '17990363', '17990384', '17990405', '17990411']
# Batch 55 indices saved!
# Batch 55 embeddings saved!
# ['17990415', '17990416', '17990422', '17990424', '17990429', '17990443', '17990452', '17990457', '17990461', '17990520']
# Batch 56 indices saved!
# Batch 56 embeddings saved!
# ['17990528', '17990530', '17990538', '17990555', '17990557', '17990559', '17990564', '17990572', '17990576', '17990583']
# Batch 57 indices saved!
# Batch 57 embeddings saved!
# ['17990627', '17990629', '17990632', '17990636', '17990651', '17990707', '17990713', '17990735', '17990785', '17990812']
# Batch 58 indices saved!
# Batch 58 embeddings saved!
# ['17990841', '17990843', '17990879', '17990882', '17990925', '17990942', '17990943', '17990945', '17990947', '17990949']
# Batch 59 indices saved!
# Batch 59 embeddings saved!
# ['17990958', '17990968', '17990979', '17990982', '17990989', '17991023', '17991029', '17991030', '17991051', '17991056']
# Batch 60 indices saved!
# Batch 60 embeddings saved!
# ['17991069', '17991093', '17991120', '17991128', '17991134', '17991148', '17991149', '17991213', '17991223', '17991225']
# Batch 61 indices saved!
# Batch 61 embeddings saved!
# ['17991230', '17991233', '17991235', '17991245', '17991271', '17991273', '17991294', '17991297', '17991300', '17991302']
# Batch 62 indices saved!
# Batch 62 embeddings saved!
# ['17991344', '17991348', '17991357', '17991364', '17991371', '17991390', '17991402', '17991409', '17991414', '17991420']
# Batch 63 indices saved!
# Batch 63 embeddings saved!
# ['17991436', '17991471', '17991474', '17991490', '17991508', '17991512', '17991529', '17991546', '17991550', '17991592']
# Batch 64 indices saved!
# Batch 64 embeddings saved!
# ['17991599', '17991605', '17991643', '17991646', '17991672', '17991711', '17991715', '17991778', '17991786', '17991798']
# Batch 65 indices saved!
# Batch 65 embeddings saved!
# ['17991799', '17991805', '17991848', '17991867', '17991868', '17991875', '17991911', '17991930', '17991936', '17991946']
# Batch 66 indices saved!
# Batch 66 embeddings saved!
# ['17991965', '17991978', '17991981', '17991983', '17991986', '17991990', '17992005', '17992013', '17992020', '17992021']
# Batch 67 indices saved!
# Batch 67 embeddings saved!
# ['17992024', '17992029', '17992034', '17992045', '17992074', '17992076', '17992082', '17992099', '17992109', '17992125']
# Batch 68 indices saved!
# Batch 68 embeddings saved!
# ['17992129', '17992136', '17992142', '17992143', '17992146', '17992161', '17992165', '17992170', '17992176', '17992203']
# Batch 69 indices saved!
# Batch 69 embeddings saved!
# ['17992220', '17992236', '17992240', '17992268', '17992271', '17992272', '17992289', '17992303', '17992313', '17992316']
# Batch 70 indices saved!
# Batch 70 embeddings saved!
# ['17992344', '17992353', '17992381', '17992405', '17992448', '17992458', '17992488', '17992490', '17992496', '17992528']
# Batch 71 indices saved!
# Batch 71 embeddings saved!
# ['17992556', '17992576', '17992583', '17992589', '17992592', '17992603', '17992615', '17992627', '17992628', '17992642']
# Batch 72 indices saved!
# Batch 72 embeddings saved!
# ['17992651', '17992716', '17992718', '17992722', '17992726', '17992737', '17992784', '17992800', '17992815', '17992827']
# Batch 73 indices saved!
# Batch 73 embeddings saved!
# ['17992834', '17992838', '17992844', '17992890', '17992893', '17992915', '17992937', '17992939', '17992946', '17992949']
# Batch 74 indices saved!
# Batch 74 embeddings saved!
# ['17992957', '17992960', '17993021', '17993040', '17993052', '17993060', '17993061', '17993078', '17993081', '17993090']
# Batch 75 indices saved!
# Batch 75 embeddings saved!
# ['17993120', '17993121', '17993140', '17993153', '17993159', '17993175', '17993181', '17993186', '17993187', '17993200']
# Batch 76 indices saved!
# Batch 76 embeddings saved!
# ['17993201', '17993204', '17993209', '17993215', '17993248', '17993249', '17993292', '17993293', '17993311', '17993344']
# Batch 77 indices saved!
# Batch 77 embeddings saved!
# ['17993373', '17993391', '17993396', '17993408', '17993448', '17993459', '17993511', '17993514', '17993516', '17993528']
# Batch 78 indices saved!
# Batch 78 embeddings saved!
# ['17993534', '17993554', '17993560', '17993569', '17993578', '17993601', '17993614', '17993626', '17993631', '17993662']
# Batch 79 indices saved!
# Batch 79 embeddings saved!
# ['17993665', '17993770', '17993773', '17993777', '17993802', '17993806', '17993815', '17993816', '17993817', '17993844']
# Batch 80 indices saved!
# Batch 80 embeddings saved!
# ['17993846', '17993861', '17993870', '17993884', '17993893', '17993915', '17993929', '17993944', '17993948', '17993950']
# Batch 81 indices saved!
# Batch 81 embeddings saved!
# ['17993962', '17993987', '17993998', '17994099', '17994112', '17994113', '17994141', '17994215', '17994223', '17994236']
# Batch 82 indices saved!
# Batch 82 embeddings saved!
# ['17994250', '17994253', '17994267', '17994270', '17994290', '17994322', '17994325', '17994349', '17994358', '17994359']
# Batch 83 indices saved!
# Batch 83 embeddings saved!
# ['17994374', '17994402', '17994419', '17994420', '17994445', '17994451', '17994544', '17994551', '17994554', '17994584']
# Batch 84 indices saved!
# Batch 84 embeddings saved!
# ['17994593', '17994613', '17994626', '17994646', '17994648', '17994663', '17994683', '17994687', '17994689', '17994702']
# Batch 85 indices saved!
# Batch 85 embeddings saved!
# ['17994707', '17994720', '17994732', '17994733', '17994764', '17994775', '17994784', '17994813', '17994819', '17994827']
# Batch 86 indices saved!
# Batch 86 embeddings saved!
# ['17994863', '17994876', '17994881', '17994892', '17994895', '17994896', '17994902', '17994905', '17994906', '17994928']
# Batch 87 indices saved!
# Batch 87 embeddings saved!
# ['17994948', '17994957', '17994961', '17995009', '17995019', '17995130', '17995137', '17995165', '17995179', '17995195']
# Batch 88 indices saved!
# Batch 88 embeddings saved!
# ['17995219', '17995294', '17995311', '17995342', '17995364', '17995399', '17995468', '17995516', '17995638', '17995655']
# Batch 89 indices saved!
# Batch 89 embeddings saved!
# ['17995701', '17995706', '17995779', '17995788', '17995789', '17995807', '17995808', '17995939', '17995990', '17996024']
# Batch 90 indices saved!
# Batch 90 embeddings saved!
# ['17996135', '17996171', '17996210', '17996213', '17996241', '17996313', '17996320', '17996361', '17996433', '17996459']
# Batch 91 indices saved!
# Batch 91 embeddings saved!
# ['17996642', '17996643', '17996664', '17996745', '17996810', '17996919', '17996934', '17996986', '17996999', '17997092']
# Batch 92 indices saved!
# Batch 92 embeddings saved!
# ['17997102', '17997160', '17997174', '17997189', '17997268', '17997319', '17997385', '17997487', '17997505', '17997607']
# Batch 93 indices saved!
# Batch 93 embeddings saved!
# ['17997664', '17997694', '17997748', '17997824', '17997826', '17997851', '17997867', '17997892', '17997942', '17998027']
# Batch 94 indices saved!
# Batch 94 embeddings saved!
# ['17998069', '17998077', '17998268', '17998288', '17998396', '17998441', '17998475', '17998491', '17998501', '17998519']
# Batch 95 indices saved!
# Batch 95 embeddings saved!
# ['17998715', '17998745', '17998812', '17998818', '17998873', '17998875', '17999020', '17999092', '17999202', '17999207']
# Batch 96 indices saved!
# Batch 96 embeddings saved!
# ['17999210', '17999248', '17999386', '17999425', '17999456', '17999488', '17999678', '17999708', '17999718', '17999817']
# Batch 97 indices saved!
# Batch 97 embeddings saved!
# ['17999931', '17999970', '18000002', '18000048', '18000246', '18000659', '18000685', '18000715', '18000816', '18000827']
# Batch 98 indices saved!
# Batch 98 embeddings saved!
# ['18000830', '18000857', '18000864', '18000935', '18000953', '18001092', '18001131', '18001295', '18001311', '18001377']
# Batch 99 indices saved!
# Batch 99 embeddings saved!
# ['18001387', '18001473', '18001900', '18002171', '18002206', '18002321', '18002500', '18002571', '18002581', '18002586']
# Batch 100 indices saved!
# Batch 100 embeddings saved!
# ['18002624', '18003314', '18003424', '18003435', '18003444', '18003558', '18003596', '18003673', '18003697', '18003700']
# Batch 101 indices saved!
# Batch 101 embeddings saved!
# ['18004021', '18004042', '18004106', '18004209', '18004214', '18004284', '18004413', '18004598', '18004662', '18004915']
# Batch 102 indices saved!
# Batch 102 embeddings saved!
# ['18004978', '18005062', '18005305', '18005354', '18005366', '18005496', '18005662', '18005678', '18005736', '18005797']
# Batch 103 indices saved!
# Batch 103 embeddings saved!
# ['18005840', '18005949', '18006046', '18006114', '18006130', '18006177', '18006406', '18006567', '18006588', '18006589']
# Batch 104 indices saved!
# Batch 104 embeddings saved!
# ['18006615', '18006700', '18006736', '18006954', '18006959', '18006986', '18007003', '18007082', '18007244', '18007478']
# Batch 105 indices saved!
# Batch 105 embeddings saved!
# ['18007485', '18007528', '18007572', '18007706', '18007735', '18007860', '18007890', '18008011', '18008022', '18008044']
# Batch 106 indices saved!
# Batch 106 embeddings saved!
# ['18008192', '18008217', '18008227', '18008300', '18008308', '18008382', '18008457', '18008474', '18008479', '18008512']
# Batch 107 indices saved!
# Batch 107 embeddings saved!
# ['18008543', '18008579', '18008669', '18008672', '18008722', '18008740', '18008840', '18008896', '18009015', '18009039']
# Batch 108 indices saved!
# Batch 108 embeddings saved!
# ['18009117', '18009118', '18009219', '18009271', '18009367', '18009386', '18009510', '18009511', '18009593', '18009620']
# Batch 109 indices saved!
# Batch 109 embeddings saved!
# ['18009740', '18009804', '18009820', '18009992', '18010006', '18010072', '18010131', '18010148', '18010211', '18010212']
# Batch 110 indices saved!
# Batch 110 embeddings saved!
# ['18010235', '18010241', '18010383', '18010390', '18010414', '18010466', '18010468', '18010491', '18010532', '18010565']
# Batch 111 indices saved!
# Batch 111 embeddings saved!
# ['18010595', '18010662', '18010665', '18010712', '18010786', '18010820', '18010839', '18010905', '18011004', '18011084']
# Batch 112 indices saved!
# Batch 112 embeddings saved!
# ['18011135', '18011163', '18011212', '18011300', '18011340', '18011392', '18011443', '18011510', '18011514', '18011516']
# Batch 113 indices saved!
# Batch 113 embeddings saved!
# ['18011536', '18011566', '18011587', '18011614', '18011620', '18011675', '18011754', '18011882', '18011910', '18011941']
# Batch 114 indices saved!
# Batch 114 embeddings saved!
# ['18012130', '18012149', '18012168', '18012228', '18012240', '18012297', '18012350', '18012436', '18012550', '18012556']
# Batch 115 indices saved!
# Batch 115 embeddings saved!
# ['18012657', '18012921', '18012924', '18012928', '18012929', '18012933', '18012938', '18012946', '18013143', '18013146']
# Batch 116 indices saved!
# Batch 116 embeddings saved!
# ['18013164', '18013212', '18013233', '18013356', '18013423', '18013434', '18013598', '18013750', '18013763', '18013829']
# Batch 117 indices saved!
# Batch 117 embeddings saved!
# ['18014002', '18014076', '18014187', '18014193', '18014230', '18014278', '18014463', '18014466', '18014493', '18014504']
# Batch 118 indices saved!
# Batch 118 embeddings saved!
# ['18014748', '18014825', '18014961', '18015065', '18015101', '18015145', '18015171', '18015298', '18015356', '18015493']
# Batch 119 indices saved!
# Batch 119 embeddings saved!
# ['18015518', '18015529', '18015727', '18015754', '18015894', '18015963', '18016148', '18016160', '18016239', '18016246']
# Batch 120 indices saved!
# Batch 120 embeddings saved!
# ['18016280', '18016356', '18016443', '18016587', '18016609', '18016710', '18016715', '18016795', '18016854', '18016872']
# Batch 121 indices saved!
# Batch 121 embeddings saved!
# ['18016974', '18016998', '18017068', '18017070', '18017144', '18017499', '18017513', '18017522', '18017641', '18017883']
# Batch 122 indices saved!
# Batch 122 embeddings saved!
# ['18017904', '18017945', '18018082', '18018087', '18018163', '18018484', '18018507', '18018998', '18019251', '18019273']
# Batch 123 indices saved!
# Batch 123 embeddings saved!
# ['18019328', '18019334', '18019362', '18019364', '18019369', '18019485', '18019586', '18019813', '18019832', '18019936']
# Batch 124 indices saved!
# Batch 124 embeddings saved!
# ['18020005', '18020043', '18020080', '18020112', '18020170', '18020183', '18020229', '18020256', '18020406', '18020512']
# Batch 125 indices saved!
# Batch 125 embeddings saved!
# ['18020602', '18020653', '18020655', '18020718', '18020722', '18020973', '18021110', '18021118', '18021124', '18021143']
# Batch 126 indices saved!
# Batch 126 embeddings saved!
# ['18021184', '18021187', '18021331', '18021484', '18021649', '18021959', '18021966', '18022122', '18022333', '18022765']
# Batch 127 indices saved!
# Batch 127 embeddings saved!
# ['18022850', '18022870', '18022976', '18022996', '18023387', '18023398', '18023481', '18023627', '18023732', '18023752']
# Batch 128 indices saved!
# Batch 128 embeddings saved!
# ['18023938', '18023986', '18023993', '18023999', '18024259', '18024463', '18024714', '18024730', '18024732', '18024735']
# Batch 129 indices saved!
# Batch 129 embeddings saved!
# ['18024982', '18025120', '18025403', '18025414', '18025569', '18025624', '18025653', '18025681', '18025712', '18025885']
# Batch 130 indices saved!
# Batch 130 embeddings saved!
# ['18026131', '18026238', '18026334', '18026729', '18026938', '18027105', '18027276', '18027690', '18027827', '18027991']
# Batch 131 indices saved!
# Batch 131 embeddings saved!
# ['18028437', '18028443', '18028475', '18028570', '18028847', '18028900', '18029319', '18029326', '18029377', '18029453']
# Batch 132 indices saved!
# Batch 132 embeddings saved!
# ['18029651', '18029662', '18029861', '18030097', '18030109', '18030282', '18030849', '18030994', '18031056', '18031089']
# Batch 133 indices saved!
# Batch 133 embeddings saved!
# ['18031268', '18031289', '18031351', '18031779', '18031926', '18032010', '18032186', '18032483', '18032629', '18032816']
# Batch 134 indices saved!
# Batch 134 embeddings saved!
# ['18033072', '18033201', '18033460', '18033565', '18033739', '18033860', '18034013', '18034049', '18034053', '18034866']
# Batch 135 indices saved!
# Batch 135 embeddings saved!
# ['18036166', '18036208', '18036864', '18037025', '18037400', '18038198', '18038815', '18039232', '18039233', '18039966']
# Batch 136 indices saved!
# Batch 136 embeddings saved!
# ['18040139', '18040143', '18040303', '18040528', '18040698', '18040704', '18040725', '18040863', '18040913', '18041079']
# Batch 137 indices saved!
# Batch 137 embeddings saved!
# ['18041203', '18041235', '18041402', '18041711', '18041843', '18041903', '18042206', '18042319', '18042609', '18042611']
# Batch 138 indices saved!
# Batch 138 embeddings saved!
# ['18042768', '18042928', '18043005', '18043027', '18043046', '18043422', '18043572', '18043599', '18043718', '18044037']
# Batch 139 indices saved!
# Batch 139 embeddings saved!
# ['18044130', '18044608', '18044716', '18044864', '18044983', '18045003', '18045023', '18045041', '18045068', '18045079']
# Batch 140 indices saved!
# Batch 140 embeddings saved!
# ['18045089', '18045103', '18045104', '18045106', '18045113', '18045127', '18045168', '18045171', '18045175', '18045202']
# Batch 141 indices saved!
# Batch 141 embeddings saved!
# ['18045209', '18045231', '18045237', '18045238', '18045258', '18045263', '18045265', '18045277', '18045282', '18045288']
# Batch 142 indices saved!
# Batch 142 embeddings saved!
# ['18045297', '18045300', '18045302', '18045314', '18045344', '18045360', '18045372', '18045373', '18045390', '18045394']
# Batch 143 indices saved!
# Batch 143 embeddings saved!
# ['18045403', '18045415', '18045417', '18045420', '18045435', '18045441', '18045443', '18045446', '18045478', '18045489']
# Batch 144 indices saved!
# Batch 144 embeddings saved!
# ['18045493', '18045507', '18045514', '18045516', '18045554', '18045559', '18045566', '18045611', '18045633', '18045650']
# Batch 145 indices saved!
# Batch 145 embeddings saved!
# ['18045677', '18045678', '18045695', '18045706', '18045712', '18045742', '18045761', '18045770', '18045771', '18045790']
# Batch 146 indices saved!
# Batch 146 embeddings saved!
# ['18045809', '18045819', '18045825', '18045831', '18045835', '18045847', '18045853', '18045861', '18045864', '18045880']
# Batch 147 indices saved!
# Batch 147 embeddings saved!
# ['18045890', '18045913', '18045924', '18045949', '18045985', '18045989', '18045990', '18046002', '18046009', '18046022']
# Batch 148 indices saved!
# Batch 148 embeddings saved!
# ['18046031', '18046036', '18046038', '18046051', '18046074', '18046090', '18046091', '18046107', '18046157', '18046159']
# Batch 149 indices saved!
# Batch 149 embeddings saved!
# ['18046182', '18046191', '18046193', '18046212', '18046217', '18046218', '18046222', '18046223', '18046230', '18046251']
# Batch 150 indices saved!
# Batch 150 embeddings saved!
# ['18046270', '18046275', '18046282', '18046324', '18046336', '18046352', '18046353', '18046368', '18046370', '18046374']
# Batch 151 indices saved!
# Batch 151 embeddings saved!
# ['18046393', '18046414', '18046426', '18046428', '18046430', '18046443', '18046449', '18046456', '18046458', '18046497']
# Batch 152 indices saved!
# Batch 152 embeddings saved!
# ['18046518', '18046536', '18046554', '18046612', '18046623', '18046638', '18046644', '18046654', '18046655', '18046663']
# Batch 153 indices saved!
# Batch 153 embeddings saved!
# ['18046677', '18046679', '18046712', '18046716', '18046757', '18046760', '18046764', '18046769', '18046780', '18046786']
# Batch 154 indices saved!
# Batch 154 embeddings saved!
# ['18046789', '18046791', '18046823', '18046830', '18046841', '18046844', '18046901', '18046934', '18046943', '18046944']
# Batch 155 indices saved!
# Batch 155 embeddings saved!
# ['18046945', '18046946', '18046983', '18046986', '18046994', '18047003', '18047018', '18047029', '18047043', '18047045']
# Batch 156 indices saved!
# Batch 156 embeddings saved!
# ['18047080', '18047085', '18047092', '18047103', '18047117', '18047127', '18047138', '18047159', '18047168', '18047170']
# Batch 157 indices saved!
# Batch 157 embeddings saved!
# ['18047171', '18047192', '18047226', '18047229', '18047231', '18047248', '18047269', '18047276', '18047281', '18047282']
# Batch 158 indices saved!
# Batch 158 embeddings saved!
# ['18047311', '18047321', '18047338', '18047343', '18047391', '18047410', '18047423', '18047436', '18047444', '18047455']
# Batch 159 indices saved!
# Batch 159 embeddings saved!
# ['18047465', '18047469', '18047476', '18047485', '18047522', '18047523', '18047524', '18047556', '18047620', '18047647']
# Batch 160 indices saved!
# Batch 160 embeddings saved!
# ['18047648', '18047680', '18047716', '18047726', '18047740', '18047747', '18047762', '18047786', '18047788', '18047806']
# Batch 161 indices saved!
# Batch 161 embeddings saved!
# ['18047809', '18047813', '18047839', '18047850', '18047857', '18047858', '18047863', '18047898', '18047902', '18047921']
# Batch 162 indices saved!
# Batch 162 embeddings saved!
# ['18047951', '18047952', '18047958', '18047961', '18047979', '18047981', '18048023', '18048024', '18048028', '18048033']
# Batch 163 indices saved!
# Batch 163 embeddings saved!
# ['18048044', '18048045', '18048047', '18048061', '18048076', '18048079', '18048104', '18048109', '18048159', '18048181']
# Batch 164 indices saved!
# Batch 164 embeddings saved!
# ['18048199', '18048223', '18048235', '18048248', '18048249', '18048253', '18048302', '18048305', '18048311', '18048336']
# Batch 165 indices saved!
# Batch 165 embeddings saved!
# ['18048350', '18048376', '18048381', '18048404', '18048418', '18048422', '18048444', '18048459', '18048466', '18048468']
# Batch 166 indices saved!
# Batch 166 embeddings saved!
# ['18048471', '18048484', '18048504', '18048506', '18048510', '18048541', '18048555', '18048556', '18048560', '18048569']
# Batch 167 indices saved!
# Batch 167 embeddings saved!
# ['18048572', '18048573', '18048581', '18048583', '18048605', '18048732', '18048736', '18048754', '18048808', '18048824']
# Batch 168 indices saved!
# Batch 168 embeddings saved!
# ['18048829', '18048847', '18048852', '18048865', '18048869', '18048871', '18048887', '18048908', '18048919', '18048924']
# Batch 169 indices saved!
# Batch 169 embeddings saved!
# ['18048971', '18048978', '18048980', '18048987', '18048992', '18048993', '18049030', '18049051', '18049052', '18049060']
# Batch 170 indices saved!
# Batch 170 embeddings saved!
# ['18049111', '18049134', '18049137', '18049164', '18049173', '18049178', '18049179', '18049196', '18049209', '18049219']
# Batch 171 indices saved!
# Batch 171 embeddings saved!
# ['18049242', '18049248', '18049256', '18049265', '18049271', '18049332', '18049340', '18049348', '18049355', '18049368']
# Batch 172 indices saved!
# Batch 172 embeddings saved!
# ['18049411', '18049418', '18049451', '18049456', '18049465', '18049475', '18049500', '18049570', '18049589', '18049601']
# Batch 173 indices saved!
# Batch 173 embeddings saved!
# ['18049616', '18049620', '18049626', '18049632', '18049635', '18049639', '18049643', '18049666', '18049673', '18049691']
# Batch 174 indices saved!
# Batch 174 embeddings saved!
# ['18049693', '18049695', '18049781', '18049788', '18049794', '18049802', '18049814', '18049821', '18049825', '18049843']
# Batch 175 indices saved!
# Batch 175 embeddings saved!
# ['18049856', '18049868', '18049871', '18049881', '18049882', '18049885', '18049900', '18049907', '18049936', '18049950']
# Batch 176 indices saved!
# Batch 176 embeddings saved!
# ['18049951', '18049961', '18049982', '18049990', '18049995', '18050021', '18050023', '18050031', '18050048', '18050115']
# Batch 177 indices saved!
# Batch 177 embeddings saved!
# ['18050117', '18050137', '18050144', '18050184', '18050188', '18050189', '18050205', '18050213', '18050253', '18050264']
# Batch 178 indices saved!
# Batch 178 embeddings saved!
# ['18050269', '18050288', '18050291', '18050297', '18050347', '18050473', '18050528', '18050553', '18050556', '18050608']
# Batch 179 indices saved!
# Batch 179 embeddings saved!
# ['18050646', '18050651', '18050660', '18050676', '18050680', '18050700', '18050717', '18050718', '18050732', '18050769']
# Batch 180 indices saved!
# Batch 180 embeddings saved!
# ['18050801', '18050830', '18050868', '18050876', '18050884', '18050888', '18050895', '18050909', '18050925', '18050937']
# Batch 181 indices saved!
# Batch 181 embeddings saved!
# ['18050938', '18050958', '18050962', '18051000', '18051015', '18051016', '18051019', '18051027', '18051034', '18051057']
# Batch 182 indices saved!
# Batch 182 embeddings saved!
# ['18051067', '18051075', '18051090', '18051092', '18051095', '18051096', '18051101', '18051116', '18051133', '18051138']
# Batch 183 indices saved!
# Batch 183 embeddings saved!
# ['18051177', '18051185', '18051202', '18051208', '18051213', '18051220', '18051227', '18051239', '18051240', '18051241']
# Batch 184 indices saved!
# Batch 184 embeddings saved!
# ['18051262', '18051265', '18051292', '18051293', '18051321', '18051334', '18051337', '18051374', '18051380', '18051381']
# Batch 185 indices saved!
# Batch 185 embeddings saved!
# ['18051383', '18051409', '18051460', '18051474', '18051526', '18051536', '18051556', '18051569', '18051579', '18051584']
# Batch 186 indices saved!
# Batch 186 embeddings saved!
# ['18051591', '18051599', '18051615', '18051620', '18051637', '18051647', '18051689', '18051694', '18051716', '18051722']
# Batch 187 indices saved!
# Batch 187 embeddings saved!
# ['18051740', '18051749', '18051787', '18051822', '18051826', '18051860', '18051883', '18051906', '18051917', '18051920']
# Batch 188 indices saved!
# Batch 188 embeddings saved!
# ['18051942', '18051946', '18051987', '18052008', '18052077', '18052080', '18052089', '18052102', '18052127', '18052128']
# Batch 189 indices saved!
# Batch 189 embeddings saved!
# ['18052156', '18052268', '18052295', '18052307', '18052329', '18052332', '18052336', '18052373', '18052379', '18052380']
# Batch 190 indices saved!
# Batch 190 embeddings saved!
# ['18052411', '18052419', '18052431', '18052432', '18052437', '18052440', '18052448', '18052459', '18052460', '18052465']
# Batch 191 indices saved!
# Batch 191 embeddings saved!
# ['18052475', '18052478', '18052491', '18052503', '18052513', '18052545', '18052568', '18052576', '18052594', '18052603']
# Batch 192 indices saved!
# Batch 192 embeddings saved!
# ['18052616', '18052620', '18052652', '18052662', '18052673', '18052680', '18052690', '18052701', '18052711', '18052727']
# Batch 193 indices saved!
# Batch 193 embeddings saved!
# ['18052741', '18052748', '18052751', '18052760', '18052771', '18052780', '18052798', '18052801', '18052834', '18052850']
# Batch 194 indices saved!
# Batch 194 embeddings saved!
# ['18052852', '18052855', '18052904', '18052929', '18052936', '18052971', '18052974', '18052985', '18052994', '18053005']
# Batch 195 indices saved!
# Batch 195 embeddings saved!
# ['18053009', '18053014', '18053022', '18053032', '18053046', '18053067', '18053068', '18053069', '18053107', '18053108']
# Batch 196 indices saved!
# Batch 196 embeddings saved!
# ['18053124', '18053134', '18053145', '18053201', '18053205', '18053215', '18053216', '18053257', '18053267', '18053293']
# Batch 197 indices saved!
# Batch 197 embeddings saved!
# ['18053299', '18053304', '18053305', '18053386', '18053403', '18053406', '18053417', '18053424', '18053426', '18053430']
# Batch 198 indices saved!
# Batch 198 embeddings saved!
# ['18053459', '18053476', '18053491', '18053498', '18053499', '18053516', '18053518', '18053528', '18053536', '18053544']
# Batch 199 indices saved!
# Batch 199 embeddings saved!
# ['18053549', '18053557', '18053592', '18053639', '18053647', '18053649', '18053653', '18053693', '18053707', '18053712']
# Batch 200 indices saved!
# Batch 200 embeddings saved!
# ['18053717', '18053777', '18053794', '18053837', '18053869', '18053888', '18053912', '18053942', '18053993', '18054000']
# Batch 201 indices saved!
# Batch 201 embeddings saved!
# ['18054006', '18054017', '18054019', '18054023', '18054053', '18054061', '18054068', '18054072', '18054077', '18054117']
# Batch 202 indices saved!
# Batch 202 embeddings saved!
# ['18054132', '18054134', '18054151', '18054168', '18054203', '18054221', '18054236', '18054239', '18054252', '18054265']
# Batch 203 indices saved!
# Batch 203 embeddings saved!
# ['18054279', '18054282', '18054325', '18054332', '18054337', '18054417', '18054473', '18054495', '18054516', '18054518']
# Batch 204 indices saved!
# Batch 204 embeddings saved!
# ['18054523', '18054533', '18054539', '18054555', '18054567', '18054605', '18054611', '18054641', '18054650', '18054655']
# Batch 205 indices saved!
# Batch 205 embeddings saved!
# ['18054666', '18054671', '18054675', '18054680', '18054697', '18054706', '18054716', '18054750', '18054762', '18054795']
# Batch 206 indices saved!
# Batch 206 embeddings saved!
# ['18054797', '18054815', '18054833', '18054838', '18054846', '18054868', '18054901', '18054905', '18054913', '18054918']
# Batch 207 indices saved!
# Batch 207 embeddings saved!
# ['18054939', '18054943', '18054945', '18054949', '18054960', '18054964', '18054985', '18054988', '18054992', '18055026']
# Batch 208 indices saved!
# Batch 208 embeddings saved!
# ['18055028', '18055070', '18055094', '18055096', '18055115', '18055131', '18055150', '18055154', '18055166', '18055181']
# Batch 209 indices saved!
# Batch 209 embeddings saved!
# ['18055194', '18055201', '18055210', '18055212', '18055220', '18055221', '18055225', '18055228', '18055237', '18055245']
# Batch 210 indices saved!
# Batch 210 embeddings saved!
# ['18055253', '18055271', '18055272', '18055277', '18055278', '18055293', '18055298', '18055305', '18055314', '18055365']
# Batch 211 indices saved!
# Batch 211 embeddings saved!
# ['18055367', '18055371', '18055384', '18055388', '18055394', '18055433', '18055442', '18055446', '18055449', '18055472']
# Batch 212 indices saved!
# Batch 212 embeddings saved!
# ['18055489', '18055504', '18055508', '18055528', '18055549', '18055552', '18055574', '18055576', '18055587', '18055607']
# Batch 213 indices saved!
# Batch 213 embeddings saved!
# ['18055623', '18055634', '18055640', '18055658', '18055660', '18055677', '18055683', '18055713', '18055714', '18055734']
# Batch 214 indices saved!
# Batch 214 embeddings saved!
# ['18055747', '18055754', '18055758', '18055777', '18055784', '18055786', '18055802', '18055826', '18055846', '18055866']
# Batch 215 indices saved!
# Batch 215 embeddings saved!
# ['18055906', '18055929', '18055962', '18055967', '18055975', '18055977', '18055989', '18056023', '18056051', '18056090']
# Batch 216 indices saved!
# Batch 216 embeddings saved!
# ['18056099', '18056109', '18056114', '18056122', '18056124', '18056156', '18056211', '18056220', '18056231', '18056235']
# Batch 217 indices saved!
# Batch 217 embeddings saved!
# ['18056248', '18056250', '18056257', '18056264', '18056299', '18056303', '18056310', '18056336', '18056399', '18056417']
# Batch 218 indices saved!
# Batch 218 embeddings saved!
# ['18056452', '18056470', '18056513', '18056522', '18056550', '18056567', '18056575', '18056582', '18056587', '18056605']
# Batch 219 indices saved!
# Batch 219 embeddings saved!
# ['18056636', '18056652', '18056657', '18056703', '18056719', '18056721', '18056763', '18056793', '18056798', '18056808']
# Batch 220 indices saved!
# Batch 220 embeddings saved!
# ['18056814', '18056826', '18056837', '18056868', '18056874', '18056878', '18056886', '18056894', '18056932', '18056937']
# Batch 221 indices saved!
# Batch 221 embeddings saved!
# ['18056943', '18056947', '18056952', '18056999', '18057006', '18057029', '18057032', '18057048', '18057058', '18057064']
# Batch 222 indices saved!
# Batch 222 embeddings saved!
# ['18057074', '18057087', '18057116', '18057155', '18057160', '18057176', '18057183', '18057191', '18057198', '18057217']
# Batch 223 indices saved!
# Batch 223 embeddings saved!
# ['18057245', '18057246', '18057251', '18057283', '18057319', '18057322', '18057324', '18057325', '18057342', '18057345']
# Batch 224 indices saved!
# Batch 224 embeddings saved!
# ['18057346', '18057362', '18057389', '18057397', '18057416', '18057428', '18057462', '18057468', '18057474', '18057481']
# Batch 225 indices saved!
# Batch 225 embeddings saved!
# ['18057485', '18057491', '18057506', '18057538', '18057550', '18057552', '18057561', '18057570', '18057601', '18057654']
# Batch 226 indices saved!
# Batch 226 embeddings saved!
# ['18057683', '18057701', '18057726', '18057751', '18057752', '18057762', '18057772', '18057784', '18057789', '18057803']
# Batch 227 indices saved!
# Batch 227 embeddings saved!
# ['18057815', '18057832', '18057833', '18057838', '18057840', '18057842', '18057867', '18057878', '18057880', '18057889']
# Batch 228 indices saved!
# Batch 228 embeddings saved!
# ['18057902', '18057991', '18057992', '18057993', '18058011', '18058023', '18058029', '18058030', '18058034', '18058040']
# Batch 229 indices saved!
# Batch 229 embeddings saved!
# ['18058041', '18058046', '18058047', '18058058', '18058073', '18058081', '18058088', '18058117', '18058137', '18058150']
# Batch 230 indices saved!
# Batch 230 embeddings saved!
# ['18058156', '18058161', '18058162', '18058190', '18058210', '18058226', '18058230', '18058232', '18058261', '18058262']
# Batch 231 indices saved!
# Batch 231 embeddings saved!
# ['18058265', '18058276', '18058306', '18058316', '18058331', '18058336', '18058343', '18058348', '18058355', '18058376']
# Batch 232 indices saved!
# Batch 232 embeddings saved!
# ['18058383', '18058446', '18058497', '18058511', '18058525', '18058548', '18058571', '18058597', '18058606', '18058607']
# Batch 233 indices saved!
# Batch 233 embeddings saved!
# ['18058639', '18058654', '18058659', '18058667', '18058725', '18058741', '18058774', '18058845', '18058847', '18058888']
# Batch 234 indices saved!
# Batch 234 embeddings saved!
# ['18058902', '18058904', '18058907', '18058912', '18058920', '18058922', '18058928', '18058940', '18058943', '18058957']
# Batch 235 indices saved!
# Batch 235 embeddings saved!
# ['18058958', '18058994', '18058997', '18059004', '18059042', '18059047', '18059075', '18059087', '18059090', '18059094']
# Batch 236 indices saved!
# Batch 236 embeddings saved!
# ['18059099', '18059128', '18059150', '18059166', '18059167', '18059172', '18059179', '18059225', '18059280', '18059299']
# Batch 237 indices saved!
# Batch 237 embeddings saved!
# ['18059306', '18059319', '18059324', '18059387', '18059390', '18059403', '18059406', '18059407', '18059463', '18059469']
# Batch 238 indices saved!
# Batch 238 embeddings saved!
# ['18059470', '18059474', '18059484', '18059488', '18059499', '18059567', '18059588', '18059657', '18059717', '18059739']
# Batch 239 indices saved!
# Batch 239 embeddings saved!
# ['18059771', '18059784', '18059797', '18059802', '18059812', '18059833', '18059874', '18059880', '18059905', '18059928']
# Batch 240 indices saved!
# Batch 240 embeddings saved!
# ['18059929', '18059934', '18059944', '18059948', '18059968', '18060070', '18060074', '18060082', '18060087', '18060140']
# Batch 241 indices saved!
# Batch 241 embeddings saved!
# ['18060176', '18060286', '18060289', '18060307', '18060308', '18060319', '18060340', '18060372', '18060378', '18060404']
# Batch 242 indices saved!
# Batch 242 embeddings saved!
# ['18060434', '18060441', '18060452', '18060454', '18060466', '18060503', '18060507', '18060525', '18060556', '18060582']
# Batch 243 indices saved!
# Batch 243 embeddings saved!
# ['18060631', '18060637', '18060639', '18060654', '18060656', '18060658', '18060707', '18060757', '18060762', '18060765']
# Batch 244 indices saved!
# Batch 244 embeddings saved!
# ['18060795', '18060801', '18060816', '18060839', '18060864', '18060867', '18060876', '18060883', '18060891', '18060918']
# Batch 245 indices saved!
# Batch 245 embeddings saved!
# ['18060930', '18060941', '18060952', '18060959', '18060970', '18060972', '18060975', '18060994', '18061006', '18061052']
# Batch 246 indices saved!
# Batch 246 embeddings saved!
# ['18061128', '18061149', '18061164', '18061179', '18061192', '18061196', '18061202', '18061218', '18061220', '18061228']
# Batch 247 indices saved!
# Batch 247 embeddings saved!
# ['18061239', '18061245', '18061274', '18061277', '18061288', '18061347', '18061350', '18061361', '18061366', '18061367']
# Batch 248 indices saved!
# Batch 248 embeddings saved!
# ['18061375', '18061395', '18061404', '18061488', '18061496', '18061503', '18061507', '18061508', '18061509', '18061520']
# Batch 249 indices saved!
# Batch 249 embeddings saved!
# ['18061551', '18061574', '18061576', '18061578', '18061581', '18061611', '18061616', '18061635', '18061638', '18061700']
# Batch 250 indices saved!
# Batch 250 embeddings saved!
# ['18061720', '18061721', '18061725', '18061743', '18061745', '18061795', '18061803', '18061807', '18061813', '18061814']
# Batch 251 indices saved!
# Batch 251 embeddings saved!
# ['18061844', '18061850', '18061860', '18061866', '18061875', '18061910', '18061990', '18062003', '18062004', '18062011']
# Batch 252 indices saved!
# Batch 252 embeddings saved!
# ['18062015', '18062025', '18062026', '18062032', '18062046', '18062051', '18062072', '18062075', '18062092', '18062148']
# Batch 253 indices saved!
# Batch 253 embeddings saved!
# ['18062152', '18062160', '18062175', '18062219', '18062222', '18062224', '18062241', '18062258', '18062271', '18062303']
# Batch 254 indices saved!
# Batch 254 embeddings saved!
# ['18062409', '18062414', '18062447', '18062465', '18062493', '18062498', '18062500', '18062505', '18062511', '18062514']
# Batch 255 indices saved!
# Batch 255 embeddings saved!
# ['18062527', '18062528', '18062545', '18062587', '18062588', '18062589', '18062595', '18062597', '18062621', '18062623']
# Batch 256 indices saved!
# Batch 256 embeddings saved!
# ['18062657', '18062676', '18062694', '18062729', '18062744', '18062803', '18062838', '18062840', '18062854', '18062870']
# Batch 257 indices saved!
# Batch 257 embeddings saved!
# ['18062891', '18062901', '18062978', '18063006', '18063064', '18063075', '18063150', '18063164', '18063213', '18063217']
# Batch 258 indices saved!
# Batch 258 embeddings saved!
# ['18063222', '18063232', '18063267', '18063393', '18063423', '18063462', '18063480', '18063493', '18063519', '18063520']
# Batch 259 indices saved!
# Batch 259 embeddings saved!
# ['18063543', '18063557', '18063565', '18063573', '18063577', '18063635', '18063640', '18063642', '18063690', '18063703']
# Batch 260 indices saved!
# Batch 260 embeddings saved!
# ['18063708', '18063740', '18063749', '18063763', '18063795', '18063797', '18063808', '18063820', '18063830', '18063831']
# Batch 261 indices saved!
# Batch 261 embeddings saved!
# ['18063851', '18063887', '18063915', '18063919', '18063949', '18063960', '18063988', '18064001', '18064006', '18064029']
# Batch 262 indices saved!
# Batch 262 embeddings saved!
# ['18064038', '18064041', '18064064', '18064086', '18064087', '18064104', '18064135', '18064160', '18064190', '18064199']
# Batch 263 indices saved!
# Batch 263 embeddings saved!
# ['18064209', '18064216', '18064233', '18064238', '18064256', '18064277', '18064308', '18064313', '18064344', '18064357']
# Batch 264 indices saved!
# Batch 264 embeddings saved!
# ['18064366', '18064369', '18064409', '18064416', '18064465', '18064497', '18064555', '18064587', '18064622', '18064631']
# Batch 265 indices saved!
# Batch 265 embeddings saved!
# ['18064672', '18064683', '18064686', '18064690', '18064691', '18064693', '18064695', '18064699', '18064765', '18064771']
# Batch 266 indices saved!
# Batch 266 embeddings saved!
# ['18064774', '18064794', '18064795', '18064805', '18064833', '18064834', '18064863', '18064869', '18064872', '18064875']
# Batch 267 indices saved!
# Batch 267 embeddings saved!
# ['18064896', '18064904', '18064905', '18064916', '18064946', '18064948', '18064974', '18064984', '18064998', '18065070']
# Batch 268 indices saved!
# Batch 268 embeddings saved!
# ['18065076', '18065083', '18065089', '18065095', '18065100', '18065104', '18065106', '18065109', '18065118', '18065124']
# Batch 269 indices saved!
# Batch 269 embeddings saved!
# ['18065139', '18065206', '18065230', '18065234', '18065235', '18065239', '18065246', '18065267', '18065328', '18065342']
# Batch 270 indices saved!
# Batch 270 embeddings saved!
# ['18065343', '18065418', '18065429', '18065445', '18065447', '18065463', '18065466', '18065475', '18065496', '18065517']
# Batch 271 indices saved!
# Batch 271 embeddings saved!
# ['18065525', '18065529', '18065530', '18065533', '18065550', '18065555', '18065562', '18065585', '18065596', '18065638']
# Batch 272 indices saved!
# Batch 272 embeddings saved!
# ['18065691', '18065693', '18065697', '18065707', '18065727', '18065749', '18065753', '18065791', '18065838', '18065893']
# Batch 273 indices saved!
# Batch 273 embeddings saved!
# ['18065906', '18065912', '18065914', '18065928', '18065935', '18065943', '18065969', '18065977', '18066030', '18066056']
# Batch 274 indices saved!
# Batch 274 embeddings saved!
# ['18066107', '18066125', '18066138', '18066154', '18066167', '18066192', '18066193', '18066200', '18066215', '18066223']
# Batch 275 indices saved!
# Batch 275 embeddings saved!
# ...
# Batch 658 indices saved!
# Batch 658 embeddings saved!
# ['18168931', '18168969', '18169080', '18169089', '18169162', '18169181', '18169197', '18169276', '18169344', '18169360']
# Batch 659 indices saved!
# Batch 659 embeddings saved!
# ['18169390', '18169434', '18169456', '18169483', '18169488', '18169506', '18169524', '18169531', '18169592', '18169700']
# Batch 660 indices saved!
# Batch 660 embeddings saved!
# ['18169710', '18169714', '18169742', '18169766', '18169777', '18169857', '18169891', '18170057', '18170101', '18170169']
# Batch 661 indices saved!
# Batch 661 embeddings saved!
# ['18170187', '18170207', '18170285', '18170325', '18170347', '18170355', '18170549', '18170551', '18170588', '18170666']
# Batch 662 indices saved!
# Batch 662 embeddings saved!
# ['18170849', '18170918', '18170940', '18171050', '18171075', '18171099', '18171113', '18171139', '18171148', '18171159']
# Batch 663 indices saved!
# Batch 663 embeddings saved!
# ['18171200', '18171302', '18171392', '18171419', '18171423', '18171437', '18171454', '18171483', '18171513', '18171526']
# Batch 664 indices saved!
# Batch 664 embeddings saved!
# ['18171527', '18171529', '18171663', '18171714', '18171823', '18171851', '18171927', '18171949', '18171971', '18172103']
# Batch 665 indices saved!
# Batch 665 embeddings saved!
# ['18172115', '18172151', '18172163', '18172181', '18172184', '18172205', '18172215', '18172251', '18172274', '18172301']
# Batch 666 indices saved!
# Batch 666 embeddings saved!
# ['18172307', '18172434', '18172458', '18172461', '18172539', '18172586', '18172596', '18172691', '18172757', '18172781']
# Batch 667 indices saved!
# Batch 667 embeddings saved!
# ['18172847', '18172865', '18172867', '18172952', '18173006', '18173016', '18173037', '18173046', '18173102', '18173132']
# Batch 668 indices saved!
# Batch 668 embeddings saved!
# ['18173136', '18173140', '18173158', '18173196', '18173211', '18173257', '18173274', '18173332', '18173403', '18173440']
# Batch 669 indices saved!
# Batch 669 embeddings saved!
# ['18173541', '18173571', '18173574', '18173597', '18173662', '18173667', '18173701', '18173704', '18173712', '18173715']
# Batch 670 indices saved!
# Batch 670 embeddings saved!
# ['18173827', '18173850', '18173860', '18173894', '18173944', '18173951', '18173967', '18174018', '18174189', '18174253']
# Batch 671 indices saved!
# Batch 671 embeddings saved!
# ['18174368', '18174374', '18174389', '18174411', '18174445', '18174503', '18174537', '18174539', '18174545', '18174546']
# Batch 672 indices saved!
# Batch 672 embeddings saved!
# ['18174664', '18174667', '18174736', '18174738', '18174778', '18174887', '18174998', '18175026', '18175045', '18175074']
# Batch 673 indices saved!
# Batch 673 embeddings saved!
# ['18175111', '18175122', '18175127', '18175159', '18175180', '18175189', '18175192', '18175196', '18175275', '18175294']
# Batch 674 indices saved!
# Batch 674 embeddings saved!
# ['18175315', '18175318', '18175356', '18175362', '18175375', '18175421', '18175457', '18175463', '18175466', '18175472']
# Batch 675 indices saved!
# Batch 675 embeddings saved!
# ['18175496', '18175529', '18175605', '18175607', '18175705', '18175829', '18175835', '18175890', '18175967', '18176055']
# Batch 676 indices saved!
# Batch 676 embeddings saved!
# ['18176061', '18176131', '18176349', '18176379', '18176449', '18176475', '18176559', '18176601', '18176647', '18176653']
# Batch 677 indices saved!
# Batch 677 embeddings saved!
# ['18176666', '18176676', '18176690', '18176764', '18176765', '18176799', '18176823', '18176848', '18176850', '18176913']
# Batch 678 indices saved!
# Batch 678 embeddings saved!
# ['18176957', '18176963', '18176964', '18176965', '18177009', '18177075', '18177191', '18177212', '18177223', '18177269']
# Batch 679 indices saved!
# Batch 679 embeddings saved!
# ['18177339', '18177349', '18177406', '18177489', '18177496', '18177531', '18177538', '18177555', '18177560', '18177711']
# Batch 680 indices saved!
# Batch 680 embeddings saved!
# ['18177790', '18177806', '18177908', '18177929', '18177949', '18177978', '18178091', '18178181', '18178197', '18178201']
# Batch 681 indices saved!
# Batch 681 embeddings saved!
# ['18178252', '18178322', '18178381', '18178385', '18178396', '18178405', '18178412', '18178416', '18178425', '18178478']
# Batch 682 indices saved!
# Batch 682 embeddings saved!
# ['18178549', '18178556', '18178557', '18178582', '18178601', '18178604', '18178617', '18178655', '18178717', '18178789']
# Batch 683 indices saved!
# Batch 683 embeddings saved!
# ['18178813', '18178831', '18178845', '18178847', '18178924', '18178933', '18178955', '18178992', '18179022', '18179052']
# Batch 684 indices saved!
# Batch 684 embeddings saved!
# ['18179062', '18179231', '18179234', '18179255', '18179293', '18179370', '18179399', '18179428', '18179461', '18179523']
# Batch 685 indices saved!
# Batch 685 embeddings saved!
# ['18179662', '18179684', '18179823', '18179841', '18179916', '18179965', '18179982', '18180016', '18180089', '18180114']
# Batch 686 indices saved!
# Batch 686 embeddings saved!
# ['18180233', '18180304', '18180344', '18180375', '18180394', '18180474', '18180478', '18180529', '18180548', '18180676']
# Batch 687 indices saved!
# Batch 687 embeddings saved!
# ['18180691', '18180695', '18180759', '18180828', '18180859', '18180882', '18180884', '18181029', '18181030', '18181064']
# Batch 688 indices saved!
# Batch 688 embeddings saved!
# ['18181177', '18181198', '18181224', '18181263', '18181294', '18181347', '18181384', '18181407', '18181529', '18181588']
# Batch 689 indices saved!
# Batch 689 embeddings saved!
# ['18181623', '18181649', '18181671', '18181728', '18181742', '18181795', '18181841', '18181870', '18181903', '18181943']
# Batch 690 indices saved!
# Batch 690 embeddings saved!
# ['18181948', '18182190', '18182201', '18182259', '18182296', '18182329', '18182401', '18182460', '18182477', '18182488']
# Batch 691 indices saved!
# Batch 691 embeddings saved!
# ['18182597', '18182608', '18182700', '18182747', '18182786', '18182892', '18182961', '18183009', '18183136', '18183151']
# Batch 692 indices saved!
# Batch 692 embeddings saved!
# ['18183171', '18183185', '18183251', '18183333', '18183347', '18183366', '18183383', '18183408', '18183503', '18183640']
# Batch 693 indices saved!
# Batch 693 embeddings saved!
# ['18183727', '18183830', '18183849', '18183889', '18183948', '18183974', '18184128', '18184145', '18184229', '18184330']
# Batch 694 indices saved!
# Batch 694 embeddings saved!
# ['18184376', '18184439', '18184476', '18184535', '18184583', '18184603', '18184723', '18184741', '18184861', '18184882']
# Batch 695 indices saved!
# Batch 695 embeddings saved!
# ['18184905', '18184922', '18184959', '18184979', '18184994', '18185045', '18185080', '18185082', '18185091', '18185109']
# Batch 696 indices saved!
# Batch 696 embeddings saved!
# ['18185148', '18185180', '18185196', '18185215', '18185284', '18185310', '18185311', '18185319', '18185334', '18185429']
# Batch 697 indices saved!
# Batch 697 embeddings saved!
# ['18185462', '18185525', '18185553', '18185570', '18185670', '18185698', '18185761', '18185783', '18185854', '18185939']
# Batch 698 indices saved!
# Batch 698 embeddings saved!
# ['18185992', '18186119', '18186121', '18186151', '18186165', '18186208', '18186232', '18186238', '18186256', '18186312']
# Batch 699 indices saved!
# Batch 699 embeddings saved!
# ['18186331', '18186463', '18186601', '18186677', '18186707', '18186777', '18187073', '18187109', '18187190', '18187286']
# Batch 700 indices saved!
# Batch 700 embeddings saved!
# ['18187385', '18187476', '18187505', '18187543', '18187584', '18187624', '18187709', '18187988', '18188130', '18188212']
# Batch 701 indices saved!
# Batch 701 embeddings saved!
# ['18188232', '18188384', '18188388', '18188513', '18188567', '18188639', '18188650', '18188702', '18188773', '18188790']
# Batch 702 indices saved!
# Batch 702 embeddings saved!
# ['18188827', '18188911', '18189047', '18189276', '18189560', '18189593', '18189626', '18189726', '18189905', '18189992']
# Batch 703 indices saved!
# Batch 703 embeddings saved!
# ['18190010', '18190044', '18190083', '18190129', '18190131', '18190193', '18190260', '18190267', '18190271', '18190280']
# Batch 704 indices saved!
# Batch 704 embeddings saved!
# ['18190311', '18190318', '18190357', '18190372', '18190393', '18190394', '18190419', '18190484', '18190560', '18190753']
# Batch 705 indices saved!
# Batch 705 embeddings saved!
# ['18190787', '18191012', '18191017', '18191019', '18191069', '18191088', '18191101', '18191109', '18191115', '18191255']
# Batch 706 indices saved!
# Batch 706 embeddings saved!
# ['18191324', '18191525', '18191592', '18191698', '18191776', '18192132', '18192227', '18192245', '18192464', '18192542']
# Batch 707 indices saved!
# Batch 707 embeddings saved!
# ['18192630', '18192636', '18192654', '18192657', '18192735', '18193053', '18193144', '18193224', '18193605', '18193658']
# Batch 708 indices saved!
# Batch 708 embeddings saved!
# ['18193674', '18193681', '18193685', '18193812', '18194077', '18194099', '18194132', '18194264', '18194491', '18194496']
# Batch 709 indices saved!
# Batch 709 embeddings saved!
# ['18194498', '18194503', '18194649', '18194769', '18195003', '18195071', '18195455', '18195715', '18195848', '18196047']
# Batch 710 indices saved!
# Batch 710 embeddings saved!
# ['18196194', '18196211', '18196318', '18196400', '18196617', '18196809', '18196827', '18196889', '18197010', '18197108']
# Batch 711 indices saved!
# Batch 711 embeddings saved!
# ['18197350', '18197355', '18197751', '18198135', '18198258', '18198459', '18198460', '18198825', '18198897', '18198929']
# Batch 712 indices saved!
# Batch 712 embeddings saved!
# ['18199197', '18199245', '18199313', '18200102', '18200166', '18200197', '18200387', '18200801', '18201295', '18201300']
# Batch 713 indices saved!
# Batch 713 embeddings saved!
# ['18201359', '18201422', '18201758', '18202499', '18202563', '18203300', '18203686', '18204062', '18204336', '18204337']
# Batch 714 indices saved!
# Batch 714 embeddings saved!
# ['18204355', '18204409', '18204719', '18204777', '18204797', '18205019', '18205124', '18205161', '18205385', '18205445']
# Batch 715 indices saved!
# Batch 715 embeddings saved!
# ['18206040', '18206237', '18206702', '18206976', '18207075', '18207433', '18207437', '18207675', '18208056', '18209296']
# Batch 716 indices saved!
# Batch 716 embeddings saved!
# ['18209580', '18209650', '18210985', '18211301', '18211308', '18212008', '18212366', '18212396', '18212616', '18212865']
# Batch 717 indices saved!
# Batch 717 embeddings saved!
# ['18212905', '18213715', '18213815', '18213905', '18214640', '18215192', '18215196', '18217037', '18217322', '18218379']
# Batch 718 indices saved!
# Batch 718 embeddings saved!
# ['18218632', '18219215', '18219704', '18221022', '18221174', '18221313', '18221331', '18221453', '18221813', '18221902']
# Batch 719 indices saved!
# Batch 719 embeddings saved!
# ['18223774', '18223863', '18224280', '18224793', '18224853', '18226933', '18227193', '18228675', '18229424', '18231235']
# Batch 720 indices saved!
# Batch 720 embeddings saved!
# ['18231697', '18231998', '18233860', '18235363', '18241990', '18244960', '18245126', '18245225', '18245254', '18245288']
# Batch 721 indices saved!
# Batch 721 embeddings saved!
# ['18245331', '18245421', '18245487', '18245497', '18245791', '18245912', '18246161', '18246342', '18246350', '18246465']
# Batch 722 indices saved!
# Batch 722 embeddings saved!
# ['18246906', '18246973', '18247879', '18248127', '18248157', '18248344', '18248654', '18249208', '18249382', '18249439']
# Batch 723 indices saved!
# Batch 723 embeddings saved!
# ['18250543', '18250824', '18251530', '18252288', '18252863', '18253305', '18253370', '18253449', '18253532', '18253717']
# Batch 724 indices saved!
# Batch 724 embeddings saved!
# ['18253858', '18254071', '18259564', '18261310', '18265242', '18265245', '18265486', '18268954', '18270232', '18295015']
# Batch 725 indices saved!
# Batch 725 embeddings saved!
# ['18295114', '18295258', '18295312', '18295349', '18295463', '18295513', '18295700', '18295781', '18295934', '18296078']
# Batch 726 indices saved!
# Batch 726 embeddings saved!
# ['18296223', '18296532', '18296656', '18296970', '18297455', '18297648', '18297973', '18297985', '18298712', '18298718']
# Batch 727 indices saved!
# Batch 727 embeddings saved!
# ['18298728', '18299180', '18299195', '18299278', '18299561', '18299583', '18299727', '18299836', '18299840', '18299883']
# Batch 728 indices saved!
# Batch 728 embeddings saved!
# ['18300018', '18300079', '18300092', '18300615', '18300761', '18300881', '18301047', '18301214', '18301364', '18301660']
# Batch 729 indices saved!
# Batch 729 embeddings saved!
# ['18301754', '18301833', '18301941', '18302263', '18302745', '18303224', '18303399', '18303443', '18303797', '18303889']
# Batch 730 indices saved!
# Batch 730 embeddings saved!
# ['18304026', '18304175', '18304495', '18304604', '18304683', '18304750', '18304838', '18304878', '18305246', '18305305']
# Batch 731 indices saved!
# Batch 731 embeddings saved!
# ['18305307', '18305311', '18305339', '18305355', '18305779', '18305835', '18306064', '18306166', '18306327', '18306411']
# Batch 732 indices saved!
# Batch 732 embeddings saved!
# ['18306652', '18306951', '18307143', '18307569', '18307588', '18307717', '18308016', '18308286', '18308305', '18308958']
# Batch 733 indices saved!
# Batch 733 embeddings saved!
# ['18309019', '18309336', '18309595', '18309835', '18309844', '18309932', '18309955', '18310017', '18310308', '18310623']
# Batch 734 indices saved!
# Batch 734 embeddings saved!
# ['18310975', '18310990', '18311079', '18311103', '18311649', '18311858', '18311920', '18312260', '18312296', '18312639']
# Batch 735 indices saved!
# Batch 735 embeddings saved!
# ['18312816', '18313281', '18313317', '18313483', '18313641', '18314120', '18314158', '18314348', '18314498', '18314552']
# Batch 736 indices saved!
# Batch 736 embeddings saved!
# ['18314791', '18314792', '18314868', '18315138', '18315594', '18315692', '18315846', '18316196', '18316257', '18316317']
# Batch 737 indices saved!
# Batch 737 embeddings saved!
# ['18316326', '18316428', '18316778', '18317067', '18317269', '18317281', '18317388', '18317392', '18317928', '18318017']
# Batch 738 indices saved!
# Batch 738 embeddings saved!
# ['18318378', '18318399', '18318701', '18318763', '18319133', '18319669', '18319709', '18319741', '18319744', '18319793']
# Batch 739 indices saved!
# Batch 739 embeddings saved!
# ['18319889', '18320228', '18320280', '18320544', '18320551', '18320626', '18320973', '18321630', '18321766', '18322427']
# Batch 740 indices saved!
# Batch 740 embeddings saved!
# ['18322669', '18322709', '18323200', '18323435', '18323965', '18324335', '18324420', '18325052', '18325165', '18325573']
# Batch 741 indices saved!
# Batch 741 embeddings saved!
# ['18326143', '18326742', '18327079', '18327674', '18327694', '18327721', '18327870', '18327923', '18328189', '18328772']
# Batch 742 indices saved!
# Batch 742 embeddings saved!
# ['18329399', '18329511', '18329572', '18329674', '18329771', '18330625', '18331060', '18331064', '18331104', '18331146']
# Batch 743 indices saved!
# Batch 743 embeddings saved!
# ['18331319', '18331442', '18331663', '18331696', '18331787', '18331806', '18331910', '18332289', '18333211', '18333575']
# Batch 744 indices saved!
# Batch 744 embeddings saved!
# ['18334051', '18334742', '18334760', '18336092', '18336614', '18336963', '18337112', '18337120', '18337124', '18337135']
# Batch 745 indices saved!
# Batch 745 embeddings saved!
# ['18337439', '18337482', '18337840', '18339125', '18339186', '18339256', '18340576', '18340909', '18341234', '18342480']
# Batch 746 indices saved!
# Batch 746 embeddings saved!
# ['18343265', '18345897', '18346036', '18346114', '18346241', '18346847', '18347545', '18349077', '18349919', '18350866']
# Batch 747 indices saved!
# Batch 747 embeddings saved!
# ['18350953', '18351949', '18352276', '18355404', '18355950', '18355973', '18356234', '18356348', '18356841', '18357389']
# Batch 748 indices saved!
# Batch 748 embeddings saved!
# ['18362329', '18363819', '18366835', '18445212', '18447597', '18448309', '18448333', '18449539', '18450819', '18455542']
# Batch 749 indices saved!
# Batch 749 embeddings saved!

# %%
# Reconstruct array of all embeddings
directory_base = "/content/drive/MyDrive/batched_titleabstracts"
all_embeddings = []
for batch in os.listdir(directory_base):
  batch_filename = os.path.join(directory_base, batch)
  batch_embeddings = np.load(batch_filename)
  all_embeddings.append(batch_embeddings)
combined_embeddings = np.vstack(all_embeddings)
print(combined_embeddings)
# Out:
# [[ 0.03034837 -0.00489766 -0.50506219 ... -0.7095755  -0.22306369
#   -1.44297842]
#  [-0.25145216  0.0405942   0.29899809 ...  0.05478382  0.3004861
#   -1.55152634]
#  [-0.291473    0.32873257  0.26148757 ... -0.73095918 -0.00283611
#   -1.29529727]
#  ...
#  [-0.024819   -0.04111831  0.14893415 ... -1.06156347  0.2407419
#   -1.24402985]
#  [-0.23080576  0.03502716  0.51062472 ... -0.28484833  0.3041521
#   -1.26389735]
#  [ 0.03682523 -0.11672256  0.29910511 ... -0.54894022  0.36077479
#   -1.44077576]]

# %%
# Reconstrct array of all indices
directory_base = "/content/drive/MyDrive/batched_indices"
all_indices = []
for batch in os.listdir(directory_base):
  batch_filename = os.path.join(directory_base,batch)
  with open(batch_filename, "r") as index_reader:
    all_indices.extend(index_reader.read().splitlines())
print(all_indices)
# Out:
# ['18455542', '18450819', '18449539', '18448333', '18448309', '18447597', '18445212', '18366835', '18363819', '18362329', '18357389', '18356841', '18356348', '18356234', '18355973', '18355950', '18355404', '18352276', '18351949', '18350953', '18350866', '18349919', '18349077', '18347545', '18346847', '18346241', '18346114', '18346036', '18345897', '18343265', '18342480', '18341234', '18340909', '18340576', '18339256', '18339186', '18339125', '18337840', '18337482', '18337439']

# %%
# Read in data for analysis
directory_base_analysis = "/content/drive/MyDrive/all"
indices = np.load(os.path.join(directory_base_analysis, "indicies.npy"))
fulltext = np.load(os.path.join(directory_base_analysis, "fulltext.npy"))
fulltext_trunc = np.load(os.path.join(directory_base_analysis, "fulltext_trunc.npy"))
titleabstracts = np.load(os.path.join(directory_base_analysis, "titleabstracts.npy"))

# %%
def top_k_similar_patent_indices(patent_index, all_patent_indices, all_patent_embeddings, k):
  try:
    ind = all_patent_indices.index(patent_index)
    patent_embedding = all_patent_embeddings[ind]
  except:
    assert("patent embedding does not exist")

  A = patent_embedding
  B = all_patent_embeddings

  A_normalized = A / np.linalg.norm(A)
  B_normalized = B / np.linalg.norm(B, axis=1, keepdims=True)

  # Compute cosine similarities
  similarities = np.dot(B_normalized, A_normalized)

  # Use argpartition to find the top k indices efficiently
  top_k_indices = np.argpartition(-similarities, k+1)[:k+1]  # Select top k indices (negate for descending order)

  # Sort the top k indices by similarity for the final order
  top_k_indices = top_k_indices[np.argsort(-similarities[top_k_indices])]
  top_k_patent_indices = [all_patent_indices[id] for id in top_k_indices[1:]]
  return top_k_patent_indices

# %%
def top_all_indices(patent_index, all_patent_indices, all_patent_embeddings):
    ind = np.where(all_patent_indices == patent_index)[0]
    patent_embedding = all_patent_embeddings[ind]

    # Normalize A and B for cosine similarity
    patent_embedding_norm = patent_embedding / np.linalg.norm(patent_embedding)
    all_patent_embeddings_norm = all_patent_embeddings / np.linalg.norm(all_patent_embeddings, axis=1, keepdims=True)

    # Compute cosine similarity
    similarities = np.dot(all_patent_embeddings_norm, patent_embedding_norm.T)

    # Combine C and D into a 2D array
    CD_combined = np.column_stack((similarities, all_patent_indices))

    # Sort by the first column (C) in descending order
    CD_sorted = CD_combined[np.argsort(CD_combined[:, 0])[::-1]]

    # Extract the sorted D values
    D_sorted = CD_sorted[:, 1]

    # D_sorted is the desired output
    return D_sorted

# %%
def ind_to_text(index, titleabstract = True):
  with open(os.path.join("/content/drive/MyDrive/titleabstracttexts1", f"{index}.txt")) as f:
    return f.read()

# %%
k = 5
print("PATENT TO MATCH:")
print("\n")
print(ind_to_text('18363819'),f"\n\nTOP {k} MOST SIMILAR")
print("\n")
for ind in top_k_similar_patent_indices('18363819', all_indices, combined_embeddings, k):
  print(ind_to_text(ind))
# Out:
# PATENT TO MATCH:
#
#
# METHOD OF MANUFACTURING SEMICONDUCTOR STRUCTURE, SEMICONDUCTOR STRUCTURE, AND MEMORY
# The present disclosure provides a method of manufacturing a semiconductor structure, a semiconductor structure, and a memory. The semiconductor structure includes a base. The base includes columnar basal bodies and an isolation layer filled around the columnar basal bodies. Word line trenches are provided in the base and extend along a direction parallel to a surface of the base. First trench portions are formed at parts of the word line trenches intersecting with the columnar basal bodies, and a first word line conductive layer, a second word line conductive layer, and an insulating layer are sequentially arranged in the first trench portions from bottom to top. Second trench portions are formed at parts of the word line trenches intersecting with the isolation layer, and the second word line conductive layer and the insulating layer are sequentially arranged in the second trench portions from bottom to top.
#
#
# TOP 5 MOST SIMILAR
#
#
# BATTERY, POWER CONSUMING APPARATUS, AND METHOD AND APPARATUS FOR MANUFACTURING BATTERY
# Provided are a battery, comprising: a battery cell group comprising N battery cell rows arranged in a first direction, battery cells in each battery cell row being arranged in a second direction, the first direction being perpendicular to the second direction; a signal transmission assembly provided on the first face of the battery cell group and comprising a busbar component and an insulation layer, the busbar component being configured to be electrically connected to the battery cells at holes of the insulation layer; and a cooling system provided between two adjacent battery cell rows in the N battery cell rows, with a blocking member being provided at an opening, facing the first face, of a gap between the two adjacent battery cell rows to block the opening to prevent condensed liquid generated by the cooling system from reaching the busbar component.
#
# BATTERY UNIT, BATTERY, AND ELECTRIC APPARATUS
# This application discloses a battery unit. The battery unit includes a housing, at least one cell, and a buffer. The at least one cell is accommodated in the housing, the buffer is disposed corresponding to a side wall of the cell, and the buffer is provided with an accommodating cavity. A periphery of the accommodating cavity includes at least one packaging structure, the packaging structure includes at least one level of packaging region with a predetermined length. When pressure in the accommodating cavity exceeds packaging strength of the packaging structure, the packaging region is opened to form a buffer space that communicates with the accommodating cavity, reducing influence caused by swelling of the cell.
#
# FOLDING CHAIR FRAMEWORK
# The present disclosure relates to a folding chair framework, including a connecting seat, a guide rod, a guide sleeve, several chair legs, several supporting rods, several connecting rods, a first spring, a second spring, and wedge-shaped blocks; upper ends of the chair legs are all hinged with the connecting seat; the guide rod is vertically arranged and connected to the connecting seat; the guide sleeve is slidably connected to the guide rod; each connecting rod is hinged with the guide sleeve and one chair leg respectively; upper and lower ends of the first spring are respectively connected to the connecting seat and the guide sleeve; the wedge-shaped blocks are slidably connected into first grooves of the guide rod; two ends of the second spring are respectively connected to the first grooves and the wedge-shaped blocks; the guide sleeve includes an inner sleeve and an outer sleeve.
#
# PORTABLE SIMULATED FLOOD DISCHARGE CULVERT FOR SURVEYING AND MAPPING
# Provided is a portable simulated flood discharge culvert for surveying and mapping, including a supporting device, where the supporting device includes a plurality of telescopic support rods, and the telescopic support rods; a tarpaulin, where the tarpaulin is cover on outer walls of the telescopic support rods; connecting devices, where each of the connecting devices is installed between any two adjacent telescopic support rods; floors, where the floors are respectively arranged between the plurality of telescopic support rods, and top surfaces of the floors are provided with a plurality of protrusions; adjusting devices, where each of the adjusting devices includes angle adjusting mechanisms and a height adjusting mechanism, and the angle adjusting mechanisms and the height adjusting mechanism are respectively fixed on a bottom surface of each of the floors; a fog generating device, a lighting part, and additional blocks.
#
# COATING APPARATUS AND COATING SYSTEM
# Provided are a coating apparatus and a coating system, where the coating apparatus includes: a coating module, the coating module including a coating roller and a coating die, where the coating roller is configured to drive, when rotating, a substrate to move toward the coating die, and the coating die is configured to apply a coating onto the substrate; an error acquisition module having a predetermined distance to the coating roller and configured to acquire a circular run-out error of rotation of the coating roller and transmit the circular run-out error to a linkage module; and the linkage module configured to adjust position of the coating die in real time according to the circular run-out error transmitted to the linkage module, so as to keep a distance between the coating roller and the coating die unchanged.

# %% [markdown]
# # Detailed text processing

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("anferico/bert-for-patents")

# %%
def truncate_to_512_tokens(text):
    # Tokenize the input
    tokens = tokenizer.tokenize(text)

    # Truncate to 512 tokens
    truncated_tokens = tokens[:450]

    # Convert back to string
    truncated_text = tokenizer.convert_tokens_to_string(truncated_tokens)
    return truncated_text

# %%
def summarize(text, summary_model, chunk_size = 1000, summary_length = 100):
  # Tokenize the input text to estimate token length
  tokens = text.split()

  # Split the text into chunks of chunk_size tokens
  chunks = [' '.join(tokens[i:i + chunk_size]) for i in range(0, len(tokens), chunk_size)]

  # Summarize each chunk
  summaries = []
  for ind, chunk in enumerate(chunks):
    if ind >= 5:
      break
    if 20 < len(chunk.split()) < 100:
      summary = summarizer(chunk, max_length=20, min_length=15, truncation=True)
    elif len(chunk.split())<=20:
      continue
    else:
      summary = summarizer(chunk, max_length=summary_length, min_length=summary_length//2, truncation=True)
    summaries.append(summary[0]['summary_text'])  # Extract summary text

  # Concatenate the summaries
  final_summary = ' '.join(summaries)

  return final_summary

# %%
# Encode the description texts batch by batch and save them
for batch_ind, textinfo in enumerate(fulltextloader(10)):
  print(f"Processing batch {batch_ind}")
  id_set, texts = textinfo

  new_texts = [summarize(text, summarizer) for text in texts]
  new_texts_shortened = [truncate_to_512_tokens(text) for text in new_texts]
  print(f"batch {batch_ind} has been shortened")

  # Extract features for each text
  features = feature_extracter(new_texts_shortened)
  squeezed_features = [np.squeeze(np.array(feats), axis=0) for feats in features]

  # Aggregate token embeddings (e.g., using the mean)
  aggregated_features = [np.mean(np.array(feats), axis=0) for feats in squeezed_features]

  # Save indices
  with open(f"/content/drive/MyDrive/batched_indices_fulltext1/batch_{batch_ind}.txt", "w") as f:
    f.write("\n".join(id_set))
  print(f"Batch {batch_ind} fulltext indices saved!")

  # Save embeded titleabstracts
  directory_embedding = os.path.join("/content/drive/MyDrive/batched_titleabstracts_fulltext1", f"batch_{batch_ind}.npy")
  np.save(directory_embedding, aggregated_features)
  print(f"Batch {batch_ind} fulltext embeddings saved!")
# Out:
# Processing batch 0
# batch 0 has been shortened
# Batch 0 fulltext indices saved!
# Batch 0 fulltext embeddings saved!
# Processing batch 1
# batch 1 has been shortened
# Batch 1 fulltext indices saved!
# Batch 1 fulltext embeddings saved!
# Processing batch 2
# batch 2 has been shortened
# Batch 2 fulltext indices saved!
# Batch 2 fulltext embeddings saved!
# Processing batch 3
# batch 3 has been shortened
# Batch 3 fulltext indices saved!
# Batch 3 fulltext embeddings saved!
# Processing batch 4
# batch 4 has been shortened
# Batch 4 fulltext indices saved!
# Batch 4 fulltext embeddings saved!
# Processing batch 5
# batch 5 has been shortened
# Batch 5 fulltext indices saved!
# Batch 5 fulltext embeddings saved!
# Processing batch 6
# batch 6 has been shortened
# Batch 6 fulltext indices saved!
# Batch 6 fulltext embeddings saved!
# Processing batch 7
# batch 7 has been shortened
# Batch 7 fulltext indices saved!
# Batch 7 fulltext embeddings saved!
# Processing batch 8
# batch 8 has been shortened
# Batch 8 fulltext indices saved!
# Batch 8 fulltext embeddings saved!
# Processing batch 9
# batch 9 has been shortened
# Batch 9 fulltext indices saved!
# Batch 9 fulltext embeddings saved!
# Processing batch 10
# batch 10 has been shortened
# Batch 10 fulltext indices saved!
# Batch 10 fulltext embeddings saved!
# Processing batch 11
# batch 11 has been shortened
# Batch 11 fulltext indices saved!
# Batch 11 fulltext embeddings saved!
# Processing batch 12
# batch 12 has been shortened
# Batch 12 fulltext indices saved!
# Batch 12 fulltext embeddings saved!
# Processing batch 13
# batch 13 has been shortened
# Batch 13 fulltext indices saved!
# Batch 13 fulltext embeddings saved!
# Processing batch 14
# batch 14 has been shortened
# Batch 14 fulltext indices saved!
# Batch 14 fulltext embeddings saved!
# Processing batch 15
# batch 15 has been shortened
# Batch 15 fulltext indices saved!
# Batch 15 fulltext embeddings saved!
# Processing batch 16
# batch 16 has been shortened
# Batch 16 fulltext indices saved!
# Batch 16 fulltext embeddings saved!
# Processing batch 17
# batch 17 has been shortened
# Batch 17 fulltext indices saved!
# Batch 17 fulltext embeddings saved!
# Processing batch 18
# batch 18 has been shortened
# Batch 18 fulltext indices saved!
# Batch 18 fulltext embeddings saved!
# Processing batch 19
# batch 19 has been shortened
# Batch 19 fulltext indices saved!
# Batch 19 fulltext embeddings saved!
# Processing batch 20
# batch 20 has been shortened
# Batch 20 fulltext indices saved!
# Batch 20 fulltext embeddings saved!
# Processing batch 21
# batch 21 has been shortened
# Batch 21 fulltext indices saved!
# Batch 21 fulltext embeddings saved!
# Processing batch 22
# batch 22 has been shortened
# Batch 22 fulltext indices saved!
# Batch 22 fulltext embeddings saved!
# Processing batch 23
# batch 23 has been shortened
# Batch 23 fulltext indices saved!
# Batch 23 fulltext embeddings saved!
# Processing batch 24
# batch 24 has been shortened
# Batch 24 fulltext indices saved!
# Batch 24 fulltext embeddings saved!
# Processing batch 25
# batch 25 has been shortened
# Batch 25 fulltext indices saved!
# Batch 25 fulltext embeddings saved!
# Processing batch 26
# batch 26 has been shortened
# Batch 26 fulltext indices saved!
# Batch 26 fulltext embeddings saved!
# Processing batch 27
# batch 27 has been shortened
# Batch 27 fulltext indices saved!
# Batch 27 fulltext embeddings saved!
# Processing batch 28
# batch 28 has been shortened
# Batch 28 fulltext indices saved!
# Batch 28 fulltext embeddings saved!
# Processing batch 29
# batch 29 has been shortened
# Batch 29 fulltext indices saved!
# Batch 29 fulltext embeddings saved!
# Processing batch 30
# batch 30 has been shortened
# Batch 30 fulltext indices saved!
# Batch 30 fulltext embeddings saved!
# Processing batch 31
# batch 31 has been shortened
# Batch 31 fulltext indices saved!
# Batch 31 fulltext embeddings saved!
# Processing batch 32
# batch 32 has been shortened
# Batch 32 fulltext indices saved!
# Batch 32 fulltext embeddings saved!
# Processing batch 33
# batch 33 has been shortened
# Batch 33 fulltext indices saved!
# Batch 33 fulltext embeddings saved!
# Processing batch 34
# batch 34 has been shortened
# Batch 34 fulltext indices saved!
# Batch 34 fulltext embeddings saved!
# Processing batch 35
# batch 35 has been shortened
# Batch 35 fulltext indices saved!
# Batch 35 fulltext embeddings saved!
# Processing batch 36
# batch 36 has been shortened
# Batch 36 fulltext indices saved!
# Batch 36 fulltext embeddings saved!
# Processing batch 37
# batch 37 has been shortened
# Batch 37 fulltext indices saved!
# Batch 37 fulltext embeddings saved!
# Processing batch 38
# batch 38 has been shortened
# Batch 38 fulltext indices saved!
# Batch 38 fulltext embeddings saved!
# Processing batch 39
# batch 39 has been shortened
# Batch 39 fulltext indices saved!
# Batch 39 fulltext embeddings saved!
# Processing batch 40
# batch 40 has been shortened
# Batch 40 fulltext indices saved!
# Batch 40 fulltext embeddings saved!
# Processing batch 41
# batch 41 has been shortened
# Batch 41 fulltext indices saved!
# Batch 41 fulltext embeddings saved!
# Processing batch 42
# batch 42 has been shortened
# Batch 42 fulltext indices saved!
# Batch 42 fulltext embeddings saved!
# Processing batch 43
# batch 43 has been shortened
# Batch 43 fulltext indices saved!
# Batch 43 fulltext embeddings saved!
# Processing batch 44
# batch 44 has been shortened
# Batch 44 fulltext indices saved!
# Batch 44 fulltext embeddings saved!
# Processing batch 45
# batch 45 has been shortened
# Batch 45 fulltext indices saved!
# Batch 45 fulltext embeddings saved!
# Processing batch 46
# batch 46 has been shortened
# Batch 46 fulltext indices saved!
# Batch 46 fulltext embeddings saved!
# Processing batch 47
# batch 47 has been shortened
# Batch 47 fulltext indices saved!
# Batch 47 fulltext embeddings saved!
# Processing batch 48
# batch 48 has been shortened
# Batch 48 fulltext indices saved!
# Batch 48 fulltext embeddings saved!
# Processing batch 49
# batch 49 has been shortened
# Batch 49 fulltext indices saved!
# Batch 49 fulltext embeddings saved!
# Processing batch 50
# batch 50 has been shortened
# Batch 50 fulltext indices saved!
# Batch 50 fulltext embeddings saved!
# Processing batch 51
# batch 51 has been shortened
# Batch 51 fulltext indices saved!
# Batch 51 fulltext embeddings saved!
# Processing batch 52
# batch 52 has been shortened
# Batch 52 fulltext indices saved!
# Batch 52 fulltext embeddings saved!
# Processing batch 53
# batch 53 has been shortened
# Batch 53 fulltext indices saved!
# Batch 53 fulltext embeddings saved!
# Processing batch 54
# batch 54 has been shortened
# Batch 54 fulltext indices saved!
# Batch 54 fulltext embeddings saved!
# Processing batch 55
# batch 55 has been shortened
# Batch 55 fulltext indices saved!
# Batch 55 fulltext embeddings saved!
# Processing batch 56
# batch 56 has been shortened
# Batch 56 fulltext indices saved!
# Batch 56 fulltext embeddings saved!
# Processing batch 57
# batch 57 has been shortened
# Batch 57 fulltext indices saved!
# Batch 57 fulltext embeddings saved!
# Processing batch 58
# batch 58 has been shortened
# Batch 58 fulltext indices saved!
# Batch 58 fulltext embeddings saved!
# Processing batch 59
# batch 59 has been shortened
# Batch 59 fulltext indices saved!
# Batch 59 fulltext embeddings saved!
# Processing batch 60
# batch 60 has been shortened
# Batch 60 fulltext indices saved!
# Batch 60 fulltext embeddings saved!
# Processing batch 61
# batch 61 has been shortened
# Batch 61 fulltext indices saved!
# Batch 61 fulltext embeddings saved!
# Processing batch 62
# batch 62 has been shortened
# Batch 62 fulltext indices saved!
# Batch 62 fulltext embeddings saved!
# Processing batch 63
# batch 63 has been shortened
# Batch 63 fulltext indices saved!
# Batch 63 fulltext embeddings saved!
# Processing batch 64
# batch 64 has been shortened
# Batch 64 fulltext indices saved!
# Batch 64 fulltext embeddings saved!
# Processing batch 65
# batch 65 has been shortened
# Batch 65 fulltext indices saved!
# Batch 65 fulltext embeddings saved!
# Processing batch 66
# batch 66 has been shortened
# Batch 66 fulltext indices saved!
# Batch 66 fulltext embeddings saved!
# Processing batch 67
# batch 67 has been shortened
# Batch 67 fulltext indices saved!
# Batch 67 fulltext embeddings saved!
# Processing batch 68
# batch 68 has been shortened
# Batch 68 fulltext indices saved!
# Batch 68 fulltext embeddings saved!
# Processing batch 69
# batch 69 has been shortened
# Batch 69 fulltext indices saved!
# Batch 69 fulltext embeddings saved!
# Processing batch 70
# batch 70 has been shortened
# Batch 70 fulltext indices saved!
# Batch 70 fulltext embeddings saved!
# Processing batch 71
# batch 71 has been shortened
# Batch 71 fulltext indices saved!
# Batch 71 fulltext embeddings saved!
# Processing batch 72
# batch 72 has been shortened
# Batch 72 fulltext indices saved!
# Batch 72 fulltext embeddings saved!
# Processing batch 73
# batch 73 has been shortened
# Batch 73 fulltext indices saved!
# Batch 73 fulltext embeddings saved!
# Processing batch 74
# batch 74 has been shortened
# Batch 74 fulltext indices saved!
# Batch 74 fulltext embeddings saved!
# Processing batch 75
# batch 75 has been shortened
# Batch 75 fulltext indices saved!
# Batch 75 fulltext embeddings saved!
# Processing batch 76
# batch 76 has been shortened
# Batch 76 fulltext indices saved!
# Batch 76 fulltext embeddings saved!
# Processing batch 77
# batch 77 has been shortened
# Batch 77 fulltext indices saved!
# Batch 77 fulltext embeddings saved!
# Processing batch 78
# batch 78 has been shortened
# Batch 78 fulltext indices saved!
# Batch 78 fulltext embeddings saved!
# Processing batch 79
# batch 79 has been shortened
# Batch 79 fulltext indices saved!
# Batch 79 fulltext embeddings saved!
# Processing batch 80
# batch 80 has been shortened
# Batch 80 fulltext indices saved!
# Batch 80 fulltext embeddings saved!
# Processing batch 81
# batch 81 has been shortened
# Batch 81 fulltext indices saved!
# Batch 81 fulltext embeddings saved!
# Processing batch 82
# batch 82 has been shortened
# Batch 82 fulltext indices saved!
# Batch 82 fulltext embeddings saved!
# Processing batch 83
# batch 83 has been shortened
# Batch 83 fulltext indices saved!
# Batch 83 fulltext embeddings saved!
# Processing batch 84
# batch 84 has been shortened
# Batch 84 fulltext indices saved!
# Batch 84 fulltext embeddings saved!
# Processing batch 85
# batch 85 has been shortened
# Batch 85 fulltext indices saved!
# Batch 85 fulltext embeddings saved!
# Processing batch 86
# batch 86 has been shortened
# Batch 86 fulltext indices saved!
# Batch 86 fulltext embeddings saved!
# Processing batch 87
# batch 87 has been shortened
# Batch 87 fulltext indices saved!
# Batch 87 fulltext embeddings saved!
# Processing batch 88
# batch 88 has been shortened
# Batch 88 fulltext indices saved!
# Batch 88 fulltext embeddings saved!
# Processing batch 89
# batch 89 has been shortened
# Batch 89 fulltext indices saved!
# Batch 89 fulltext embeddings saved!
# Processing batch 90
# batch 90 has been shortened
# Batch 90 fulltext indices saved!
# Batch 90 fulltext embeddings saved!
# Processing batch 91
# batch 91 has been shortened
# Batch 91 fulltext indices saved!
# Batch 91 fulltext embeddings saved!
# Processing batch 92
# batch 92 has been shortened
# Batch 92 fulltext indices saved!
# Batch 92 fulltext embeddings saved!
# Processing batch 93
# batch 93 has been shortened
# Batch 93 fulltext indices saved!
# Batch 93 fulltext embeddings saved!
# Processing batch 94
# batch 94 has been shortened
# Batch 94 fulltext indices saved!
# Batch 94 fulltext embeddings saved!
# Processing batch 95
# batch 95 has been shortened
# Batch 95 fulltext indices saved!
# Batch 95 fulltext embeddings saved!
# Processing batch 96
# batch 96 has been shortened
# Batch 96 fulltext indices saved!
# Batch 96 fulltext embeddings saved!
# Processing batch 97
# batch 97 has been shortened
# Batch 97 fulltext indices saved!
# Batch 97 fulltext embeddings saved!
# Processing batch 98
# batch 98 has been shortened
# Batch 98 fulltext indices saved!
# Batch 98 fulltext embeddings saved!
# Processing batch 99
# batch 99 has been shortened
# Batch 99 fulltext indices saved!
# Batch 99 fulltext embeddings saved!
# Processing batch 100
# batch 100 has been shortened
# Batch 100 fulltext indices saved!
# Batch 100 fulltext embeddings saved!
# Processing batch 101
# batch 101 has been shortened
# Batch 101 fulltext indices saved!
# Batch 101 fulltext embeddings saved!
# Processing batch 102
# batch 102 has been shortened
# Batch 102 fulltext indices saved!
# Batch 102 fulltext embeddings saved!
# Processing batch 103
# batch 103 has been shortened
# Batch 103 fulltext indices saved!
# Batch 103 fulltext embeddings saved!
# Processing batch 104
# batch 104 has been shortened
# Batch 104 fulltext indices saved!
# Batch 104 fulltext embeddings saved!
# Processing batch 105
# batch 105 has been shortened
# Batch 105 fulltext indices saved!
# Batch 105 fulltext embeddings saved!
# Processing batch 106
# batch 106 has been shortened
# Batch 106 fulltext indices saved!
# Batch 106 fulltext embeddings saved!
# Processing batch 107
# batch 107 has been shortened
# Batch 107 fulltext indices saved!
# Batch 107 fulltext embeddings saved!
# Processing batch 108
# batch 108 has been shortened
# Batch 108 fulltext indices saved!
# Batch 108 fulltext embeddings saved!
# Processing batch 109
# batch 109 has been shortened
# Batch 109 fulltext indices saved!
# Batch 109 fulltext embeddings saved!
# Processing batch 110
# batch 110 has been shortened
# Batch 110 fulltext indices saved!
# Batch 110 fulltext embeddings saved!
# Processing batch 111
# batch 111 has been shortened
# Batch 111 fulltext indices saved!
# Batch 111 fulltext embeddings saved!
# Processing batch 112
# batch 112 has been shortened
# Batch 112 fulltext indices saved!
# Batch 112 fulltext embeddings saved!
# Processing batch 113
# batch 113 has been shortened
# Batch 113 fulltext indices saved!
# Batch 113 fulltext embeddings saved!
# Processing batch 114
# batch 114 has been shortened
# Batch 114 fulltext indices saved!
# Batch 114 fulltext embeddings saved!
# Processing batch 115
# batch 115 has been shortened
# Batch 115 fulltext indices saved!
# Batch 115 fulltext embeddings saved!
# Processing batch 116
# batch 116 has been shortened
# Batch 116 fulltext indices saved!
# Batch 116 fulltext embeddings saved!
# Processing batch 117
# batch 117 has been shortened
# Batch 117 fulltext indices saved!
# Batch 117 fulltext embeddings saved!
# Processing batch 118
# batch 118 has been shortened
# Batch 118 fulltext indices saved!
# Batch 118 fulltext embeddings saved!
# Processing batch 119
# batch 119 has been shortened
# Batch 119 fulltext indices saved!
# Batch 119 fulltext embeddings saved!
# Processing batch 120
# batch 120 has been shortened
# Batch 120 fulltext indices saved!
# Batch 120 fulltext embeddings saved!
# Processing batch 121
# batch 121 has been shortened
# Batch 121 fulltext indices saved!
# Batch 121 fulltext embeddings saved!
# Processing batch 122
# batch 122 has been shortened
# Batch 122 fulltext indices saved!
# Batch 122 fulltext embeddings saved!
# Processing batch 123
# batch 123 has been shortened
# Batch 123 fulltext indices saved!
# Batch 123 fulltext embeddings saved!
# Processing batch 124
# batch 124 has been shortened
# Batch 124 fulltext indices saved!
# Batch 124 fulltext embeddings saved!
# Processing batch 125
# batch 125 has been shortened
# Batch 125 fulltext indices saved!
# Batch 125 fulltext embeddings saved!
# Processing batch 126
# batch 126 has been shortened
# Batch 126 fulltext indices saved!
# Batch 126 fulltext embeddings saved!
# Processing batch 127
# batch 127 has been shortened
# Batch 127 fulltext indices saved!
# Batch 127 fulltext embeddings saved!
# Processing batch 128
# batch 128 has been shortened
# Batch 128 fulltext indices saved!
# Batch 128 fulltext embeddings saved!
# Processing batch 129
# batch 129 has been shortened
# Batch 129 fulltext indices saved!
# Batch 129 fulltext embeddings saved!
# Processing batch 130
# batch 130 has been shortened
# Batch 130 fulltext indices saved!
# Batch 130 fulltext embeddings saved!
# Processing batch 131
# batch 131 has been shortened
# Batch 131 fulltext indices saved!
# Batch 131 fulltext embeddings saved!
# Processing batch 132
# batch 132 has been shortened
# Batch 132 fulltext indices saved!
# Batch 132 fulltext embeddings saved!
# Processing batch 133
# batch 133 has been shortened
# Batch 133 fulltext indices saved!
# Batch 133 fulltext embeddings saved!
# Processing batch 134
# batch 134 has been shortened
# Batch 134 fulltext indices saved!
# Batch 134 fulltext embeddings saved!
# Processing batch 135
# batch 135 has been shortened
# Batch 135 fulltext indices saved!
# Batch 135 fulltext embeddings saved!
# Processing batch 136
# batch 136 has been shortened
# Batch 136 fulltext indices saved!
# Batch 136 fulltext embeddings saved!
# Processing batch 137
# batch 137 has been shortened
# Batch 137 fulltext indices saved!
# Batch 137 fulltext embeddings saved!
# Processing batch 138
# batch 138 has been shortened
# Batch 138 fulltext indices saved!
# Batch 138 fulltext embeddings saved!
# Processing batch 139
# batch 139 has been shortened
# Batch 139 fulltext indices saved!
# Batch 139 fulltext embeddings saved!
# Processing batch 140
# batch 140 has been shortened
# Batch 140 fulltext indices saved!
# Batch 140 fulltext embeddings saved!
# Processing batch 141
# batch 141 has been shortened
# Batch 141 fulltext indices saved!
# Batch 141 fulltext embeddings saved!
# Processing batch 142
# batch 142 has been shortened
# Batch 142 fulltext indices saved!
# Batch 142 fulltext embeddings saved!
# Processing batch 143
# batch 143 has been shortened
# Batch 143 fulltext indices saved!
# Batch 143 fulltext embeddings saved!
# Processing batch 144
# batch 144 has been shortened
# Batch 144 fulltext indices saved!
# Batch 144 fulltext embeddings saved!
# Processing batch 145
# batch 145 has been shortened
# Batch 145 fulltext indices saved!
# Batch 145 fulltext embeddings saved!
# Processing batch 146
# batch 146 has been shortened
# Batch 146 fulltext indices saved!
# Batch 146 fulltext embeddings saved!
# Processing batch 147
# batch 147 has been shortened
# Batch 147 fulltext indices saved!
# Batch 147 fulltext embeddings saved!
# Processing batch 148
# batch 148 has been shortened
# Batch 148 fulltext indices saved!
# Batch 148 fulltext embeddings saved!
# Processing batch 149
# batch 149 has been shortened
# Batch 149 fulltext indices saved!
# Batch 149 fulltext embeddings saved!
# Processing batch 150
# batch 150 has been shortened
# Batch 150 fulltext indices saved!
# Batch 150 fulltext embeddings saved!
# Processing batch 151
# batch 151 has been shortened
# Batch 151 fulltext indices saved!
# Batch 151 fulltext embeddings saved!
# Processing batch 152
# batch 152 has been shortened
# Batch 152 fulltext indices saved!
# Batch 152 fulltext embeddings saved!
# Processing batch 153
# batch 153 has been shortened
# Batch 153 fulltext indices saved!
# Batch 153 fulltext embeddings saved!
# Processing batch 154
# batch 154 has been shortened
# Batch 154 fulltext indices saved!
# Batch 154 fulltext embeddings saved!
# Processing batch 155
# batch 155 has been shortened
# Batch 155 fulltext indices saved!
# Batch 155 fulltext embeddings saved!
# Processing batch 156
# batch 156 has been shortened
# Batch 156 fulltext indices saved!
# Batch 156 fulltext embeddings saved!
# Processing batch 157
# batch 157 has been shortened
# Batch 157 fulltext indices saved!
# Batch 157 fulltext embeddings saved!
# Processing batch 158
# batch 158 has been shortened
# Batch 158 fulltext indices saved!
# Batch 158 fulltext embeddings saved!
# Processing batch 159
# batch 159 has been shortened
# Batch 159 fulltext indices saved!
# Batch 159 fulltext embeddings saved!
# Processing batch 160
# batch 160 has been shortened
# Batch 160 fulltext indices saved!
# Batch 160 fulltext embeddings saved!
# Processing batch 161
# batch 161 has been shortened
# Batch 161 fulltext indices saved!
# Batch 161 fulltext embeddings saved!
# Processing batch 162
# batch 162 has been shortened
# Batch 162 fulltext indices saved!
# Batch 162 fulltext embeddings saved!
# Processing batch 163
# batch 163 has been shortened
# Batch 163 fulltext indices saved!
# Batch 163 fulltext embeddings saved!
# Processing batch 164
# batch 164 has been shortened
# Batch 164 fulltext indices saved!
# Batch 164 fulltext embeddings saved!
# Processing batch 165
# batch 165 has been shortened
# Batch 165 fulltext indices saved!
# Batch 165 fulltext embeddings saved!
# Processing batch 166
# batch 166 has been shortened
# Batch 166 fulltext indices saved!
# Batch 166 fulltext embeddings saved!
# Processing batch 167
# batch 167 has been shortened
# Batch 167 fulltext indices saved!
# Batch 167 fulltext embeddings saved!
# Processing batch 168
# batch 168 has been shortened
# Batch 168 fulltext indices saved!
# Batch 168 fulltext embeddings saved!
# Processing batch 169
# batch 169 has been shortened
# Batch 169 fulltext indices saved!
# Batch 169 fulltext embeddings saved!
# Processing batch 170
# batch 170 has been shortened
# Batch 170 fulltext indices saved!
# Batch 170 fulltext embeddings saved!
# Processing batch 171
# batch 171 has been shortened
# Batch 171 fulltext indices saved!
# Batch 171 fulltext embeddings saved!
# Processing batch 172
# batch 172 has been shortened
# Batch 172 fulltext indices saved!
# Batch 172 fulltext embeddings saved!
# Processing batch 173
# batch 173 has been shortened
# Batch 173 fulltext indices saved!
# Batch 173 fulltext embeddings saved!
# Processing batch 174
# batch 174 has been shortened
# Batch 174 fulltext indices saved!
# Batch 174 fulltext embeddings saved!
# Processing batch 175
# batch 175 has been shortened
# Batch 175 fulltext indices saved!
# Batch 175 fulltext embeddings saved!
# Processing batch 176
# batch 176 has been shortened
# Batch 176 fulltext indices saved!
# Batch 176 fulltext embeddings saved!
# Processing batch 177
# batch 177 has been shortened
# Batch 177 fulltext indices saved!
# Batch 177 fulltext embeddings saved!
# Processing batch 178
# batch 178 has been shortened
# Batch 178 fulltext indices saved!
# Batch 178 fulltext embeddings saved!
# Processing batch 179
# batch 179 has been shortened
# Batch 179 fulltext indices saved!
# Batch 179 fulltext embeddings saved!
# Processing batch 180
# batch 180 has been shortened
# Batch 180 fulltext indices saved!
# Batch 180 fulltext embeddings saved!
# Processing batch 181
# batch 181 has been shortened
# Batch 181 fulltext indices saved!
# Batch 181 fulltext embeddings saved!
# Processing batch 182
# batch 182 has been shortened
# Batch 182 fulltext indices saved!
# Batch 182 fulltext embeddings saved!
# Processing batch 183
# batch 183 has been shortened
# Batch 183 fulltext indices saved!
# Batch 183 fulltext embeddings saved!
# Processing batch 184
# batch 184 has been shortened
# Batch 184 fulltext indices saved!
# Batch 184 fulltext embeddings saved!
# Processing batch 185
# batch 185 has been shortened
# Batch 185 fulltext indices saved!
# Batch 185 fulltext embeddings saved!
# Processing batch 186
# batch 186 has been shortened
# Batch 186 fulltext indices saved!
# Batch 186 fulltext embeddings saved!
# Processing batch 187
# batch 187 has been shortened
# Batch 187 fulltext indices saved!
# Batch 187 fulltext embeddings saved!
# Processing batch 188
# batch 188 has been shortened
# Batch 188 fulltext indices saved!
# Batch 188 fulltext embeddings saved!
# Processing batch 189
# batch 189 has been shortened
# Batch 189 fulltext indices saved!
# Batch 189 fulltext embeddings saved!
# Processing batch 190
# batch 190 has been shortened
# Batch 190 fulltext indices saved!
# Batch 190 fulltext embeddings saved!
# Processing batch 191
# batch 191 has been shortened
# Batch 191 fulltext indices saved!
# Batch 191 fulltext embeddings saved!
# Processing batch 192
# batch 192 has been shortened
# Batch 192 fulltext indices saved!
# Batch 192 fulltext embeddings saved!
# Processing batch 193
# batch 193 has been shortened
# Batch 193 fulltext indices saved!
# Batch 193 fulltext embeddings saved!
# Processing batch 194
# batch 194 has been shortened
# Batch 194 fulltext indices saved!
# Batch 194 fulltext embeddings saved!
# Processing batch 195
# batch 195 has been shortened
# Batch 195 fulltext indices saved!
# Batch 195 fulltext embeddings saved!
# Processing batch 196
# batch 196 has been shortened
# Batch 196 fulltext indices saved!
# Batch 196 fulltext embeddings saved!
# Processing batch 197
# batch 197 has been shortened
# Batch 197 fulltext indices saved!
# Batch 197 fulltext embeddings saved!
# Processing batch 198
# batch 198 has been shortened
# Batch 198 fulltext indices saved!
# Batch 198 fulltext embeddings saved!
# Processing batch 199
# batch 199 has been shortened
# Batch 199 fulltext indices saved!
# Batch 199 fulltext embeddings saved!
# Processing batch 200
# batch 200 has been shortened
# Batch 200 fulltext indices saved!
# Batch 200 fulltext embeddings saved!
# Processing batch 201
# batch 201 has been shortened
# Batch 201 fulltext indices saved!
# Batch 201 fulltext embeddings saved!
# Processing batch 202
# batch 202 has been shortened
# Batch 202 fulltext indices saved!
# Batch 202 fulltext embeddings saved!
# Processing batch 203
# batch 203 has been shortened
# Batch 203 fulltext indices saved!
# Batch 203 fulltext embeddings saved!
# Processing batch 204
# batch 204 has been shortened
# Batch 204 fulltext indices saved!
# Batch 204 fulltext embeddings saved!
# Processing batch 205
# batch 205 has been shortened
# Batch 205 fulltext indices saved!
# Batch 205 fulltext embeddings saved!
# Processing batch 206
# batch 206 has been shortened
# Batch 206 fulltext indices saved!
# Batch 206 fulltext embeddings saved!
# Processing batch 207
# batch 207 has been shortened
# Batch 207 fulltext indices saved!
# Batch 207 fulltext embeddings saved!
# Processing batch 208
# batch 208 has been shortened
# Batch 208 fulltext indices saved!
# Batch 208 fulltext embeddings saved!
# Processing batch 209
# batch 209 has been shortened
# Batch 209 fulltext indices saved!
# Batch 209 fulltext embeddings saved!
# Processing batch 210
# batch 210 has been shortened
# Batch 210 fulltext indices saved!
# Batch 210 fulltext embeddings saved!
# Processing batch 211
# batch 211 has been shortened
# Batch 211 fulltext indices saved!
# Batch 211 fulltext embeddings saved!
# Processing batch 212
# batch 212 has been shortened
# Batch 212 fulltext indices saved!
# Batch 212 fulltext embeddings saved!
# Processing batch 213
# batch 213 has been shortened
# Batch 213 fulltext indices saved!
# Batch 213 fulltext embeddings saved!
# Processing batch 214
# batch 214 has been shortened
# Batch 214 fulltext indices saved!
# Batch 214 fulltext embeddings saved!
# Processing batch 215
# batch 215 has been shortened
# Batch 215 fulltext indices saved!
# Batch 215 fulltext embeddings saved!
# Processing batch 216
# batch 216 has been shortened
# Batch 216 fulltext indices saved!
# Batch 216 fulltext embeddings saved!
# Processing batch 217
# batch 217 has been shortened
# Batch 217 fulltext indices saved!
# Batch 217 fulltext embeddings saved!
# Processing batch 218
# batch 218 has been shortened
# Batch 218 fulltext indices saved!
# Batch 218 fulltext embeddings saved!
# Processing batch 219
# batch 219 has been shortened
# Batch 219 fulltext indices saved!
# Batch 219 fulltext embeddings saved!
# Processing batch 220
# batch 220 has been shortened
# Batch 220 fulltext indices saved!
# Batch 220 fulltext embeddings saved!
# Processing batch 221
# batch 221 has been shortened
# Batch 221 fulltext indices saved!
# Batch 221 fulltext embeddings saved!
# Processing batch 222
# batch 222 has been shortened
# Batch 222 fulltext indices saved!
# Batch 222 fulltext embeddings saved!
# Processing batch 223
# batch 223 has been shortened
# Batch 223 fulltext indices saved!
# Batch 223 fulltext embeddings saved!
# Processing batch 224
# batch 224 has been shortened
# Batch 224 fulltext indices saved!
# Batch 224 fulltext embeddings saved!
# Processing batch 225
# batch 225 has been shortened
# Batch 225 fulltext indices saved!
# Batch 225 fulltext embeddings saved!
# Processing batch 226
# batch 226 has been shortened
# Batch 226 fulltext indices saved!
# Batch 226 fulltext embeddings saved!
# Processing batch 227
# batch 227 has been shortened
# Batch 227 fulltext indices saved!
# Batch 227 fulltext embeddings saved!
# Processing batch 228
# batch 228 has been shortened
# Batch 228 fulltext indices saved!
# Batch 228 fulltext embeddings saved!
# Processing batch 229
# batch 229 has been shortened
# Batch 229 fulltext indices saved!
# Batch 229 fulltext embeddings saved!
# Processing batch 230
# batch 230 has been shortened
# Batch 230 fulltext indices saved!
# Batch 230 fulltext embeddings saved!
# Processing batch 231
# batch 231 has been shortened
# Batch 231 fulltext indices saved!
# Batch 231 fulltext embeddings saved!
# Processing batch 232
# batch 232 has been shortened
# Batch 232 fulltext indices saved!
# Batch 232 fulltext embeddings saved!
# Processing batch 233
# batch 233 has been shortened
# Batch 233 fulltext indices saved!
# Batch 233 fulltext embeddings saved!
# Processing batch 234
# batch 234 has been shortened
# Batch 234 fulltext indices saved!
# Batch 234 fulltext embeddings saved!
# Processing batch 235
# batch 235 has been shortened
# Batch 235 fulltext indices saved!
# Batch 235 fulltext embeddings saved!
# Processing batch 236
# batch 236 has been shortened
# Batch 236 fulltext indices saved!
# Batch 236 fulltext embeddings saved!
# Processing batch 237
# batch 237 has been shortened
# Batch 237 fulltext indices saved!
# Batch 237 fulltext embeddings saved!
# Processing batch 238
# batch 238 has been shortened
# Batch 238 fulltext indices saved!
# Batch 238 fulltext embeddings saved!
# Processing batch 239
# batch 239 has been shortened
# Batch 239 fulltext indices saved!
# Batch 239 fulltext embeddings saved!
# Processing batch 240
# batch 240 has been shortened
# Batch 240 fulltext indices saved!
# Batch 240 fulltext embeddings saved!
# Processing batch 241
# batch 241 has been shortened
# Batch 241 fulltext indices saved!
# Batch 241 fulltext embeddings saved!
# Processing batch 242
# batch 242 has been shortened
# Batch 242 fulltext indices saved!
# Batch 242 fulltext embeddings saved!
# Processing batch 243
# batch 243 has been shortened
# Batch 243 fulltext indices saved!
# Batch 243 fulltext embeddings saved!
# Processing batch 244
# batch 244 has been shortened
# Batch 244 fulltext indices saved!
# Batch 244 fulltext embeddings saved!
# Processing batch 245
# batch 245 has been shortened
# Batch 245 fulltext indices saved!
# Batch 245 fulltext embeddings saved!
# Processing batch 246
# batch 246 has been shortened
# Batch 246 fulltext indices saved!
# Batch 246 fulltext embeddings saved!
# Processing batch 247
# batch 247 has been shortened
# Batch 247 fulltext indices saved!
# Batch 247 fulltext embeddings saved!
# Processing batch 248
# batch 248 has been shortened
# Batch 248 fulltext indices saved!
# Batch 248 fulltext embeddings saved!
# Processing batch 249
# batch 249 has been shortened
# Batch 249 fulltext indices saved!
# Batch 249 fulltext embeddings saved!
# Processing batch 250
# batch 250 has been shortened
# Batch 250 fulltext indices saved!
# Batch 250 fulltext embeddings saved!
# Processing batch 251
# batch 251 has been shortened
# Batch 251 fulltext indices saved!
# Batch 251 fulltext embeddings saved!
# Processing batch 252
# batch 252 has been shortened
# Batch 252 fulltext indices saved!
# Batch 252 fulltext embeddings saved!
# Processing batch 253
# batch 253 has been shortened
# Batch 253 fulltext indices saved!
# Batch 253 fulltext embeddings saved!
# Processing batch 254
# batch 254 has been shortened
# Batch 254 fulltext indices saved!
# Batch 254 fulltext embeddings saved!
# Processing batch 255
# batch 255 has been shortened
# Batch 255 fulltext indices saved!
# Batch 255 fulltext embeddings saved!
# Processing batch 256
# batch 256 has been shortened
# Batch 256 fulltext indices saved!
# Batch 256 fulltext embeddings saved!
# Processing batch 257
# batch 257 has been shortened
# Batch 257 fulltext indices saved!
# Batch 257 fulltext embeddings saved!
# Processing batch 258
# batch 258 has been shortened
# Batch 258 fulltext indices saved!
# Batch 258 fulltext embeddings saved!
# Processing batch 259
# batch 259 has been shortened
# Batch 259 fulltext indices saved!
# Batch 259 fulltext embeddings saved!
# Processing batch 260
# batch 260 has been shortened
# Batch 260 fulltext indices saved!
# Batch 260 fulltext embeddings saved!
# Processing batch 261
# batch 261 has been shortened
# Batch 261 fulltext indices saved!
# Batch 261 fulltext embeddings saved!
# Processing batch 262
# batch 262 has been shortened
# Batch 262 fulltext indices saved!
# Batch 262 fulltext embeddings saved!
# Processing batch 263
# batch 263 has been shortened
# Batch 263 fulltext indices saved!
# Batch 263 fulltext embeddings saved!
# Processing batch 264
# batch 264 has been shortened
# Batch 264 fulltext indices saved!
# Batch 264 fulltext embeddings saved!
# Processing batch 265
# batch 265 has been shortened
# Batch 265 fulltext indices saved!
# Batch 265 fulltext embeddings saved!
# Processing batch 266
# batch 266 has been shortened
# Batch 266 fulltext indices saved!
# Batch 266 fulltext embeddings saved!
# Processing batch 267
# batch 267 has been shortened
# Batch 267 fulltext indices saved!
# Batch 267 fulltext embeddings saved!
# Processing batch 268
# batch 268 has been shortened
# Batch 268 fulltext indices saved!
# Batch 268 fulltext embeddings saved!
# Processing batch 269
# batch 269 has been shortened
# Batch 269 fulltext indices saved!
# Batch 269 fulltext embeddings saved!
# Processing batch 270
# batch 270 has been shortened
# Batch 270 fulltext indices saved!
# Batch 270 fulltext embeddings saved!
# Processing batch 271
# batch 271 has been shortened
# Batch 271 fulltext indices saved!
# Batch 271 fulltext embeddings saved!
# Processing batch 272
# batch 272 has been shortened
# Batch 272 fulltext indices saved!
# Batch 272 fulltext embeddings saved!
# Processing batch 273
# batch 273 has been shortened
# Batch 273 fulltext indices saved!
# Batch 273 fulltext embeddings saved!
# Processing batch 274
# batch 274 has been shortened
# Batch 274 fulltext indices saved!
# Batch 274 fulltext embeddings saved!
# Processing batch 275
# batch 275 has been shortened
# Batch 275 fulltext indices saved!
# Batch 275 fulltext embeddings saved!
# Processing batch 276
# batch 276 has been shortened
# Batch 276 fulltext indices saved!
# Batch 276 fulltext embeddings saved!
# Processing batch 277
# batch 277 has been shortened
# Batch 277 fulltext indices saved!
# Batch 277 fulltext embeddings saved!
# Processing batch 278
# batch 278 has been shortened
# Batch 278 fulltext indices saved!
# Batch 278 fulltext embeddings saved!
# Processing batch 279
# batch 279 has been shortened
# Batch 279 fulltext indices saved!
# Batch 279 fulltext embeddings saved!
# Processing batch 280
# batch 280 has been shortened
# Batch 280 fulltext indices saved!
# Batch 280 fulltext embeddings saved!
# Processing batch 281
# batch 281 has been shortened
# Batch 281 fulltext indices saved!
# Batch 281 fulltext embeddings saved!
# Processing batch 282
# batch 282 has been shortened
# Batch 282 fulltext indices saved!
# Batch 282 fulltext embeddings saved!
# Processing batch 283
# batch 283 has been shortened
# Batch 283 fulltext indices saved!
# Batch 283 fulltext embeddings saved!
# Processing batch 284
# batch 284 has been shortened
# Batch 284 fulltext indices saved!
# Batch 284 fulltext embeddings saved!
# Processing batch 285
# batch 285 has been shortened
# Batch 285 fulltext indices saved!
# Batch 285 fulltext embeddings saved!
# Processing batch 286
# batch 286 has been shortened
# Batch 286 fulltext indices saved!
# Batch 286 fulltext embeddings saved!
# Processing batch 287
# batch 287 has been shortened
# Batch 287 fulltext indices saved!
# Batch 287 fulltext embeddings saved!
# Processing batch 288
# batch 288 has been shortened
# Batch 288 fulltext indices saved!
# Batch 288 fulltext embeddings saved!
# Processing batch 289
# batch 289 has been shortened
# Batch 289 fulltext indices saved!
# Batch 289 fulltext embeddings saved!
# Processing batch 290
# batch 290 has been shortened
# Batch 290 fulltext indices saved!
# Batch 290 fulltext embeddings saved!
# Processing batch 291
# batch 291 has been shortened
# Batch 291 fulltext indices saved!
# Batch 291 fulltext embeddings saved!
# Processing batch 292
# batch 292 has been shortened
# Batch 292 fulltext indices saved!
# Batch 292 fulltext embeddings saved!
# Processing batch 293
# batch 293 has been shortened
# Batch 293 fulltext indices saved!
# Batch 293 fulltext embeddings saved!
# Processing batch 294
# batch 294 has been shortened
# Batch 294 fulltext indices saved!
# Batch 294 fulltext embeddings saved!
# Processing batch 295
# batch 295 has been shortened
# Batch 295 fulltext indices saved!
# Batch 295 fulltext embeddings saved!
# Processing batch 296
# batch 296 has been shortened
# Batch 296 fulltext indices saved!
# Batch 296 fulltext embeddings saved!
# Processing batch 297
# batch 297 has been shortened
# Batch 297 fulltext indices saved!
# Batch 297 fulltext embeddings saved!
# Processing batch 298
# batch 298 has been shortened
# Batch 298 fulltext indices saved!
# Batch 298 fulltext embeddings saved!
# Processing batch 299
# batch 299 has been shortened
# Batch 299 fulltext indices saved!
# Batch 299 fulltext embeddings saved!
# Processing batch 300
# batch 300 has been shortened
# Batch 300 fulltext indices saved!
# Batch 300 fulltext embeddings saved!
# Processing batch 301
# batch 301 has been shortened
# Batch 301 fulltext indices saved!
# Batch 301 fulltext embeddings saved!
# Processing batch 302
# batch 302 has been shortened
# Batch 302 fulltext indices saved!
# Batch 302 fulltext embeddings saved!
# Processing batch 303
# batch 303 has been shortened
# Batch 303 fulltext indices saved!
# Batch 303 fulltext embeddings saved!
# Processing batch 304
# batch 304 has been shortened
# Batch 304 fulltext indices saved!
# Batch 304 fulltext embeddings saved!
# Processing batch 305
# batch 305 has been shortened
# Batch 305 fulltext indices saved!
# Batch 305 fulltext embeddings saved!
# Processing batch 306
# batch 306 has been shortened
# Batch 306 fulltext indices saved!
# Batch 306 fulltext embeddings saved!
# Processing batch 307
# batch 307 has been shortened
# Batch 307 fulltext indices saved!
# Batch 307 fulltext embeddings saved!
# Processing batch 308
# batch 308 has been shortened
# Batch 308 fulltext indices saved!
# Batch 308 fulltext embeddings saved!
# Processing batch 309
# batch 309 has been shortened
# Batch 309 fulltext indices saved!
# Batch 309 fulltext embeddings saved!
# Processing batch 310
# batch 310 has been shortened
# Batch 310 fulltext indices saved!
# Batch 310 fulltext embeddings saved!
# Processing batch 311
# batch 311 has been shortened
# Batch 311 fulltext indices saved!
# Batch 311 fulltext embeddings saved!
# Processing batch 312
# batch 312 has been shortened
# Batch 312 fulltext indices saved!
# Batch 312 fulltext embeddings saved!
# Processing batch 313
# batch 313 has been shortened
# Batch 313 fulltext indices saved!
# Batch 313 fulltext embeddings saved!
# Processing batch 314
# batch 314 has been shortened
# Batch 314 fulltext indices saved!
# Batch 314 fulltext embeddings saved!
# Processing batch 315
# batch 315 has been shortened
# Batch 315 fulltext indices saved!
# Batch 315 fulltext embeddings saved!
# Processing batch 316
# batch 316 has been shortened
# Batch 316 fulltext indices saved!
# Batch 316 fulltext embeddings saved!
# Processing batch 317
# batch 317 has been shortened
# Batch 317 fulltext indices saved!
# Batch 317 fulltext embeddings saved!
# Processing batch 318
# batch 318 has been shortened
# Batch 318 fulltext indices saved!
# Batch 318 fulltext embeddings saved!
# Processing batch 319
# batch 319 has been shortened
# Batch 319 fulltext indices saved!
# Batch 319 fulltext embeddings saved!
# Processing batch 320
# batch 320 has been shortened
# Batch 320 fulltext indices saved!
# Batch 320 fulltext embeddings saved!
# Processing batch 321
# batch 321 has been shortened
# Batch 321 fulltext indices saved!
# Batch 321 fulltext embeddings saved!
# Processing batch 322
# batch 322 has been shortened
# Batch 322 fulltext indices saved!
# Batch 322 fulltext embeddings saved!
# Processing batch 323
# batch 323 has been shortened
# Batch 323 fulltext indices saved!
# Batch 323 fulltext embeddings saved!
# Processing batch 324
# batch 324 has been shortened
# Batch 324 fulltext indices saved!
# Batch 324 fulltext embeddings saved!
# Processing batch 325
# batch 325 has been shortened
# Batch 325 fulltext indices saved!
# Batch 325 fulltext embeddings saved!
# Processing batch 326
# batch 326 has been shortened
# Batch 326 fulltext indices saved!
# Batch 326 fulltext embeddings saved!
# Processing batch 327
# batch 327 has been shortened
# Batch 327 fulltext indices saved!
# Batch 327 fulltext embeddings saved!
# Processing batch 328
# batch 328 has been shortened
# Batch 328 fulltext indices saved!
# Batch 328 fulltext embeddings saved!
# Processing batch 329
# batch 329 has been shortened
# Batch 329 fulltext indices saved!
# Batch 329 fulltext embeddings saved!
# Processing batch 330
# batch 330 has been shortened
# Batch 330 fulltext indices saved!
# Batch 330 fulltext embeddings saved!
# Processing batch 331
# batch 331 has been shortened
# Batch 331 fulltext indices saved!
# Batch 331 fulltext embeddings saved!
# Processing batch 332
# batch 332 has been shortened
# Batch 332 fulltext indices saved!
# Batch 332 fulltext embeddings saved!
# Processing batch 333
# batch 333 has been shortened
# Batch 333 fulltext indices saved!
# Batch 333 fulltext embeddings saved!
# Processing batch 334
# batch 334 has been shortened
# Batch 334 fulltext indices saved!
# Batch 334 fulltext embeddings saved!
# Processing batch 335
# batch 335 has been shortened
# Batch 335 fulltext indices saved!
# Batch 335 fulltext embeddings saved!
# Processing batch 336
# batch 336 has been shortened
# Batch 336 fulltext indices saved!
# Batch 336 fulltext embeddings saved!
# Processing batch 337
# batch 337 has been shortened
# Batch 337 fulltext indices saved!
# Batch 337 fulltext embeddings saved!
# Processing batch 338
# batch 338 has been shortened
# Batch 338 fulltext indices saved!
# Batch 338 fulltext embeddings saved!
# Processing batch 339
# batch 339 has been shortened
# Batch 339 fulltext indices saved!
# Batch 339 fulltext embeddings saved!
# Processing batch 340
# batch 340 has been shortened
# Batch 340 fulltext indices saved!
# Batch 340 fulltext embeddings saved!
# Processing batch 341
# batch 341 has been shortened
# Batch 341 fulltext indices saved!
# Batch 341 fulltext embeddings saved!
# Processing batch 342
# batch 342 has been shortened
# Batch 342 fulltext indices saved!
# Batch 342 fulltext embeddings saved!
# Processing batch 343
# batch 343 has been shortened
# Batch 343 fulltext indices saved!
# Batch 343 fulltext embeddings saved!
# Processing batch 344
# batch 344 has been shortened
# Batch 344 fulltext indices saved!
# Batch 344 fulltext embeddings saved!
# Processing batch 345
# batch 345 has been shortened
# Batch 345 fulltext indices saved!
# Batch 345 fulltext embeddings saved!
# Processing batch 346
# batch 346 has been shortened
# Batch 346 fulltext indices saved!
# Batch 346 fulltext embeddings saved!
# Processing batch 347
# batch 347 has been shortened
# Batch 347 fulltext indices saved!
# Batch 347 fulltext embeddings saved!
# Processing batch 348
# batch 348 has been shortened
# Batch 348 fulltext indices saved!
# Batch 348 fulltext embeddings saved!
# Processing batch 349
# batch 349 has been shortened
# Batch 349 fulltext indices saved!
# Batch 349 fulltext embeddings saved!
# Processing batch 350
# batch 350 has been shortened
# Batch 350 fulltext indices saved!
# Batch 350 fulltext embeddings saved!
# Processing batch 351
# batch 351 has been shortened
# Batch 351 fulltext indices saved!
# Batch 351 fulltext embeddings saved!
# Processing batch 352
# batch 352 has been shortened
# Batch 352 fulltext indices saved!
# Batch 352 fulltext embeddings saved!
# Processing batch 353
# batch 353 has been shortened
# Batch 353 fulltext indices saved!
# Batch 353 fulltext embeddings saved!
# Processing batch 354
# batch 354 has been shortened
# Batch 354 fulltext indices saved!
# Batch 354 fulltext embeddings saved!
# Processing batch 355
# batch 355 has been shortened
# Batch 355 fulltext indices saved!
# Batch 355 fulltext embeddings saved!
# Processing batch 356
# batch 356 has been shortened
# Batch 356 fulltext indices saved!
# Batch 356 fulltext embeddings saved!
# Processing batch 357
# batch 357 has been shortened
# Batch 357 fulltext indices saved!
# Batch 357 fulltext embeddings saved!
# Processing batch 358
# batch 358 has been shortened
# Batch 358 fulltext indices saved!
# Batch 358 fulltext embeddings saved!
# Processing batch 359
# batch 359 has been shortened
# Batch 359 fulltext indices saved!
# Batch 359 fulltext embeddings saved!
# Processing batch 360
# batch 360 has been shortened
# Batch 360 fulltext indices saved!
# Batch 360 fulltext embeddings saved!
# Processing batch 361
# batch 361 has been shortened
# Batch 361 fulltext indices saved!
# Batch 361 fulltext embeddings saved!
# Processing batch 362
# batch 362 has been shortened
# Batch 362 fulltext indices saved!
# Batch 362 fulltext embeddings saved!
# Processing batch 363
# batch 363 has been shortened
# Batch 363 fulltext indices saved!
# Batch 363 fulltext embeddings saved!
# Processing batch 364
# batch 364 has been shortened
# Batch 364 fulltext indices saved!
# Batch 364 fulltext embeddings saved!
# Processing batch 365
# batch 365 has been shortened
# Batch 365 fulltext indices saved!
# Batch 365 fulltext embeddings saved!
# Processing batch 366
# batch 366 has been shortened
# Batch 366 fulltext indices saved!
# Batch 366 fulltext embeddings saved!
# Processing batch 367
# batch 367 has been shortened
# Batch 367 fulltext indices saved!
# Batch 367 fulltext embeddings saved!
# Processing batch 368
# batch 368 has been shortened
# Batch 368 fulltext indices saved!
# Batch 368 fulltext embeddings saved!
# Processing batch 369
# batch 369 has been shortened
# Batch 369 fulltext indices saved!
# Batch 369 fulltext embeddings saved!
# Processing batch 370
# batch 370 has been shortened
# Batch 370 fulltext indices saved!
# Batch 370 fulltext embeddings saved!
# Processing batch 371
# batch 371 has been shortened
# Batch 371 fulltext indices saved!
# Batch 371 fulltext embeddings saved!
# Processing batch 372
# batch 372 has been shortened
# Batch 372 fulltext indices saved!
# Batch 372 fulltext embeddings saved!
# Processing batch 373
# batch 373 has been shortened
# Batch 373 fulltext indices saved!
# Batch 373 fulltext embeddings saved!
# Processing batch 374
# batch 374 has been shortened
# Batch 374 fulltext indices saved!
# Batch 374 fulltext embeddings saved!
# Processing batch 375
# batch 375 has been shortened
# Batch 375 fulltext indices saved!
# Batch 375 fulltext embeddings saved!
# Processing batch 376
# batch 376 has been shortened
# Batch 376 fulltext indices saved!
# Batch 376 fulltext embeddings saved!
# Processing batch 377
# batch 377 has been shortened
# Batch 377 fulltext indices saved!
# Batch 377 fulltext embeddings saved!
# Processing batch 378
# batch 378 has been shortened
# Batch 378 fulltext indices saved!
# Batch 378 fulltext embeddings saved!
# Processing batch 379
# batch 379 has been shortened
# Batch 379 fulltext indices saved!
# Batch 379 fulltext embeddings saved!
# Processing batch 380
# batch 380 has been shortened
# Batch 380 fulltext indices saved!
# Batch 380 fulltext embeddings saved!
# Processing batch 381
# batch 381 has been shortened
# Batch 381 fulltext indices saved!
# Batch 381 fulltext embeddings saved!
# Processing batch 382
# batch 382 has been shortened
# Batch 382 fulltext indices saved!
# Batch 382 fulltext embeddings saved!
# Processing batch 383
# batch 383 has been shortened
# Batch 383 fulltext indices saved!
# Batch 383 fulltext embeddings saved!
# Processing batch 384
# batch 384 has been shortened
# Batch 384 fulltext indices saved!
# Batch 384 fulltext embeddings saved!
# Processing batch 385
# batch 385 has been shortened
# Batch 385 fulltext indices saved!
# Batch 385 fulltext embeddings saved!
# Processing batch 386
# batch 386 has been shortened
# Batch 386 fulltext indices saved!
# Batch 386 fulltext embeddings saved!
# Processing batch 387
# batch 387 has been shortened
# Batch 387 fulltext indices saved!
# Batch 387 fulltext embeddings saved!
# Processing batch 388
# batch 388 has been shortened
# Batch 388 fulltext indices saved!
# Batch 388 fulltext embeddings saved!
# Processing batch 389
# batch 389 has been shortened
# Batch 389 fulltext indices saved!
# Batch 389 fulltext embeddings saved!
# Processing batch 390
# batch 390 has been shortened
# Batch 390 fulltext indices saved!
# Batch 390 fulltext embeddings saved!
# Processing batch 391
# batch 391 has been shortened
# Batch 391 fulltext indices saved!
# Batch 391 fulltext embeddings saved!
# Processing batch 392
# batch 392 has been shortened
# Batch 392 fulltext indices saved!
# Batch 392 fulltext embeddings saved!
# Processing batch 393
# batch 393 has been shortened
# Batch 393 fulltext indices saved!
# Batch 393 fulltext embeddings saved!
# Processing batch 394
# batch 394 has been shortened
# Batch 394 fulltext indices saved!
# Batch 394 fulltext embeddings saved!
# Processing batch 395
# batch 395 has been shortened
# Batch 395 fulltext indices saved!
# Batch 395 fulltext embeddings saved!
# Processing batch 396
# batch 396 has been shortened
# Batch 396 fulltext indices saved!
# Batch 396 fulltext embeddings saved!
# Processing batch 397
# batch 397 has been shortened
# Batch 397 fulltext indices saved!
# Batch 397 fulltext embeddings saved!
# Processing batch 398
# batch 398 has been shortened
# Batch 398 fulltext indices saved!
# Batch 398 fulltext embeddings saved!
# Processing batch 399
# batch 399 has been shortened
# Batch 399 fulltext indices saved!
# Batch 399 fulltext embeddings saved!
# Processing batch 400
# ...
# Processing batch 617
# batch 617 has been shortened
# Batch 617 fulltext indices saved!
# Batch 617 fulltext embeddings saved!
# Processing batch 618
# batch 618 has been shortened
# Batch 618 fulltext indices saved!
# Batch 618 fulltext embeddings saved!
# Processing batch 619
# batch 619 has been shortened
# Batch 619 fulltext indices saved!
# Batch 619 fulltext embeddings saved!
# Processing batch 620
# batch 620 has been shortened
# Batch 620 fulltext indices saved!
# Batch 620 fulltext embeddings saved!
# Processing batch 621
# batch 621 has been shortened
# Batch 621 fulltext indices saved!
# Batch 621 fulltext embeddings saved!
# Processing batch 622
# batch 622 has been shortened
# Batch 622 fulltext indices saved!
# Batch 622 fulltext embeddings saved!
# Processing batch 623
# batch 623 has been shortened
# Batch 623 fulltext indices saved!
# Batch 623 fulltext embeddings saved!
# Processing batch 624
# batch 624 has been shortened
# Batch 624 fulltext indices saved!
# Batch 624 fulltext embeddings saved!
# Processing batch 625
# batch 625 has been shortened
# Batch 625 fulltext indices saved!
# Batch 625 fulltext embeddings saved!
# Processing batch 626
# batch 626 has been shortened
# Batch 626 fulltext indices saved!
# Batch 626 fulltext embeddings saved!
# Processing batch 627
# batch 627 has been shortened
# Batch 627 fulltext indices saved!
# Batch 627 fulltext embeddings saved!
# Processing batch 628
# batch 628 has been shortened
# Batch 628 fulltext indices saved!
# Batch 628 fulltext embeddings saved!
# Processing batch 629
# batch 629 has been shortened
# Batch 629 fulltext indices saved!
# Batch 629 fulltext embeddings saved!
# Processing batch 630
# batch 630 has been shortened
# Batch 630 fulltext indices saved!
# Batch 630 fulltext embeddings saved!
# Processing batch 631
# batch 631 has been shortened
# Batch 631 fulltext indices saved!
# Batch 631 fulltext embeddings saved!
# Processing batch 632
# batch 632 has been shortened
# Batch 632 fulltext indices saved!
# Batch 632 fulltext embeddings saved!
# Processing batch 633
# batch 633 has been shortened
# Batch 633 fulltext indices saved!
# Batch 633 fulltext embeddings saved!
# Processing batch 634
# batch 634 has been shortened
# Batch 634 fulltext indices saved!
# Batch 634 fulltext embeddings saved!
# Processing batch 635
# batch 635 has been shortened
# Batch 635 fulltext indices saved!
# Batch 635 fulltext embeddings saved!
# Processing batch 636
# batch 636 has been shortened
# Batch 636 fulltext indices saved!
# Batch 636 fulltext embeddings saved!
# Processing batch 637
# batch 637 has been shortened
# Batch 637 fulltext indices saved!
# Batch 637 fulltext embeddings saved!
# Processing batch 638
# batch 638 has been shortened
# Batch 638 fulltext indices saved!
# Batch 638 fulltext embeddings saved!
# Processing batch 639
# batch 639 has been shortened
# Batch 639 fulltext indices saved!
# Batch 639 fulltext embeddings saved!
# Processing batch 640
# batch 640 has been shortened
# Batch 640 fulltext indices saved!
# Batch 640 fulltext embeddings saved!
# Processing batch 641
# batch 641 has been shortened
# Batch 641 fulltext indices saved!
# Batch 641 fulltext embeddings saved!
# Processing batch 642
# batch 642 has been shortened
# Batch 642 fulltext indices saved!
# Batch 642 fulltext embeddings saved!
# Processing batch 643
# batch 643 has been shortened
# Batch 643 fulltext indices saved!
# Batch 643 fulltext embeddings saved!
# Processing batch 644
# batch 644 has been shortened
# Batch 644 fulltext indices saved!
# Batch 644 fulltext embeddings saved!
# Processing batch 645
# batch 645 has been shortened
# Batch 645 fulltext indices saved!
# Batch 645 fulltext embeddings saved!
# Processing batch 646
# batch 646 has been shortened
# Batch 646 fulltext indices saved!
# Batch 646 fulltext embeddings saved!
# Processing batch 647
# batch 647 has been shortened
# Batch 647 fulltext indices saved!
# Batch 647 fulltext embeddings saved!
# Processing batch 648
# batch 648 has been shortened
# Batch 648 fulltext indices saved!
# Batch 648 fulltext embeddings saved!
# Processing batch 649
# batch 649 has been shortened
# Batch 649 fulltext indices saved!
# Batch 649 fulltext embeddings saved!
# Processing batch 650
# batch 650 has been shortened
# Batch 650 fulltext indices saved!
# Batch 650 fulltext embeddings saved!
# Processing batch 651
# batch 651 has been shortened
# Batch 651 fulltext indices saved!
# Batch 651 fulltext embeddings saved!
# Processing batch 652
# batch 652 has been shortened
# Batch 652 fulltext indices saved!
# Batch 652 fulltext embeddings saved!
# Processing batch 653
# batch 653 has been shortened
# Batch 653 fulltext indices saved!
# Batch 653 fulltext embeddings saved!
# Processing batch 654
# batch 654 has been shortened
# Batch 654 fulltext indices saved!
# Batch 654 fulltext embeddings saved!
# Processing batch 655
# batch 655 has been shortened
# Batch 655 fulltext indices saved!
# Batch 655 fulltext embeddings saved!
# Processing batch 656
# batch 656 has been shortened
# Batch 656 fulltext indices saved!
# Batch 656 fulltext embeddings saved!
# Processing batch 657
# batch 657 has been shortened
# Batch 657 fulltext indices saved!
# Batch 657 fulltext embeddings saved!
# Processing batch 658
# batch 658 has been shortened
# Batch 658 fulltext indices saved!
# Batch 658 fulltext embeddings saved!
# Processing batch 659
# batch 659 has been shortened
# Batch 659 fulltext indices saved!
# Batch 659 fulltext embeddings saved!
# Processing batch 660
# batch 660 has been shortened
# Batch 660 fulltext indices saved!
# Batch 660 fulltext embeddings saved!
# Processing batch 661
# batch 661 has been shortened
# Batch 661 fulltext indices saved!
# Batch 661 fulltext embeddings saved!
# Processing batch 662
# batch 662 has been shortened
# Batch 662 fulltext indices saved!
# Batch 662 fulltext embeddings saved!
# Processing batch 663
# batch 663 has been shortened
# Batch 663 fulltext indices saved!
# Batch 663 fulltext embeddings saved!
# Processing batch 664
# batch 664 has been shortened
# Batch 664 fulltext indices saved!
# Batch 664 fulltext embeddings saved!
# Processing batch 665
# batch 665 has been shortened
# Batch 665 fulltext indices saved!
# Batch 665 fulltext embeddings saved!
# Processing batch 666
# batch 666 has been shortened
# Batch 666 fulltext indices saved!
# Batch 666 fulltext embeddings saved!
# Processing batch 667
# batch 667 has been shortened
# Batch 667 fulltext indices saved!
# Batch 667 fulltext embeddings saved!
# Processing batch 668
# batch 668 has been shortened
# Batch 668 fulltext indices saved!
# Batch 668 fulltext embeddings saved!
# Processing batch 669
# batch 669 has been shortened
# Batch 669 fulltext indices saved!
# Batch 669 fulltext embeddings saved!
# Processing batch 670
# batch 670 has been shortened
# Batch 670 fulltext indices saved!
# Batch 670 fulltext embeddings saved!
# Processing batch 671
# batch 671 has been shortened
# Batch 671 fulltext indices saved!
# Batch 671 fulltext embeddings saved!
# Processing batch 672
# batch 672 has been shortened
# Batch 672 fulltext indices saved!
# Batch 672 fulltext embeddings saved!
# Processing batch 673
# batch 673 has been shortened
# Batch 673 fulltext indices saved!
# Batch 673 fulltext embeddings saved!
# Processing batch 674
# batch 674 has been shortened
# Batch 674 fulltext indices saved!
# Batch 674 fulltext embeddings saved!
# Processing batch 675
# batch 675 has been shortened
# Batch 675 fulltext indices saved!
# Batch 675 fulltext embeddings saved!
# Processing batch 676
# batch 676 has been shortened
# Batch 676 fulltext indices saved!
# Batch 676 fulltext embeddings saved!
# Processing batch 677
# batch 677 has been shortened
# Batch 677 fulltext indices saved!
# Batch 677 fulltext embeddings saved!
# Processing batch 678
# batch 678 has been shortened
# Batch 678 fulltext indices saved!
# Batch 678 fulltext embeddings saved!
# Processing batch 679
# batch 679 has been shortened
# Batch 679 fulltext indices saved!
# Batch 679 fulltext embeddings saved!
# Processing batch 680
# batch 680 has been shortened
# Batch 680 fulltext indices saved!
# Batch 680 fulltext embeddings saved!
# Processing batch 681
# batch 681 has been shortened
# Batch 681 fulltext indices saved!
# Batch 681 fulltext embeddings saved!
# Processing batch 682
# batch 682 has been shortened
# Batch 682 fulltext indices saved!
# Batch 682 fulltext embeddings saved!
# Processing batch 683
# batch 683 has been shortened
# Batch 683 fulltext indices saved!
# Batch 683 fulltext embeddings saved!
# Processing batch 684
# batch 684 has been shortened
# Batch 684 fulltext indices saved!
# Batch 684 fulltext embeddings saved!
# Processing batch 685
# batch 685 has been shortened
# Batch 685 fulltext indices saved!
# Batch 685 fulltext embeddings saved!
# Processing batch 686
# batch 686 has been shortened
# Batch 686 fulltext indices saved!
# Batch 686 fulltext embeddings saved!
# Processing batch 687
# batch 687 has been shortened
# Batch 687 fulltext indices saved!
# Batch 687 fulltext embeddings saved!
# Processing batch 688
# batch 688 has been shortened
# Batch 688 fulltext indices saved!
# Batch 688 fulltext embeddings saved!
# Processing batch 689
# batch 689 has been shortened
# Batch 689 fulltext indices saved!
# Batch 689 fulltext embeddings saved!
# Processing batch 690
# batch 690 has been shortened
# Batch 690 fulltext indices saved!
# Batch 690 fulltext embeddings saved!
# Processing batch 691
# batch 691 has been shortened
# Batch 691 fulltext indices saved!
# Batch 691 fulltext embeddings saved!
# Processing batch 692
# batch 692 has been shortened
# Batch 692 fulltext indices saved!
# Batch 692 fulltext embeddings saved!
# Processing batch 693
# batch 693 has been shortened
# Batch 693 fulltext indices saved!
# Batch 693 fulltext embeddings saved!
# Processing batch 694
# batch 694 has been shortened
# Batch 694 fulltext indices saved!
# Batch 694 fulltext embeddings saved!
# Processing batch 695
# batch 695 has been shortened
# Batch 695 fulltext indices saved!
# Batch 695 fulltext embeddings saved!
# Processing batch 696
# batch 696 has been shortened
# Batch 696 fulltext indices saved!
# Batch 696 fulltext embeddings saved!
# Processing batch 697
# batch 697 has been shortened
# Batch 697 fulltext indices saved!
# Batch 697 fulltext embeddings saved!
# Processing batch 698
# batch 698 has been shortened
# Batch 698 fulltext indices saved!
# Batch 698 fulltext embeddings saved!
# Processing batch 699
# batch 699 has been shortened
# Batch 699 fulltext indices saved!
# Batch 699 fulltext embeddings saved!
# Processing batch 700
# batch 700 has been shortened
# Batch 700 fulltext indices saved!
# Batch 700 fulltext embeddings saved!
# Processing batch 701
# batch 701 has been shortened
# Batch 701 fulltext indices saved!
# Batch 701 fulltext embeddings saved!
# Processing batch 702
# batch 702 has been shortened
# Batch 702 fulltext indices saved!
# Batch 702 fulltext embeddings saved!
# Processing batch 703
# batch 703 has been shortened
# Batch 703 fulltext indices saved!
# Batch 703 fulltext embeddings saved!
# Processing batch 704
# batch 704 has been shortened
# Batch 704 fulltext indices saved!
# Batch 704 fulltext embeddings saved!
# Processing batch 705
# batch 705 has been shortened
# Batch 705 fulltext indices saved!
# Batch 705 fulltext embeddings saved!
# Processing batch 706
# batch 706 has been shortened
# Batch 706 fulltext indices saved!
# Batch 706 fulltext embeddings saved!
# Processing batch 707
# batch 707 has been shortened
# Batch 707 fulltext indices saved!
# Batch 707 fulltext embeddings saved!
# Processing batch 708
# batch 708 has been shortened
# Batch 708 fulltext indices saved!
# Batch 708 fulltext embeddings saved!
# Processing batch 709
# batch 709 has been shortened
# Batch 709 fulltext indices saved!
# Batch 709 fulltext embeddings saved!
# Processing batch 710
# batch 710 has been shortened
# Batch 710 fulltext indices saved!
# Batch 710 fulltext embeddings saved!
# Processing batch 711
# batch 711 has been shortened
# Batch 711 fulltext indices saved!
# Batch 711 fulltext embeddings saved!
# Processing batch 712
# batch 712 has been shortened
# Batch 712 fulltext indices saved!
# Batch 712 fulltext embeddings saved!
# Processing batch 713
# batch 713 has been shortened
# Batch 713 fulltext indices saved!
# Batch 713 fulltext embeddings saved!
# Processing batch 714
# batch 714 has been shortened
# Batch 714 fulltext indices saved!
# Batch 714 fulltext embeddings saved!
# Processing batch 715
# batch 715 has been shortened
# Batch 715 fulltext indices saved!
# Batch 715 fulltext embeddings saved!
# Processing batch 716
# batch 716 has been shortened
# Batch 716 fulltext indices saved!
# Batch 716 fulltext embeddings saved!
# Processing batch 717
# batch 717 has been shortened
# Batch 717 fulltext indices saved!
# Batch 717 fulltext embeddings saved!
# Processing batch 718
# batch 718 has been shortened
# Batch 718 fulltext indices saved!
# Batch 718 fulltext embeddings saved!
# Processing batch 719
# batch 719 has been shortened
# Batch 719 fulltext indices saved!
# Batch 719 fulltext embeddings saved!
# Processing batch 720
# batch 720 has been shortened
# Batch 720 fulltext indices saved!
# Batch 720 fulltext embeddings saved!
# Processing batch 721
# batch 721 has been shortened
# Batch 721 fulltext indices saved!
# Batch 721 fulltext embeddings saved!
# Processing batch 722
# batch 722 has been shortened
# Batch 722 fulltext indices saved!
# Batch 722 fulltext embeddings saved!
# Processing batch 723
# batch 723 has been shortened
# Batch 723 fulltext indices saved!
# Batch 723 fulltext embeddings saved!
# Processing batch 724
# batch 724 has been shortened
# Batch 724 fulltext indices saved!
# Batch 724 fulltext embeddings saved!
# Processing batch 725
# batch 725 has been shortened
# Batch 725 fulltext indices saved!
# Batch 725 fulltext embeddings saved!
# Processing batch 726
# batch 726 has been shortened
# Batch 726 fulltext indices saved!
# Batch 726 fulltext embeddings saved!
# Processing batch 727
# batch 727 has been shortened
# Batch 727 fulltext indices saved!
# Batch 727 fulltext embeddings saved!
# Processing batch 728
# batch 728 has been shortened
# Batch 728 fulltext indices saved!
# Batch 728 fulltext embeddings saved!
# Processing batch 729
# batch 729 has been shortened
# Batch 729 fulltext indices saved!
# Batch 729 fulltext embeddings saved!
# Processing batch 730
# batch 730 has been shortened
# Batch 730 fulltext indices saved!
# Batch 730 fulltext embeddings saved!
# Processing batch 731
# batch 731 has been shortened
# Batch 731 fulltext indices saved!
# Batch 731 fulltext embeddings saved!
# Processing batch 732
# batch 732 has been shortened
# Batch 732 fulltext indices saved!
# Batch 732 fulltext embeddings saved!
# Processing batch 733
# batch 733 has been shortened
# Batch 733 fulltext indices saved!
# Batch 733 fulltext embeddings saved!
# Processing batch 734
# batch 734 has been shortened
# Batch 734 fulltext indices saved!
# Batch 734 fulltext embeddings saved!
# Processing batch 735
# batch 735 has been shortened
# Batch 735 fulltext indices saved!
# Batch 735 fulltext embeddings saved!
# Processing batch 736
# batch 736 has been shortened
# Batch 736 fulltext indices saved!
# Batch 736 fulltext embeddings saved!
# Processing batch 737
# batch 737 has been shortened
# Batch 737 fulltext indices saved!
# Batch 737 fulltext embeddings saved!
# Processing batch 738
# batch 738 has been shortened
# Batch 738 fulltext indices saved!
# Batch 738 fulltext embeddings saved!
# Processing batch 739
# batch 739 has been shortened
# Batch 739 fulltext indices saved!
# Batch 739 fulltext embeddings saved!
# Processing batch 740
# batch 740 has been shortened
# Batch 740 fulltext indices saved!
# Batch 740 fulltext embeddings saved!
# Processing batch 741
# batch 741 has been shortened
# Batch 741 fulltext indices saved!
# Batch 741 fulltext embeddings saved!
# Processing batch 742
# batch 742 has been shortened
# Batch 742 fulltext indices saved!
# Batch 742 fulltext embeddings saved!
# Processing batch 743
# batch 743 has been shortened
# Batch 743 fulltext indices saved!
# Batch 743 fulltext embeddings saved!
# Processing batch 744
# batch 744 has been shortened
# Batch 744 fulltext indices saved!
# Batch 744 fulltext embeddings saved!
# Processing batch 745
# batch 745 has been shortened
# Batch 745 fulltext indices saved!
# Batch 745 fulltext embeddings saved!
# Processing batch 746
# batch 746 has been shortened
# Batch 746 fulltext indices saved!
# Batch 746 fulltext embeddings saved!
# Processing batch 747
# batch 747 has been shortened
# Batch 747 fulltext indices saved!
# Batch 747 fulltext embeddings saved!
# Processing batch 748
# batch 748 has been shortened
# Batch 748 fulltext indices saved!
# Batch 748 fulltext embeddings saved!
# Processing batch 749

# %%
# Reconstruct array of all embeddings
directory_base = "/content/drive/MyDrive/batched_titleabstracts_fulltext"
all_embeddings_fulltext = []
for batch in os.listdir(directory_base):
  batch_filename = os.path.join(directory_base, batch)
  batch_embeddings = np.load(batch_filename)
  all_embeddings_fulltext.append(batch_embeddings)
combined_embeddings_fulltext = np.vstack(all_embeddings_fulltext)
print(combined_embeddings_fulltext.shape)
# Out:
# (40, 1024)

# %%
# Reconstrct array of all indices
directory_base = "/content/drive/MyDrive/batched_indices_fulltext"
all_indices_fulltext = []
for batch in os.listdir(directory_base):
  batch_filename = os.path.join(directory_base,batch)
  with open(batch_filename, "r") as index_reader:
    all_indices_fulltext.extend(index_reader.read().splitlines())
print(all_indices_fulltext)
# Out:
# ['18455542', '18450819', '18449539', '18448333', '18448309', '18447597', '18445212', '18366835', '18363819', '18362329', '18357389', '18356841', '18356348', '18356234', '18355973', '18355950', '18355404', '18352276', '18351949', '18350953', '18350866', '18349919', '18349077', '18347545', '18346847', '18346241', '18346114', '18346036', '18345897', '18343265', '18342480', '18341234', '18340909', '18340576', '18339256', '18339186', '18339125', '18337840', '18337482', '18337439']

# %%
k = 5
for ind in top_k_similar_patent_indices('18363819', all_indices, combined_embeddings, k):
  print(ind_to_text(ind))
# Out:
# BATTERY, POWER CONSUMING APPARATUS, AND METHOD AND APPARATUS FOR MANUFACTURING BATTERY
# Provided are a battery, comprising: a battery cell group comprising N battery cell rows arranged in a first direction, battery cells in each battery cell row being arranged in a second direction, the first direction being perpendicular to the second direction; a signal transmission assembly provided on the first face of the battery cell group and comprising a busbar component and an insulation layer, the busbar component being configured to be electrically connected to the battery cells at holes of the insulation layer; and a cooling system provided between two adjacent battery cell rows in the N battery cell rows, with a blocking member being provided at an opening, facing the first face, of a gap between the two adjacent battery cell rows to block the opening to prevent condensed liquid generated by the cooling system from reaching the busbar component.
#
# BATTERY UNIT, BATTERY, AND ELECTRIC APPARATUS
# This application discloses a battery unit. The battery unit includes a housing, at least one cell, and a buffer. The at least one cell is accommodated in the housing, the buffer is disposed corresponding to a side wall of the cell, and the buffer is provided with an accommodating cavity. A periphery of the accommodating cavity includes at least one packaging structure, the packaging structure includes at least one level of packaging region with a predetermined length. When pressure in the accommodating cavity exceeds packaging strength of the packaging structure, the packaging region is opened to form a buffer space that communicates with the accommodating cavity, reducing influence caused by swelling of the cell.
#
# FOLDING CHAIR FRAMEWORK
# The present disclosure relates to a folding chair framework, including a connecting seat, a guide rod, a guide sleeve, several chair legs, several supporting rods, several connecting rods, a first spring, a second spring, and wedge-shaped blocks; upper ends of the chair legs are all hinged with the connecting seat; the guide rod is vertically arranged and connected to the connecting seat; the guide sleeve is slidably connected to the guide rod; each connecting rod is hinged with the guide sleeve and one chair leg respectively; upper and lower ends of the first spring are respectively connected to the connecting seat and the guide sleeve; the wedge-shaped blocks are slidably connected into first grooves of the guide rod; two ends of the second spring are respectively connected to the first grooves and the wedge-shaped blocks; the guide sleeve includes an inner sleeve and an outer sleeve.
#
# PORTABLE SIMULATED FLOOD DISCHARGE CULVERT FOR SURVEYING AND MAPPING
# Provided is a portable simulated flood discharge culvert for surveying and mapping, including a supporting device, where the supporting device includes a plurality of telescopic support rods, and the telescopic support rods; a tarpaulin, where the tarpaulin is cover on outer walls of the telescopic support rods; connecting devices, where each of the connecting devices is installed between any two adjacent telescopic support rods; floors, where the floors are respectively arranged between the plurality of telescopic support rods, and top surfaces of the floors are provided with a plurality of protrusions; adjusting devices, where each of the adjusting devices includes angle adjusting mechanisms and a height adjusting mechanism, and the angle adjusting mechanisms and the height adjusting mechanism are respectively fixed on a bottom surface of each of the floors; a fog generating device, a lighting part, and additional blocks.
#
# COATING APPARATUS AND COATING SYSTEM
# Provided are a coating apparatus and a coating system, where the coating apparatus includes: a coating module, the coating module including a coating roller and a coating die, where the coating roller is configured to drive, when rotating, a substrate to move toward the coating die, and the coating die is configured to apply a coating onto the substrate; an error acquisition module having a predetermined distance to the coating roller and configured to acquire a circular run-out error of rotation of the coating roller and transmit the circular run-out error to a linkage module; and the linkage module configured to adjust position of the coating die in real time according to the circular run-out error transmitted to the linkage module, so as to keep a distance between the coating roller and the coating die unchanged.

# %%
def combine_titleabstract_fulltext(abstracttitles, fulltexts, ATtoFtRatio = 1):
  abstracttitles_normalized = abstracttitles / np.linalg.norm(abstracttitles, axis=1, keepdims=True)
  fulltexts_normalized = fulltexts / np.linalg.norm(fulltexts, axis = 1, keepdims = True)
  combined_array = np.concatenate((abstracttitles_normalized*ATtoFtRatio, fulltexts_normalized), axis=1)
  return combined_array

# %%
k = 5
ATFtcombined = combine_titleabstract_fulltext(combined_embeddings, combined_embeddings_fulltext)
for ind in top_k_similar_patent_indices('18363819', all_indices, ATFtcombined, k):
  print(ind_to_text(ind))
# Out:
# BATTERY, POWER CONSUMING APPARATUS, AND METHOD AND APPARATUS FOR MANUFACTURING BATTERY
# Provided are a battery, comprising: a battery cell group comprising N battery cell rows arranged in a first direction, battery cells in each battery cell row being arranged in a second direction, the first direction being perpendicular to the second direction; a signal transmission assembly provided on the first face of the battery cell group and comprising a busbar component and an insulation layer, the busbar component being configured to be electrically connected to the battery cells at holes of the insulation layer; and a cooling system provided between two adjacent battery cell rows in the N battery cell rows, with a blocking member being provided at an opening, facing the first face, of a gap between the two adjacent battery cell rows to block the opening to prevent condensed liquid generated by the cooling system from reaching the busbar component.
#
# COATING APPARATUS AND COATING SYSTEM
# Provided are a coating apparatus and a coating system, where the coating apparatus includes: a coating module, the coating module including a coating roller and a coating die, where the coating roller is configured to drive, when rotating, a substrate to move toward the coating die, and the coating die is configured to apply a coating onto the substrate; an error acquisition module having a predetermined distance to the coating roller and configured to acquire a circular run-out error of rotation of the coating roller and transmit the circular run-out error to a linkage module; and the linkage module configured to adjust position of the coating die in real time according to the circular run-out error transmitted to the linkage module, so as to keep a distance between the coating roller and the coating die unchanged.
#
# QUICK-DETACHABLE CONNECTING DEVICE WITH SIMPLIFIED THREAD STRUCTURE AND CONNECTION METHOD USING SAME
# A quick-detachable connecting device with a simplified thread structure includes a top nozzle, a connecting tube sleeve, a locking tube and a locking piece. The top nozzle is provided with a through hole, in which the connecting tube sleeve is assembled. The locking tube is accommodated in the through hole. An outer peripheral surface of the locking tube is provided with a second stopping structure, and an inner peripheral surface of the connecting tube sleeve is provided with a first stopping structure fitting the second stopping structure. The locking piece is movably arranged on the locking tube for circumferentially limiting or releasing the locking tube. A connection method using such connecting device is also provided.
#
# BATTERY UNIT, BATTERY, AND ELECTRIC APPARATUS
# This application discloses a battery unit. The battery unit includes a housing, at least one cell, and a buffer. The at least one cell is accommodated in the housing, the buffer is disposed corresponding to a side wall of the cell, and the buffer is provided with an accommodating cavity. A periphery of the accommodating cavity includes at least one packaging structure, the packaging structure includes at least one level of packaging region with a predetermined length. When pressure in the accommodating cavity exceeds packaging strength of the packaging structure, the packaging region is opened to form a buffer space that communicates with the accommodating cavity, reducing influence caused by swelling of the cell.
#
# PORTABLE SIMULATED FLOOD DISCHARGE CULVERT FOR SURVEYING AND MAPPING
# Provided is a portable simulated flood discharge culvert for surveying and mapping, including a supporting device, where the supporting device includes a plurality of telescopic support rods, and the telescopic support rods; a tarpaulin, where the tarpaulin is cover on outer walls of the telescopic support rods; connecting devices, where each of the connecting devices is installed between any two adjacent telescopic support rods; floors, where the floors are respectively arranged between the plurality of telescopic support rods, and top surfaces of the floors are provided with a plurality of protrusions; adjusting devices, where each of the adjusting devices includes angle adjusting mechanisms and a height adjusting mechanism, and the angle adjusting mechanisms and the height adjusting mechanism are respectively fixed on a bottom surface of each of the floors; a fog generating device, a lighting part, and additional blocks.

# %%
os.mkdir(f"/content/drive/MyDrive/batched_indices_fulltext1_trunc")
os.mkdir(f"/content/drive/MyDrive/batched_titleabstracts_fulltext1_trunc")

# %%
# Encode the description texts batch by batch and save them
for batch_ind, textinfo in enumerate(fulltextloader(10)):
  print(f"Processing batch {batch_ind}")
  id_set, texts = textinfo

  new_texts = texts
  new_texts_shortened = [truncate_to_512_tokens(text) for text in new_texts]
  print(f"batch {batch_ind} has been shortened")

  # Extract features for each text
  features = feature_extracter(new_texts_shortened)
  squeezed_features = [np.squeeze(np.array(feats), axis=0) for feats in features]

  # Aggregate token embeddings (e.g., using the mean)
  aggregated_features = [np.mean(np.array(feats), axis=0) for feats in squeezed_features]

  # Save indices
  with open(f"/content/drive/MyDrive/batched_indices_fulltext1_trunc/batch_{batch_ind}.txt", "w") as f:
    f.write("\n".join(id_set))
  print(f"Batch {batch_ind} fulltext indices saved!")

  # Save embeded titleabstracts
  directory_embedding = os.path.join("/content/drive/MyDrive/batched_titleabstracts_fulltext1_trunc", f"batch_{batch_ind}.npy")
  np.save(directory_embedding, aggregated_features)
  print(f"Batch {batch_ind} fulltext embeddings saved!")
# Out:
# Processing batch 0
# batch 0 has been shortened
# Batch 0 fulltext indices saved!
# Batch 0 fulltext embeddings saved!
# Processing batch 1
# batch 1 has been shortened
# Batch 1 fulltext indices saved!
# Batch 1 fulltext embeddings saved!
# Processing batch 2
# batch 2 has been shortened
# Batch 2 fulltext indices saved!
# Batch 2 fulltext embeddings saved!
# Processing batch 3
# batch 3 has been shortened
# Batch 3 fulltext indices saved!
# Batch 3 fulltext embeddings saved!
# Processing batch 4
# batch 4 has been shortened
# Batch 4 fulltext indices saved!
# Batch 4 fulltext embeddings saved!
# Processing batch 5
# batch 5 has been shortened
# Batch 5 fulltext indices saved!
# Batch 5 fulltext embeddings saved!
# Processing batch 6
# batch 6 has been shortened
# Batch 6 fulltext indices saved!
# Batch 6 fulltext embeddings saved!
# Processing batch 7
# batch 7 has been shortened
# Batch 7 fulltext indices saved!
# Batch 7 fulltext embeddings saved!
# Processing batch 8
# batch 8 has been shortened
# Batch 8 fulltext indices saved!
# Batch 8 fulltext embeddings saved!
# Processing batch 9
# batch 9 has been shortened
# Batch 9 fulltext indices saved!
# Batch 9 fulltext embeddings saved!
# Processing batch 10
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# batch 10 has been shortened
# Batch 10 fulltext indices saved!
# Batch 10 fulltext embeddings saved!
# Processing batch 11
# batch 11 has been shortened
# Batch 11 fulltext indices saved!
# Batch 11 fulltext embeddings saved!
# Processing batch 12
# batch 12 has been shortened
# Batch 12 fulltext indices saved!
# Batch 12 fulltext embeddings saved!
# Processing batch 13
# batch 13 has been shortened
# Batch 13 fulltext indices saved!
# Batch 13 fulltext embeddings saved!
# Processing batch 14
# batch 14 has been shortened
# Batch 14 fulltext indices saved!
# Batch 14 fulltext embeddings saved!
# Processing batch 15
# batch 15 has been shortened
# Batch 15 fulltext indices saved!
# Batch 15 fulltext embeddings saved!
# Processing batch 16
# batch 16 has been shortened
# Batch 16 fulltext indices saved!
# Batch 16 fulltext embeddings saved!
# Processing batch 17
# batch 17 has been shortened
# Batch 17 fulltext indices saved!
# Batch 17 fulltext embeddings saved!
# Processing batch 18
# batch 18 has been shortened
# Batch 18 fulltext indices saved!
# Batch 18 fulltext embeddings saved!
# Processing batch 19
# batch 19 has been shortened
# Batch 19 fulltext indices saved!
# Batch 19 fulltext embeddings saved!
# Processing batch 20
# batch 20 has been shortened
# Batch 20 fulltext indices saved!
# Batch 20 fulltext embeddings saved!
# Processing batch 21
# batch 21 has been shortened
# Batch 21 fulltext indices saved!
# Batch 21 fulltext embeddings saved!
# Processing batch 22
# batch 22 has been shortened
# Batch 22 fulltext indices saved!
# Batch 22 fulltext embeddings saved!
# Processing batch 23
# batch 23 has been shortened
# Batch 23 fulltext indices saved!
# Batch 23 fulltext embeddings saved!
# Processing batch 24
# batch 24 has been shortened
# Batch 24 fulltext indices saved!
# Batch 24 fulltext embeddings saved!
# Processing batch 25
# batch 25 has been shortened
# Batch 25 fulltext indices saved!
# Batch 25 fulltext embeddings saved!
# Processing batch 26
# batch 26 has been shortened
# Batch 26 fulltext indices saved!
# Batch 26 fulltext embeddings saved!
# Processing batch 27
# batch 27 has been shortened
# Batch 27 fulltext indices saved!
# Batch 27 fulltext embeddings saved!
# Processing batch 28
# batch 28 has been shortened
# Batch 28 fulltext indices saved!
# Batch 28 fulltext embeddings saved!
# Processing batch 29
# batch 29 has been shortened
# Batch 29 fulltext indices saved!
# Batch 29 fulltext embeddings saved!
# Processing batch 30
# batch 30 has been shortened
# Batch 30 fulltext indices saved!
# Batch 30 fulltext embeddings saved!
# Processing batch 31
# batch 31 has been shortened
# Batch 31 fulltext indices saved!
# Batch 31 fulltext embeddings saved!
# Processing batch 32
# batch 32 has been shortened
# Batch 32 fulltext indices saved!
# Batch 32 fulltext embeddings saved!
# Processing batch 33
# batch 33 has been shortened
# Batch 33 fulltext indices saved!
# Batch 33 fulltext embeddings saved!
# Processing batch 34
# batch 34 has been shortened
# Batch 34 fulltext indices saved!
# Batch 34 fulltext embeddings saved!
# Processing batch 35
# batch 35 has been shortened
# Batch 35 fulltext indices saved!
# Batch 35 fulltext embeddings saved!
# Processing batch 36
# batch 36 has been shortened
# Batch 36 fulltext indices saved!
# Batch 36 fulltext embeddings saved!
# Processing batch 37
# batch 37 has been shortened
# Batch 37 fulltext indices saved!
# Batch 37 fulltext embeddings saved!
# Processing batch 38
# batch 38 has been shortened
# Batch 38 fulltext indices saved!
# Batch 38 fulltext embeddings saved!
# Processing batch 39
# batch 39 has been shortened
# Batch 39 fulltext indices saved!
# Batch 39 fulltext embeddings saved!
# Processing batch 40
# batch 40 has been shortened
# Batch 40 fulltext indices saved!
# Batch 40 fulltext embeddings saved!
# Processing batch 41
# batch 41 has been shortened
# Batch 41 fulltext indices saved!
# Batch 41 fulltext embeddings saved!
# Processing batch 42
# batch 42 has been shortened
# Batch 42 fulltext indices saved!
# Batch 42 fulltext embeddings saved!
# Processing batch 43
# batch 43 has been shortened
# Batch 43 fulltext indices saved!
# Batch 43 fulltext embeddings saved!
# Processing batch 44
# batch 44 has been shortened
# Batch 44 fulltext indices saved!
# Batch 44 fulltext embeddings saved!
# Processing batch 45
# batch 45 has been shortened
# Batch 45 fulltext indices saved!
# Batch 45 fulltext embeddings saved!
# Processing batch 46
# batch 46 has been shortened
# Batch 46 fulltext indices saved!
# Batch 46 fulltext embeddings saved!
# Processing batch 47
# batch 47 has been shortened
# Batch 47 fulltext indices saved!
# Batch 47 fulltext embeddings saved!
# Processing batch 48
# batch 48 has been shortened
# Batch 48 fulltext indices saved!
# Batch 48 fulltext embeddings saved!
# Processing batch 49
# batch 49 has been shortened
# Batch 49 fulltext indices saved!
# Batch 49 fulltext embeddings saved!
# Processing batch 50
# batch 50 has been shortened
# Batch 50 fulltext indices saved!
# Batch 50 fulltext embeddings saved!
# Processing batch 51
# batch 51 has been shortened
# Batch 51 fulltext indices saved!
# Batch 51 fulltext embeddings saved!
# Processing batch 52
# batch 52 has been shortened
# Batch 52 fulltext indices saved!
# Batch 52 fulltext embeddings saved!
# Processing batch 53
# batch 53 has been shortened
# Batch 53 fulltext indices saved!
# Batch 53 fulltext embeddings saved!
# Processing batch 54
# batch 54 has been shortened
# Batch 54 fulltext indices saved!
# Batch 54 fulltext embeddings saved!
# Processing batch 55
# batch 55 has been shortened
# Batch 55 fulltext indices saved!
# Batch 55 fulltext embeddings saved!
# Processing batch 56
# batch 56 has been shortened
# Batch 56 fulltext indices saved!
# Batch 56 fulltext embeddings saved!
# Processing batch 57
# batch 57 has been shortened
# Batch 57 fulltext indices saved!
# Batch 57 fulltext embeddings saved!
# Processing batch 58
# batch 58 has been shortened
# Batch 58 fulltext indices saved!
# Batch 58 fulltext embeddings saved!
# Processing batch 59
# batch 59 has been shortened
# Batch 59 fulltext indices saved!
# Batch 59 fulltext embeddings saved!
# Processing batch 60
# batch 60 has been shortened
# Batch 60 fulltext indices saved!
# Batch 60 fulltext embeddings saved!
# Processing batch 61
# batch 61 has been shortened
# Batch 61 fulltext indices saved!
# Batch 61 fulltext embeddings saved!
# Processing batch 62
# batch 62 has been shortened
# Batch 62 fulltext indices saved!
# Batch 62 fulltext embeddings saved!
# Processing batch 63
# batch 63 has been shortened
# Batch 63 fulltext indices saved!
# Batch 63 fulltext embeddings saved!
# Processing batch 64
# batch 64 has been shortened
# Batch 64 fulltext indices saved!
# Batch 64 fulltext embeddings saved!
# Processing batch 65
# batch 65 has been shortened
# Batch 65 fulltext indices saved!
# Batch 65 fulltext embeddings saved!
# Processing batch 66
# batch 66 has been shortened
# Batch 66 fulltext indices saved!
# Batch 66 fulltext embeddings saved!
# Processing batch 67
# batch 67 has been shortened
# Batch 67 fulltext indices saved!
# Batch 67 fulltext embeddings saved!
# Processing batch 68
# batch 68 has been shortened
# Batch 68 fulltext indices saved!
# Batch 68 fulltext embeddings saved!
# Processing batch 69
# batch 69 has been shortened
# Batch 69 fulltext indices saved!
# Batch 69 fulltext embeddings saved!
# Processing batch 70
# batch 70 has been shortened
# Batch 70 fulltext indices saved!
# Batch 70 fulltext embeddings saved!
# Processing batch 71
# batch 71 has been shortened
# Batch 71 fulltext indices saved!
# Batch 71 fulltext embeddings saved!
# Processing batch 72
# batch 72 has been shortened
# Batch 72 fulltext indices saved!
# Batch 72 fulltext embeddings saved!
# Processing batch 73
# batch 73 has been shortened
# Batch 73 fulltext indices saved!
# Batch 73 fulltext embeddings saved!
# Processing batch 74
# batch 74 has been shortened
# Batch 74 fulltext indices saved!
# Batch 74 fulltext embeddings saved!
# Processing batch 75
# batch 75 has been shortened
# Batch 75 fulltext indices saved!
# Batch 75 fulltext embeddings saved!
# Processing batch 76
# batch 76 has been shortened
# Batch 76 fulltext indices saved!
# Batch 76 fulltext embeddings saved!
# Processing batch 77
# batch 77 has been shortened
# Batch 77 fulltext indices saved!
# Batch 77 fulltext embeddings saved!
# Processing batch 78
# batch 78 has been shortened
# Batch 78 fulltext indices saved!
# Batch 78 fulltext embeddings saved!
# Processing batch 79
# batch 79 has been shortened
# Batch 79 fulltext indices saved!
# Batch 79 fulltext embeddings saved!
# Processing batch 80
# batch 80 has been shortened
# Batch 80 fulltext indices saved!
# Batch 80 fulltext embeddings saved!
# Processing batch 81
# batch 81 has been shortened
# Batch 81 fulltext indices saved!
# Batch 81 fulltext embeddings saved!
# Processing batch 82
# batch 82 has been shortened
# Batch 82 fulltext indices saved!
# Batch 82 fulltext embeddings saved!
# Processing batch 83
# batch 83 has been shortened
# Batch 83 fulltext indices saved!
# Batch 83 fulltext embeddings saved!
# Processing batch 84
# batch 84 has been shortened
# Batch 84 fulltext indices saved!
# Batch 84 fulltext embeddings saved!
# Processing batch 85
# batch 85 has been shortened
# Batch 85 fulltext indices saved!
# Batch 85 fulltext embeddings saved!
# Processing batch 86
# batch 86 has been shortened
# Batch 86 fulltext indices saved!
# Batch 86 fulltext embeddings saved!
# Processing batch 87
# batch 87 has been shortened
# Batch 87 fulltext indices saved!
# Batch 87 fulltext embeddings saved!
# Processing batch 88
# batch 88 has been shortened
# Batch 88 fulltext indices saved!
# Batch 88 fulltext embeddings saved!
# Processing batch 89
# batch 89 has been shortened
# Batch 89 fulltext indices saved!
# Batch 89 fulltext embeddings saved!
# Processing batch 90
# batch 90 has been shortened
# Batch 90 fulltext indices saved!
# Batch 90 fulltext embeddings saved!
# Processing batch 91
# batch 91 has been shortened
# Batch 91 fulltext indices saved!
# Batch 91 fulltext embeddings saved!
# Processing batch 92
# batch 92 has been shortened
# Batch 92 fulltext indices saved!
# Batch 92 fulltext embeddings saved!
# Processing batch 93
# batch 93 has been shortened
# Batch 93 fulltext indices saved!
# Batch 93 fulltext embeddings saved!
# Processing batch 94
# batch 94 has been shortened
# Batch 94 fulltext indices saved!
# Batch 94 fulltext embeddings saved!
# Processing batch 95
# batch 95 has been shortened
# Batch 95 fulltext indices saved!
# Batch 95 fulltext embeddings saved!
# Processing batch 96
# batch 96 has been shortened
# Batch 96 fulltext indices saved!
# Batch 96 fulltext embeddings saved!
# Processing batch 97
# batch 97 has been shortened
# Batch 97 fulltext indices saved!
# Batch 97 fulltext embeddings saved!
# Processing batch 98
# batch 98 has been shortened
# Batch 98 fulltext indices saved!
# Batch 98 fulltext embeddings saved!
# Processing batch 99
# batch 99 has been shortened
# Batch 99 fulltext indices saved!
# Batch 99 fulltext embeddings saved!
# Processing batch 100
# batch 100 has been shortened
# Batch 100 fulltext indices saved!
# Batch 100 fulltext embeddings saved!
# Processing batch 101
# batch 101 has been shortened
# Batch 101 fulltext indices saved!
# Batch 101 fulltext embeddings saved!
# Processing batch 102
# batch 102 has been shortened
# Batch 102 fulltext indices saved!
# Batch 102 fulltext embeddings saved!
# Processing batch 103
# batch 103 has been shortened
# Batch 103 fulltext indices saved!
# Batch 103 fulltext embeddings saved!
# Processing batch 104
# batch 104 has been shortened
# Batch 104 fulltext indices saved!
# Batch 104 fulltext embeddings saved!
# Processing batch 105
# batch 105 has been shortened
# Batch 105 fulltext indices saved!
# Batch 105 fulltext embeddings saved!
# Processing batch 106
# batch 106 has been shortened
# Batch 106 fulltext indices saved!
# Batch 106 fulltext embeddings saved!
# Processing batch 107
# batch 107 has been shortened
# Batch 107 fulltext indices saved!
# Batch 107 fulltext embeddings saved!
# Processing batch 108
# batch 108 has been shortened
# Batch 108 fulltext indices saved!
# Batch 108 fulltext embeddings saved!
# Processing batch 109
# batch 109 has been shortened
# Batch 109 fulltext indices saved!
# Batch 109 fulltext embeddings saved!
# Processing batch 110
# batch 110 has been shortened
# Batch 110 fulltext indices saved!
# Batch 110 fulltext embeddings saved!
# Processing batch 111
# batch 111 has been shortened
# Batch 111 fulltext indices saved!
# Batch 111 fulltext embeddings saved!
# Processing batch 112
# batch 112 has been shortened
# Batch 112 fulltext indices saved!
# Batch 112 fulltext embeddings saved!
# Processing batch 113
# batch 113 has been shortened
# Batch 113 fulltext indices saved!
# Batch 113 fulltext embeddings saved!
# Processing batch 114
# batch 114 has been shortened
# Batch 114 fulltext indices saved!
# Batch 114 fulltext embeddings saved!
# Processing batch 115
# batch 115 has been shortened
# Batch 115 fulltext indices saved!
# Batch 115 fulltext embeddings saved!
# Processing batch 116
# batch 116 has been shortened
# Batch 116 fulltext indices saved!
# Batch 116 fulltext embeddings saved!
# Processing batch 117
# batch 117 has been shortened
# Batch 117 fulltext indices saved!
# Batch 117 fulltext embeddings saved!
# Processing batch 118
# batch 118 has been shortened
# Batch 118 fulltext indices saved!
# Batch 118 fulltext embeddings saved!
# Processing batch 119
# batch 119 has been shortened
# Batch 119 fulltext indices saved!
# Batch 119 fulltext embeddings saved!
# Processing batch 120
# batch 120 has been shortened
# Batch 120 fulltext indices saved!
# Batch 120 fulltext embeddings saved!
# Processing batch 121
# batch 121 has been shortened
# Batch 121 fulltext indices saved!
# Batch 121 fulltext embeddings saved!
# Processing batch 122
# batch 122 has been shortened
# Batch 122 fulltext indices saved!
# Batch 122 fulltext embeddings saved!
# Processing batch 123
# batch 123 has been shortened
# Batch 123 fulltext indices saved!
# Batch 123 fulltext embeddings saved!
# Processing batch 124
# batch 124 has been shortened
# Batch 124 fulltext indices saved!
# Batch 124 fulltext embeddings saved!
# Processing batch 125
# batch 125 has been shortened
# Batch 125 fulltext indices saved!
# Batch 125 fulltext embeddings saved!
# Processing batch 126
# batch 126 has been shortened
# Batch 126 fulltext indices saved!
# Batch 126 fulltext embeddings saved!
# Processing batch 127
# batch 127 has been shortened
# Batch 127 fulltext indices saved!
# Batch 127 fulltext embeddings saved!
# Processing batch 128
# batch 128 has been shortened
# Batch 128 fulltext indices saved!
# Batch 128 fulltext embeddings saved!
# Processing batch 129
# batch 129 has been shortened
# Batch 129 fulltext indices saved!
# Batch 129 fulltext embeddings saved!
# Processing batch 130
# batch 130 has been shortened
# Batch 130 fulltext indices saved!
# Batch 130 fulltext embeddings saved!
# Processing batch 131
# batch 131 has been shortened
# Batch 131 fulltext indices saved!
# Batch 131 fulltext embeddings saved!
# Processing batch 132
# batch 132 has been shortened
# Batch 132 fulltext indices saved!
# Batch 132 fulltext embeddings saved!
# Processing batch 133
# batch 133 has been shortened
# Batch 133 fulltext indices saved!
# Batch 133 fulltext embeddings saved!
# Processing batch 134
# batch 134 has been shortened
# Batch 134 fulltext indices saved!
# Batch 134 fulltext embeddings saved!
# Processing batch 135
# batch 135 has been shortened
# Batch 135 fulltext indices saved!
# Batch 135 fulltext embeddings saved!
# Processing batch 136
# batch 136 has been shortened
# Batch 136 fulltext indices saved!
# Batch 136 fulltext embeddings saved!
# Processing batch 137
# batch 137 has been shortened
# Batch 137 fulltext indices saved!
# Batch 137 fulltext embeddings saved!
# Processing batch 138
# batch 138 has been shortened
# Batch 138 fulltext indices saved!
# Batch 138 fulltext embeddings saved!
# Processing batch 139
# batch 139 has been shortened
# Batch 139 fulltext indices saved!
# Batch 139 fulltext embeddings saved!
# Processing batch 140
# batch 140 has been shortened
# Batch 140 fulltext indices saved!
# Batch 140 fulltext embeddings saved!
# Processing batch 141
# batch 141 has been shortened
# Batch 141 fulltext indices saved!
# Batch 141 fulltext embeddings saved!
# Processing batch 142
# batch 142 has been shortened
# Batch 142 fulltext indices saved!
# Batch 142 fulltext embeddings saved!
# Processing batch 143
# batch 143 has been shortened
# Batch 143 fulltext indices saved!
# Batch 143 fulltext embeddings saved!
# Processing batch 144
# batch 144 has been shortened
# Batch 144 fulltext indices saved!
# Batch 144 fulltext embeddings saved!
# Processing batch 145
# batch 145 has been shortened
# Batch 145 fulltext indices saved!
# Batch 145 fulltext embeddings saved!
# Processing batch 146
# batch 146 has been shortened
# Batch 146 fulltext indices saved!
# Batch 146 fulltext embeddings saved!
# Processing batch 147
# batch 147 has been shortened
# Batch 147 fulltext indices saved!
# Batch 147 fulltext embeddings saved!
# Processing batch 148
# batch 148 has been shortened
# Batch 148 fulltext indices saved!
# Batch 148 fulltext embeddings saved!
# Processing batch 149
# batch 149 has been shortened
# Batch 149 fulltext indices saved!
# Batch 149 fulltext embeddings saved!
# Processing batch 150
# batch 150 has been shortened
# Batch 150 fulltext indices saved!
# Batch 150 fulltext embeddings saved!
# Processing batch 151
# batch 151 has been shortened
# Batch 151 fulltext indices saved!
# Batch 151 fulltext embeddings saved!
# Processing batch 152
# batch 152 has been shortened
# Batch 152 fulltext indices saved!
# Batch 152 fulltext embeddings saved!
# Processing batch 153
# batch 153 has been shortened
# Batch 153 fulltext indices saved!
# Batch 153 fulltext embeddings saved!
# Processing batch 154
# batch 154 has been shortened
# Batch 154 fulltext indices saved!
# Batch 154 fulltext embeddings saved!
# Processing batch 155
# batch 155 has been shortened
# Batch 155 fulltext indices saved!
# Batch 155 fulltext embeddings saved!
# Processing batch 156
# batch 156 has been shortened
# Batch 156 fulltext indices saved!
# Batch 156 fulltext embeddings saved!
# Processing batch 157
# batch 157 has been shortened
# Batch 157 fulltext indices saved!
# Batch 157 fulltext embeddings saved!
# Processing batch 158
# batch 158 has been shortened
# Batch 158 fulltext indices saved!
# Batch 158 fulltext embeddings saved!
# Processing batch 159
# batch 159 has been shortened
# Batch 159 fulltext indices saved!
# Batch 159 fulltext embeddings saved!
# Processing batch 160
# batch 160 has been shortened
# Batch 160 fulltext indices saved!
# Batch 160 fulltext embeddings saved!
# Processing batch 161
# batch 161 has been shortened
# Batch 161 fulltext indices saved!
# Batch 161 fulltext embeddings saved!
# Processing batch 162
# batch 162 has been shortened
# Batch 162 fulltext indices saved!
# Batch 162 fulltext embeddings saved!
# Processing batch 163
# batch 163 has been shortened
# Batch 163 fulltext indices saved!
# Batch 163 fulltext embeddings saved!
# Processing batch 164
# batch 164 has been shortened
# Batch 164 fulltext indices saved!
# Batch 164 fulltext embeddings saved!
# Processing batch 165
# batch 165 has been shortened
# Batch 165 fulltext indices saved!
# Batch 165 fulltext embeddings saved!
# Processing batch 166
# batch 166 has been shortened
# Batch 166 fulltext indices saved!
# Batch 166 fulltext embeddings saved!
# Processing batch 167
# batch 167 has been shortened
# Batch 167 fulltext indices saved!
# Batch 167 fulltext embeddings saved!
# Processing batch 168
# batch 168 has been shortened
# Batch 168 fulltext indices saved!
# Batch 168 fulltext embeddings saved!
# Processing batch 169
# batch 169 has been shortened
# Batch 169 fulltext indices saved!
# Batch 169 fulltext embeddings saved!
# Processing batch 170
# batch 170 has been shortened
# Batch 170 fulltext indices saved!
# Batch 170 fulltext embeddings saved!
# Processing batch 171
# batch 171 has been shortened
# Batch 171 fulltext indices saved!
# Batch 171 fulltext embeddings saved!
# Processing batch 172
# batch 172 has been shortened
# Batch 172 fulltext indices saved!
# Batch 172 fulltext embeddings saved!
# Processing batch 173
# batch 173 has been shortened
# Batch 173 fulltext indices saved!
# Batch 173 fulltext embeddings saved!
# Processing batch 174
# batch 174 has been shortened
# Batch 174 fulltext indices saved!
# Batch 174 fulltext embeddings saved!
# Processing batch 175
# batch 175 has been shortened
# Batch 175 fulltext indices saved!
# Batch 175 fulltext embeddings saved!
# Processing batch 176
# batch 176 has been shortened
# Batch 176 fulltext indices saved!
# Batch 176 fulltext embeddings saved!
# Processing batch 177
# batch 177 has been shortened
# Batch 177 fulltext indices saved!
# Batch 177 fulltext embeddings saved!
# Processing batch 178
# batch 178 has been shortened
# Batch 178 fulltext indices saved!
# Batch 178 fulltext embeddings saved!
# Processing batch 179
# batch 179 has been shortened
# Batch 179 fulltext indices saved!
# Batch 179 fulltext embeddings saved!
# Processing batch 180
# batch 180 has been shortened
# Batch 180 fulltext indices saved!
# Batch 180 fulltext embeddings saved!
# Processing batch 181
# batch 181 has been shortened
# Batch 181 fulltext indices saved!
# Batch 181 fulltext embeddings saved!
# Processing batch 182
# batch 182 has been shortened
# Batch 182 fulltext indices saved!
# Batch 182 fulltext embeddings saved!
# Processing batch 183
# batch 183 has been shortened
# Batch 183 fulltext indices saved!
# Batch 183 fulltext embeddings saved!
# Processing batch 184
# batch 184 has been shortened
# Batch 184 fulltext indices saved!
# Batch 184 fulltext embeddings saved!
# Processing batch 185
# batch 185 has been shortened
# Batch 185 fulltext indices saved!
# Batch 185 fulltext embeddings saved!
# Processing batch 186
# batch 186 has been shortened
# Batch 186 fulltext indices saved!
# Batch 186 fulltext embeddings saved!
# Processing batch 187
# batch 187 has been shortened
# Batch 187 fulltext indices saved!
# Batch 187 fulltext embeddings saved!
# Processing batch 188
# batch 188 has been shortened
# Batch 188 fulltext indices saved!
# Batch 188 fulltext embeddings saved!
# Processing batch 189
# batch 189 has been shortened
# Batch 189 fulltext indices saved!
# Batch 189 fulltext embeddings saved!
# Processing batch 190
# batch 190 has been shortened
# Batch 190 fulltext indices saved!
# Batch 190 fulltext embeddings saved!
# Processing batch 191
# batch 191 has been shortened
# Batch 191 fulltext indices saved!
# Batch 191 fulltext embeddings saved!
# Processing batch 192
# batch 192 has been shortened
# Batch 192 fulltext indices saved!
# Batch 192 fulltext embeddings saved!
# Processing batch 193
# batch 193 has been shortened
# Batch 193 fulltext indices saved!
# Batch 193 fulltext embeddings saved!
# Processing batch 194
# batch 194 has been shortened
# Batch 194 fulltext indices saved!
# Batch 194 fulltext embeddings saved!
# Processing batch 195
# batch 195 has been shortened
# Batch 195 fulltext indices saved!
# Batch 195 fulltext embeddings saved!
# Processing batch 196
# batch 196 has been shortened
# Batch 196 fulltext indices saved!
# Batch 196 fulltext embeddings saved!
# Processing batch 197
# batch 197 has been shortened
# Batch 197 fulltext indices saved!
# Batch 197 fulltext embeddings saved!
# Processing batch 198
# batch 198 has been shortened
# Batch 198 fulltext indices saved!
# Batch 198 fulltext embeddings saved!
# Processing batch 199
# batch 199 has been shortened
# Batch 199 fulltext indices saved!
# Batch 199 fulltext embeddings saved!
# Processing batch 200
# batch 200 has been shortened
# Batch 200 fulltext indices saved!
# Batch 200 fulltext embeddings saved!
# Processing batch 201
# batch 201 has been shortened
# Batch 201 fulltext indices saved!
# Batch 201 fulltext embeddings saved!
# Processing batch 202
# batch 202 has been shortened
# Batch 202 fulltext indices saved!
# Batch 202 fulltext embeddings saved!
# Processing batch 203
# batch 203 has been shortened
# Batch 203 fulltext indices saved!
# Batch 203 fulltext embeddings saved!
# Processing batch 204
# batch 204 has been shortened
# Batch 204 fulltext indices saved!
# Batch 204 fulltext embeddings saved!
# Processing batch 205
# batch 205 has been shortened
# Batch 205 fulltext indices saved!
# Batch 205 fulltext embeddings saved!
# Processing batch 206
# batch 206 has been shortened
# Batch 206 fulltext indices saved!
# Batch 206 fulltext embeddings saved!
# Processing batch 207
# batch 207 has been shortened
# Batch 207 fulltext indices saved!
# Batch 207 fulltext embeddings saved!
# Processing batch 208
# batch 208 has been shortened
# Batch 208 fulltext indices saved!
# Batch 208 fulltext embeddings saved!
# Processing batch 209
# batch 209 has been shortened
# Batch 209 fulltext indices saved!
# Batch 209 fulltext embeddings saved!
# Processing batch 210
# batch 210 has been shortened
# Batch 210 fulltext indices saved!
# Batch 210 fulltext embeddings saved!
# Processing batch 211
# batch 211 has been shortened
# Batch 211 fulltext indices saved!
# Batch 211 fulltext embeddings saved!
# Processing batch 212
# batch 212 has been shortened
# Batch 212 fulltext indices saved!
# Batch 212 fulltext embeddings saved!
# Processing batch 213
# batch 213 has been shortened
# Batch 213 fulltext indices saved!
# Batch 213 fulltext embeddings saved!
# Processing batch 214
# batch 214 has been shortened
# Batch 214 fulltext indices saved!
# Batch 214 fulltext embeddings saved!
# Processing batch 215
# batch 215 has been shortened
# Batch 215 fulltext indices saved!
# Batch 215 fulltext embeddings saved!
# Processing batch 216
# batch 216 has been shortened
# Batch 216 fulltext indices saved!
# Batch 216 fulltext embeddings saved!
# Processing batch 217
# batch 217 has been shortened
# Batch 217 fulltext indices saved!
# Batch 217 fulltext embeddings saved!
# Processing batch 218
# batch 218 has been shortened
# Batch 218 fulltext indices saved!
# Batch 218 fulltext embeddings saved!
# Processing batch 219
# batch 219 has been shortened
# Batch 219 fulltext indices saved!
# Batch 219 fulltext embeddings saved!
# Processing batch 220
# batch 220 has been shortened
# Batch 220 fulltext indices saved!
# Batch 220 fulltext embeddings saved!
# Processing batch 221
# batch 221 has been shortened
# Batch 221 fulltext indices saved!
# Batch 221 fulltext embeddings saved!
# Processing batch 222
# batch 222 has been shortened
# Batch 222 fulltext indices saved!
# Batch 222 fulltext embeddings saved!
# Processing batch 223
# batch 223 has been shortened
# Batch 223 fulltext indices saved!
# Batch 223 fulltext embeddings saved!
# Processing batch 224
# batch 224 has been shortened
# Batch 224 fulltext indices saved!
# Batch 224 fulltext embeddings saved!
# Processing batch 225
# batch 225 has been shortened
# Batch 225 fulltext indices saved!
# Batch 225 fulltext embeddings saved!
# Processing batch 226
# batch 226 has been shortened
# Batch 226 fulltext indices saved!
# Batch 226 fulltext embeddings saved!
# Processing batch 227
# batch 227 has been shortened
# Batch 227 fulltext indices saved!
# Batch 227 fulltext embeddings saved!
# Processing batch 228
# batch 228 has been shortened
# Batch 228 fulltext indices saved!
# Batch 228 fulltext embeddings saved!
# Processing batch 229
# batch 229 has been shortened
# Batch 229 fulltext indices saved!
# Batch 229 fulltext embeddings saved!
# Processing batch 230
# batch 230 has been shortened
# Batch 230 fulltext indices saved!
# Batch 230 fulltext embeddings saved!
# Processing batch 231
# batch 231 has been shortened
# Batch 231 fulltext indices saved!
# Batch 231 fulltext embeddings saved!
# Processing batch 232
# batch 232 has been shortened
# Batch 232 fulltext indices saved!
# Batch 232 fulltext embeddings saved!
# Processing batch 233
# batch 233 has been shortened
# Batch 233 fulltext indices saved!
# Batch 233 fulltext embeddings saved!
# Processing batch 234
# batch 234 has been shortened
# Batch 234 fulltext indices saved!
# Batch 234 fulltext embeddings saved!
# Processing batch 235
# batch 235 has been shortened
# Batch 235 fulltext indices saved!
# Batch 235 fulltext embeddings saved!
# Processing batch 236
# batch 236 has been shortened
# Batch 236 fulltext indices saved!
# Batch 236 fulltext embeddings saved!
# Processing batch 237
# batch 237 has been shortened
# Batch 237 fulltext indices saved!
# Batch 237 fulltext embeddings saved!
# Processing batch 238
# batch 238 has been shortened
# Batch 238 fulltext indices saved!
# Batch 238 fulltext embeddings saved!
# Processing batch 239
# batch 239 has been shortened
# Batch 239 fulltext indices saved!
# Batch 239 fulltext embeddings saved!
# Processing batch 240
# batch 240 has been shortened
# Batch 240 fulltext indices saved!
# Batch 240 fulltext embeddings saved!
# Processing batch 241
# batch 241 has been shortened
# Batch 241 fulltext indices saved!
# Batch 241 fulltext embeddings saved!
# Processing batch 242
# batch 242 has been shortened
# Batch 242 fulltext indices saved!
# Batch 242 fulltext embeddings saved!
# Processing batch 243
# batch 243 has been shortened
# Batch 243 fulltext indices saved!
# Batch 243 fulltext embeddings saved!
# Processing batch 244
# batch 244 has been shortened
# Batch 244 fulltext indices saved!
# Batch 244 fulltext embeddings saved!
# Processing batch 245
# batch 245 has been shortened
# Batch 245 fulltext indices saved!
# Batch 245 fulltext embeddings saved!
# Processing batch 246
# batch 246 has been shortened
# Batch 246 fulltext indices saved!
# Batch 246 fulltext embeddings saved!
# Processing batch 247
# batch 247 has been shortened
# Batch 247 fulltext indices saved!
# Batch 247 fulltext embeddings saved!
# Processing batch 248
# batch 248 has been shortened
# Batch 248 fulltext indices saved!
# Batch 248 fulltext embeddings saved!
# Processing batch 249
# batch 249 has been shortened
# Batch 249 fulltext indices saved!
# Batch 249 fulltext embeddings saved!
# Processing batch 250
# batch 250 has been shortened
# Batch 250 fulltext indices saved!
# Batch 250 fulltext embeddings saved!
# Processing batch 251
# batch 251 has been shortened
# Batch 251 fulltext indices saved!
# Batch 251 fulltext embeddings saved!
# Processing batch 252
# batch 252 has been shortened
# Batch 252 fulltext indices saved!
# Batch 252 fulltext embeddings saved!
# Processing batch 253
# batch 253 has been shortened
# Batch 253 fulltext indices saved!
# Batch 253 fulltext embeddings saved!
# Processing batch 254
# batch 254 has been shortened
# Batch 254 fulltext indices saved!
# Batch 254 fulltext embeddings saved!
# Processing batch 255
# batch 255 has been shortened
# Batch 255 fulltext indices saved!
# Batch 255 fulltext embeddings saved!
# Processing batch 256
# batch 256 has been shortened
# Batch 256 fulltext indices saved!
# Batch 256 fulltext embeddings saved!
# Processing batch 257
# batch 257 has been shortened
# Batch 257 fulltext indices saved!
# Batch 257 fulltext embeddings saved!
# Processing batch 258
# batch 258 has been shortened
# Batch 258 fulltext indices saved!
# Batch 258 fulltext embeddings saved!
# Processing batch 259
# batch 259 has been shortened
# Batch 259 fulltext indices saved!
# Batch 259 fulltext embeddings saved!
# Processing batch 260
# batch 260 has been shortened
# Batch 260 fulltext indices saved!
# Batch 260 fulltext embeddings saved!
# Processing batch 261
# batch 261 has been shortened
# Batch 261 fulltext indices saved!
# Batch 261 fulltext embeddings saved!
# Processing batch 262
# batch 262 has been shortened
# Batch 262 fulltext indices saved!
# Batch 262 fulltext embeddings saved!
# Processing batch 263
# batch 263 has been shortened
# Batch 263 fulltext indices saved!
# Batch 263 fulltext embeddings saved!
# Processing batch 264
# batch 264 has been shortened
# Batch 264 fulltext indices saved!
# Batch 264 fulltext embeddings saved!
# Processing batch 265
# batch 265 has been shortened
# Batch 265 fulltext indices saved!
# Batch 265 fulltext embeddings saved!
# Processing batch 266
# batch 266 has been shortened
# Batch 266 fulltext indices saved!
# Batch 266 fulltext embeddings saved!
# Processing batch 267
# batch 267 has been shortened
# Batch 267 fulltext indices saved!
# Batch 267 fulltext embeddings saved!
# Processing batch 268
# batch 268 has been shortened
# Batch 268 fulltext indices saved!
# Batch 268 fulltext embeddings saved!
# Processing batch 269
# batch 269 has been shortened
# Batch 269 fulltext indices saved!
# Batch 269 fulltext embeddings saved!
# Processing batch 270
# batch 270 has been shortened
# Batch 270 fulltext indices saved!
# Batch 270 fulltext embeddings saved!
# Processing batch 271
# batch 271 has been shortened
# Batch 271 fulltext indices saved!
# Batch 271 fulltext embeddings saved!
# Processing batch 272
# batch 272 has been shortened
# Batch 272 fulltext indices saved!
# Batch 272 fulltext embeddings saved!
# Processing batch 273
# batch 273 has been shortened
# Batch 273 fulltext indices saved!
# Batch 273 fulltext embeddings saved!
# Processing batch 274
# batch 274 has been shortened
# Batch 274 fulltext indices saved!
# Batch 274 fulltext embeddings saved!
# Processing batch 275
# batch 275 has been shortened
# Batch 275 fulltext indices saved!
# Batch 275 fulltext embeddings saved!
# Processing batch 276
# batch 276 has been shortened
# Batch 276 fulltext indices saved!
# Batch 276 fulltext embeddings saved!
# Processing batch 277
# batch 277 has been shortened
# Batch 277 fulltext indices saved!
# Batch 277 fulltext embeddings saved!
# Processing batch 278
# batch 278 has been shortened
# Batch 278 fulltext indices saved!
# Batch 278 fulltext embeddings saved!
# Processing batch 279
# batch 279 has been shortened
# Batch 279 fulltext indices saved!
# Batch 279 fulltext embeddings saved!
# Processing batch 280
# batch 280 has been shortened
# Batch 280 fulltext indices saved!
# Batch 280 fulltext embeddings saved!
# Processing batch 281
# batch 281 has been shortened
# Batch 281 fulltext indices saved!
# Batch 281 fulltext embeddings saved!
# Processing batch 282
# batch 282 has been shortened
# Batch 282 fulltext indices saved!
# Batch 282 fulltext embeddings saved!
# Processing batch 283
# batch 283 has been shortened
# Batch 283 fulltext indices saved!
# Batch 283 fulltext embeddings saved!
# Processing batch 284
# batch 284 has been shortened
# Batch 284 fulltext indices saved!
# Batch 284 fulltext embeddings saved!
# Processing batch 285
# batch 285 has been shortened
# Batch 285 fulltext indices saved!
# Batch 285 fulltext embeddings saved!
# Processing batch 286
# batch 286 has been shortened
# Batch 286 fulltext indices saved!
# Batch 286 fulltext embeddings saved!
# Processing batch 287
# batch 287 has been shortened
# Batch 287 fulltext indices saved!
# Batch 287 fulltext embeddings saved!
# Processing batch 288
# batch 288 has been shortened
# Batch 288 fulltext indices saved!
# Batch 288 fulltext embeddings saved!
# Processing batch 289
# batch 289 has been shortened
# Batch 289 fulltext indices saved!
# Batch 289 fulltext embeddings saved!
# Processing batch 290
# batch 290 has been shortened
# Batch 290 fulltext indices saved!
# Batch 290 fulltext embeddings saved!
# Processing batch 291
# batch 291 has been shortened
# Batch 291 fulltext indices saved!
# Batch 291 fulltext embeddings saved!
# Processing batch 292
# batch 292 has been shortened
# Batch 292 fulltext indices saved!
# Batch 292 fulltext embeddings saved!
# Processing batch 293
# batch 293 has been shortened
# Batch 293 fulltext indices saved!
# Batch 293 fulltext embeddings saved!
# Processing batch 294
# batch 294 has been shortened
# Batch 294 fulltext indices saved!
# Batch 294 fulltext embeddings saved!
# Processing batch 295
# batch 295 has been shortened
# Batch 295 fulltext indices saved!
# Batch 295 fulltext embeddings saved!
# Processing batch 296
# batch 296 has been shortened
# Batch 296 fulltext indices saved!
# Batch 296 fulltext embeddings saved!
# Processing batch 297
# batch 297 has been shortened
# Batch 297 fulltext indices saved!
# Batch 297 fulltext embeddings saved!
# Processing batch 298
# batch 298 has been shortened
# Batch 298 fulltext indices saved!
# Batch 298 fulltext embeddings saved!
# Processing batch 299
# batch 299 has been shortened
# Batch 299 fulltext indices saved!
# Batch 299 fulltext embeddings saved!
# Processing batch 300
# batch 300 has been shortened
# Batch 300 fulltext indices saved!
# Batch 300 fulltext embeddings saved!
# Processing batch 301
# batch 301 has been shortened
# Batch 301 fulltext indices saved!
# Batch 301 fulltext embeddings saved!
# Processing batch 302
# batch 302 has been shortened
# Batch 302 fulltext indices saved!
# Batch 302 fulltext embeddings saved!
# Processing batch 303
# batch 303 has been shortened
# Batch 303 fulltext indices saved!
# Batch 303 fulltext embeddings saved!
# Processing batch 304
# batch 304 has been shortened
# Batch 304 fulltext indices saved!
# Batch 304 fulltext embeddings saved!
# Processing batch 305
# batch 305 has been shortened
# Batch 305 fulltext indices saved!
# Batch 305 fulltext embeddings saved!
# Processing batch 306
# batch 306 has been shortened
# Batch 306 fulltext indices saved!
# Batch 306 fulltext embeddings saved!
# Processing batch 307
# batch 307 has been shortened
# Batch 307 fulltext indices saved!
# Batch 307 fulltext embeddings saved!
# Processing batch 308
# batch 308 has been shortened
# Batch 308 fulltext indices saved!
# Batch 308 fulltext embeddings saved!
# Processing batch 309
# batch 309 has been shortened
# Batch 309 fulltext indices saved!
# Batch 309 fulltext embeddings saved!
# Processing batch 310
# batch 310 has been shortened
# Batch 310 fulltext indices saved!
# Batch 310 fulltext embeddings saved!
# Processing batch 311
# batch 311 has been shortened
# Batch 311 fulltext indices saved!
# Batch 311 fulltext embeddings saved!
# Processing batch 312
# batch 312 has been shortened
# Batch 312 fulltext indices saved!
# Batch 312 fulltext embeddings saved!
# Processing batch 313
# batch 313 has been shortened
# Batch 313 fulltext indices saved!
# Batch 313 fulltext embeddings saved!
# Processing batch 314
# batch 314 has been shortened
# Batch 314 fulltext indices saved!
# Batch 314 fulltext embeddings saved!
# Processing batch 315
# batch 315 has been shortened
# Batch 315 fulltext indices saved!
# Batch 315 fulltext embeddings saved!
# Processing batch 316
# batch 316 has been shortened
# Batch 316 fulltext indices saved!
# Batch 316 fulltext embeddings saved!
# Processing batch 317
# batch 317 has been shortened
# Batch 317 fulltext indices saved!
# Batch 317 fulltext embeddings saved!
# Processing batch 318
# batch 318 has been shortened
# Batch 318 fulltext indices saved!
# Batch 318 fulltext embeddings saved!
# Processing batch 319
# batch 319 has been shortened
# Batch 319 fulltext indices saved!
# Batch 319 fulltext embeddings saved!
# Processing batch 320
# batch 320 has been shortened
# Batch 320 fulltext indices saved!
# Batch 320 fulltext embeddings saved!
# Processing batch 321
# batch 321 has been shortened
# Batch 321 fulltext indices saved!
# Batch 321 fulltext embeddings saved!
# Processing batch 322
# batch 322 has been shortened
# Batch 322 fulltext indices saved!
# Batch 322 fulltext embeddings saved!
# Processing batch 323
# batch 323 has been shortened
# Batch 323 fulltext indices saved!
# Batch 323 fulltext embeddings saved!
# Processing batch 324
# batch 324 has been shortened
# Batch 324 fulltext indices saved!
# Batch 324 fulltext embeddings saved!
# Processing batch 325
# batch 325 has been shortened
# Batch 325 fulltext indices saved!
# Batch 325 fulltext embeddings saved!
# Processing batch 326
# batch 326 has been shortened
# Batch 326 fulltext indices saved!
# Batch 326 fulltext embeddings saved!
# Processing batch 327
# batch 327 has been shortened
# Batch 327 fulltext indices saved!
# Batch 327 fulltext embeddings saved!
# Processing batch 328
# batch 328 has been shortened
# Batch 328 fulltext indices saved!
# Batch 328 fulltext embeddings saved!
# Processing batch 329
# batch 329 has been shortened
# Batch 329 fulltext indices saved!
# Batch 329 fulltext embeddings saved!
# Processing batch 330
# batch 330 has been shortened
# Batch 330 fulltext indices saved!
# Batch 330 fulltext embeddings saved!
# Processing batch 331
# batch 331 has been shortened
# Batch 331 fulltext indices saved!
# Batch 331 fulltext embeddings saved!
# Processing batch 332
# batch 332 has been shortened
# Batch 332 fulltext indices saved!
# Batch 332 fulltext embeddings saved!
# Processing batch 333
# batch 333 has been shortened
# Batch 333 fulltext indices saved!
# Batch 333 fulltext embeddings saved!
# Processing batch 334
# batch 334 has been shortened
# Batch 334 fulltext indices saved!
# Batch 334 fulltext embeddings saved!
# Processing batch 335
# batch 335 has been shortened
# Batch 335 fulltext indices saved!
# Batch 335 fulltext embeddings saved!
# Processing batch 336
# batch 336 has been shortened
# Batch 336 fulltext indices saved!
# Batch 336 fulltext embeddings saved!
# Processing batch 337
# batch 337 has been shortened
# Batch 337 fulltext indices saved!
# Batch 337 fulltext embeddings saved!
# Processing batch 338
# batch 338 has been shortened
# Batch 338 fulltext indices saved!
# Batch 338 fulltext embeddings saved!
# Processing batch 339
# batch 339 has been shortened
# Batch 339 fulltext indices saved!
# Batch 339 fulltext embeddings saved!
# Processing batch 340
# batch 340 has been shortened
# Batch 340 fulltext indices saved!
# Batch 340 fulltext embeddings saved!
# Processing batch 341
# batch 341 has been shortened
# Batch 341 fulltext indices saved!
# Batch 341 fulltext embeddings saved!
# Processing batch 342
# batch 342 has been shortened
# Batch 342 fulltext indices saved!
# Batch 342 fulltext embeddings saved!
# Processing batch 343
# batch 343 has been shortened
# Batch 343 fulltext indices saved!
# Batch 343 fulltext embeddings saved!
# Processing batch 344
# batch 344 has been shortened
# Batch 344 fulltext indices saved!
# Batch 344 fulltext embeddings saved!
# Processing batch 345
# batch 345 has been shortened
# Batch 345 fulltext indices saved!
# Batch 345 fulltext embeddings saved!
# Processing batch 346
# batch 346 has been shortened
# Batch 346 fulltext indices saved!
# Batch 346 fulltext embeddings saved!
# Processing batch 347
# batch 347 has been shortened
# Batch 347 fulltext indices saved!
# Batch 347 fulltext embeddings saved!
# Processing batch 348
# batch 348 has been shortened
# Batch 348 fulltext indices saved!
# Batch 348 fulltext embeddings saved!
# Processing batch 349
# batch 349 has been shortened
# Batch 349 fulltext indices saved!
# Batch 349 fulltext embeddings saved!
# Processing batch 350
# batch 350 has been shortened
# Batch 350 fulltext indices saved!
# Batch 350 fulltext embeddings saved!
# Processing batch 351
# batch 351 has been shortened
# Batch 351 fulltext indices saved!
# Batch 351 fulltext embeddings saved!
# Processing batch 352
# batch 352 has been shortened
# Batch 352 fulltext indices saved!
# Batch 352 fulltext embeddings saved!
# Processing batch 353
# batch 353 has been shortened
# Batch 353 fulltext indices saved!
# Batch 353 fulltext embeddings saved!
# Processing batch 354
# batch 354 has been shortened
# Batch 354 fulltext indices saved!
# Batch 354 fulltext embeddings saved!
# Processing batch 355
# batch 355 has been shortened
# Batch 355 fulltext indices saved!
# Batch 355 fulltext embeddings saved!
# Processing batch 356
# batch 356 has been shortened
# Batch 356 fulltext indices saved!
# Batch 356 fulltext embeddings saved!
# Processing batch 357
# batch 357 has been shortened
# Batch 357 fulltext indices saved!
# Batch 357 fulltext embeddings saved!
# Processing batch 358
# batch 358 has been shortened
# Batch 358 fulltext indices saved!
# Batch 358 fulltext embeddings saved!
# Processing batch 359
# batch 359 has been shortened
# Batch 359 fulltext indices saved!
# Batch 359 fulltext embeddings saved!
# Processing batch 360
# batch 360 has been shortened
# Batch 360 fulltext indices saved!
# Batch 360 fulltext embeddings saved!
# Processing batch 361
# batch 361 has been shortened
# Batch 361 fulltext indices saved!
# Batch 361 fulltext embeddings saved!
# Processing batch 362
# batch 362 has been shortened
# Batch 362 fulltext indices saved!
# Batch 362 fulltext embeddings saved!
# Processing batch 363
# batch 363 has been shortened
# Batch 363 fulltext indices saved!
# Batch 363 fulltext embeddings saved!
# Processing batch 364
# batch 364 has been shortened
# Batch 364 fulltext indices saved!
# Batch 364 fulltext embeddings saved!
# Processing batch 365
# batch 365 has been shortened
# Batch 365 fulltext indices saved!
# Batch 365 fulltext embeddings saved!
# Processing batch 366
# batch 366 has been shortened
# Batch 366 fulltext indices saved!
# Batch 366 fulltext embeddings saved!
# Processing batch 367
# batch 367 has been shortened
# Batch 367 fulltext indices saved!
# Batch 367 fulltext embeddings saved!
# Processing batch 368
# batch 368 has been shortened
# Batch 368 fulltext indices saved!
# Batch 368 fulltext embeddings saved!
# Processing batch 369
# batch 369 has been shortened
# Batch 369 fulltext indices saved!
# Batch 369 fulltext embeddings saved!
# Processing batch 370
# batch 370 has been shortened
# Batch 370 fulltext indices saved!
# Batch 370 fulltext embeddings saved!
# Processing batch 371
# batch 371 has been shortened
# Batch 371 fulltext indices saved!
# Batch 371 fulltext embeddings saved!
# Processing batch 372
# batch 372 has been shortened
# Batch 372 fulltext indices saved!
# Batch 372 fulltext embeddings saved!
# Processing batch 373
# batch 373 has been shortened
# Batch 373 fulltext indices saved!
# Batch 373 fulltext embeddings saved!
# Processing batch 374
# batch 374 has been shortened
# Batch 374 fulltext indices saved!
# Batch 374 fulltext embeddings saved!
# Processing batch 375
# batch 375 has been shortened
# Batch 375 fulltext indices saved!
# Batch 375 fulltext embeddings saved!
# Processing batch 376
# batch 376 has been shortened
# Batch 376 fulltext indices saved!
# Batch 376 fulltext embeddings saved!
# Processing batch 377
# batch 377 has been shortened
# Batch 377 fulltext indices saved!
# Batch 377 fulltext embeddings saved!
# Processing batch 378
# batch 378 has been shortened
# Batch 378 fulltext indices saved!
# Batch 378 fulltext embeddings saved!
# Processing batch 379
# batch 379 has been shortened
# Batch 379 fulltext indices saved!
# Batch 379 fulltext embeddings saved!
# Processing batch 380
# batch 380 has been shortened
# Batch 380 fulltext indices saved!
# Batch 380 fulltext embeddings saved!
# Processing batch 381
# batch 381 has been shortened
# Batch 381 fulltext indices saved!
# Batch 381 fulltext embeddings saved!
# Processing batch 382
# batch 382 has been shortened
# Batch 382 fulltext indices saved!
# Batch 382 fulltext embeddings saved!
# Processing batch 383
# batch 383 has been shortened
# Batch 383 fulltext indices saved!
# Batch 383 fulltext embeddings saved!
# Processing batch 384
# batch 384 has been shortened
# Batch 384 fulltext indices saved!
# Batch 384 fulltext embeddings saved!
# Processing batch 385
# batch 385 has been shortened
# Batch 385 fulltext indices saved!
# Batch 385 fulltext embeddings saved!
# Processing batch 386
# batch 386 has been shortened
# Batch 386 fulltext indices saved!
# Batch 386 fulltext embeddings saved!
# Processing batch 387
# batch 387 has been shortened
# Batch 387 fulltext indices saved!
# Batch 387 fulltext embeddings saved!
# Processing batch 388
# batch 388 has been shortened
# Batch 388 fulltext indices saved!
# Batch 388 fulltext embeddings saved!
# Processing batch 389
# batch 389 has been shortened
# Batch 389 fulltext indices saved!
# Batch 389 fulltext embeddings saved!
# Processing batch 390
# batch 390 has been shortened
# Batch 390 fulltext indices saved!
# Batch 390 fulltext embeddings saved!
# Processing batch 391
# batch 391 has been shortened
# Batch 391 fulltext indices saved!
# Batch 391 fulltext embeddings saved!
# Processing batch 392
# batch 392 has been shortened
# Batch 392 fulltext indices saved!
# Batch 392 fulltext embeddings saved!
# Processing batch 393
# batch 393 has been shortened
# Batch 393 fulltext indices saved!
# Batch 393 fulltext embeddings saved!
# Processing batch 394
# batch 394 has been shortened
# Batch 394 fulltext indices saved!
# Batch 394 fulltext embeddings saved!
# Processing batch 395
# batch 395 has been shortened
# Batch 395 fulltext indices saved!
# Batch 395 fulltext embeddings saved!
# Processing batch 396
# batch 396 has been shortened
# Batch 396 fulltext indices saved!
# Batch 396 fulltext embeddings saved!
# Processing batch 397
# batch 397 has been shortened
# Batch 397 fulltext indices saved!
# Batch 397 fulltext embeddings saved!
# Processing batch 398
# batch 398 has been shortened
# Batch 398 fulltext indices saved!
# Batch 398 fulltext embeddings saved!
# Processing batch 399
# batch 399 has been shortened
# ...
# Processing batch 618
# batch 618 has been shortened
# Batch 618 fulltext indices saved!
# Batch 618 fulltext embeddings saved!
# Processing batch 619
# batch 619 has been shortened
# Batch 619 fulltext indices saved!
# Batch 619 fulltext embeddings saved!
# Processing batch 620
# batch 620 has been shortened
# Batch 620 fulltext indices saved!
# Batch 620 fulltext embeddings saved!
# Processing batch 621
# batch 621 has been shortened
# Batch 621 fulltext indices saved!
# Batch 621 fulltext embeddings saved!
# Processing batch 622
# batch 622 has been shortened
# Batch 622 fulltext indices saved!
# Batch 622 fulltext embeddings saved!
# Processing batch 623
# batch 623 has been shortened
# Batch 623 fulltext indices saved!
# Batch 623 fulltext embeddings saved!
# Processing batch 624
# batch 624 has been shortened
# Batch 624 fulltext indices saved!
# Batch 624 fulltext embeddings saved!
# Processing batch 625
# batch 625 has been shortened
# Batch 625 fulltext indices saved!
# Batch 625 fulltext embeddings saved!
# Processing batch 626
# batch 626 has been shortened
# Batch 626 fulltext indices saved!
# Batch 626 fulltext embeddings saved!
# Processing batch 627
# batch 627 has been shortened
# Batch 627 fulltext indices saved!
# Batch 627 fulltext embeddings saved!
# Processing batch 628
# batch 628 has been shortened
# Batch 628 fulltext indices saved!
# Batch 628 fulltext embeddings saved!
# Processing batch 629
# batch 629 has been shortened
# Batch 629 fulltext indices saved!
# Batch 629 fulltext embeddings saved!
# Processing batch 630
# batch 630 has been shortened
# Batch 630 fulltext indices saved!
# Batch 630 fulltext embeddings saved!
# Processing batch 631
# batch 631 has been shortened
# Batch 631 fulltext indices saved!
# Batch 631 fulltext embeddings saved!
# Processing batch 632
# batch 632 has been shortened
# Batch 632 fulltext indices saved!
# Batch 632 fulltext embeddings saved!
# Processing batch 633
# batch 633 has been shortened
# Batch 633 fulltext indices saved!
# Batch 633 fulltext embeddings saved!
# Processing batch 634
# batch 634 has been shortened
# Batch 634 fulltext indices saved!
# Batch 634 fulltext embeddings saved!
# Processing batch 635
# batch 635 has been shortened
# Batch 635 fulltext indices saved!
# Batch 635 fulltext embeddings saved!
# Processing batch 636
# batch 636 has been shortened
# Batch 636 fulltext indices saved!
# Batch 636 fulltext embeddings saved!
# Processing batch 637
# batch 637 has been shortened
# Batch 637 fulltext indices saved!
# Batch 637 fulltext embeddings saved!
# Processing batch 638
# batch 638 has been shortened
# Batch 638 fulltext indices saved!
# Batch 638 fulltext embeddings saved!
# Processing batch 639
# batch 639 has been shortened
# Batch 639 fulltext indices saved!
# Batch 639 fulltext embeddings saved!
# Processing batch 640
# batch 640 has been shortened
# Batch 640 fulltext indices saved!
# Batch 640 fulltext embeddings saved!
# Processing batch 641
# batch 641 has been shortened
# Batch 641 fulltext indices saved!
# Batch 641 fulltext embeddings saved!
# Processing batch 642
# batch 642 has been shortened
# Batch 642 fulltext indices saved!
# Batch 642 fulltext embeddings saved!
# Processing batch 643
# batch 643 has been shortened
# Batch 643 fulltext indices saved!
# Batch 643 fulltext embeddings saved!
# Processing batch 644
# batch 644 has been shortened
# Batch 644 fulltext indices saved!
# Batch 644 fulltext embeddings saved!
# Processing batch 645
# batch 645 has been shortened
# Batch 645 fulltext indices saved!
# Batch 645 fulltext embeddings saved!
# Processing batch 646
# batch 646 has been shortened
# Batch 646 fulltext indices saved!
# Batch 646 fulltext embeddings saved!
# Processing batch 647
# batch 647 has been shortened
# Batch 647 fulltext indices saved!
# Batch 647 fulltext embeddings saved!
# Processing batch 648
# batch 648 has been shortened
# Batch 648 fulltext indices saved!
# Batch 648 fulltext embeddings saved!
# Processing batch 649
# batch 649 has been shortened
# Batch 649 fulltext indices saved!
# Batch 649 fulltext embeddings saved!
# Processing batch 650
# batch 650 has been shortened
# Batch 650 fulltext indices saved!
# Batch 650 fulltext embeddings saved!
# Processing batch 651
# batch 651 has been shortened
# Batch 651 fulltext indices saved!
# Batch 651 fulltext embeddings saved!
# Processing batch 652
# batch 652 has been shortened
# Batch 652 fulltext indices saved!
# Batch 652 fulltext embeddings saved!
# Processing batch 653
# batch 653 has been shortened
# Batch 653 fulltext indices saved!
# Batch 653 fulltext embeddings saved!
# Processing batch 654
# batch 654 has been shortened
# Batch 654 fulltext indices saved!
# Batch 654 fulltext embeddings saved!
# Processing batch 655
# batch 655 has been shortened
# Batch 655 fulltext indices saved!
# Batch 655 fulltext embeddings saved!
# Processing batch 656
# batch 656 has been shortened
# Batch 656 fulltext indices saved!
# Batch 656 fulltext embeddings saved!
# Processing batch 657
# batch 657 has been shortened
# Batch 657 fulltext indices saved!
# Batch 657 fulltext embeddings saved!
# Processing batch 658
# batch 658 has been shortened
# Batch 658 fulltext indices saved!
# Batch 658 fulltext embeddings saved!
# Processing batch 659
# batch 659 has been shortened
# Batch 659 fulltext indices saved!
# Batch 659 fulltext embeddings saved!
# Processing batch 660
# batch 660 has been shortened
# Batch 660 fulltext indices saved!
# Batch 660 fulltext embeddings saved!
# Processing batch 661
# batch 661 has been shortened
# Batch 661 fulltext indices saved!
# Batch 661 fulltext embeddings saved!
# Processing batch 662
# batch 662 has been shortened
# Batch 662 fulltext indices saved!
# Batch 662 fulltext embeddings saved!
# Processing batch 663
# batch 663 has been shortened
# Batch 663 fulltext indices saved!
# Batch 663 fulltext embeddings saved!
# Processing batch 664
# batch 664 has been shortened
# Batch 664 fulltext indices saved!
# Batch 664 fulltext embeddings saved!
# Processing batch 665
# batch 665 has been shortened
# Batch 665 fulltext indices saved!
# Batch 665 fulltext embeddings saved!
# Processing batch 666
# batch 666 has been shortened
# Batch 666 fulltext indices saved!
# Batch 666 fulltext embeddings saved!
# Processing batch 667
# batch 667 has been shortened
# Batch 667 fulltext indices saved!
# Batch 667 fulltext embeddings saved!
# Processing batch 668
# batch 668 has been shortened
# Batch 668 fulltext indices saved!
# Batch 668 fulltext embeddings saved!
# Processing batch 669
# batch 669 has been shortened
# Batch 669 fulltext indices saved!
# Batch 669 fulltext embeddings saved!
# Processing batch 670
# batch 670 has been shortened
# Batch 670 fulltext indices saved!
# Batch 670 fulltext embeddings saved!
# Processing batch 671
# batch 671 has been shortened
# Batch 671 fulltext indices saved!
# Batch 671 fulltext embeddings saved!
# Processing batch 672
# batch 672 has been shortened
# Batch 672 fulltext indices saved!
# Batch 672 fulltext embeddings saved!
# Processing batch 673
# batch 673 has been shortened
# Batch 673 fulltext indices saved!
# Batch 673 fulltext embeddings saved!
# Processing batch 674
# batch 674 has been shortened
# Batch 674 fulltext indices saved!
# Batch 674 fulltext embeddings saved!
# Processing batch 675
# batch 675 has been shortened
# Batch 675 fulltext indices saved!
# Batch 675 fulltext embeddings saved!
# Processing batch 676
# batch 676 has been shortened
# Batch 676 fulltext indices saved!
# Batch 676 fulltext embeddings saved!
# Processing batch 677
# batch 677 has been shortened
# Batch 677 fulltext indices saved!
# Batch 677 fulltext embeddings saved!
# Processing batch 678
# batch 678 has been shortened
# Batch 678 fulltext indices saved!
# Batch 678 fulltext embeddings saved!
# Processing batch 679
# batch 679 has been shortened
# Batch 679 fulltext indices saved!
# Batch 679 fulltext embeddings saved!
# Processing batch 680
# batch 680 has been shortened
# Batch 680 fulltext indices saved!
# Batch 680 fulltext embeddings saved!
# Processing batch 681
# batch 681 has been shortened
# Batch 681 fulltext indices saved!
# Batch 681 fulltext embeddings saved!
# Processing batch 682
# batch 682 has been shortened
# Batch 682 fulltext indices saved!
# Batch 682 fulltext embeddings saved!
# Processing batch 683
# batch 683 has been shortened
# Batch 683 fulltext indices saved!
# Batch 683 fulltext embeddings saved!
# Processing batch 684
# batch 684 has been shortened
# Batch 684 fulltext indices saved!
# Batch 684 fulltext embeddings saved!
# Processing batch 685
# batch 685 has been shortened
# Batch 685 fulltext indices saved!
# Batch 685 fulltext embeddings saved!
# Processing batch 686
# batch 686 has been shortened
# Batch 686 fulltext indices saved!
# Batch 686 fulltext embeddings saved!
# Processing batch 687
# batch 687 has been shortened
# Batch 687 fulltext indices saved!
# Batch 687 fulltext embeddings saved!
# Processing batch 688
# batch 688 has been shortened
# Batch 688 fulltext indices saved!
# Batch 688 fulltext embeddings saved!
# Processing batch 689
# batch 689 has been shortened
# Batch 689 fulltext indices saved!
# Batch 689 fulltext embeddings saved!
# Processing batch 690
# batch 690 has been shortened
# Batch 690 fulltext indices saved!
# Batch 690 fulltext embeddings saved!
# Processing batch 691
# batch 691 has been shortened
# Batch 691 fulltext indices saved!
# Batch 691 fulltext embeddings saved!
# Processing batch 692
# batch 692 has been shortened
# Batch 692 fulltext indices saved!
# Batch 692 fulltext embeddings saved!
# Processing batch 693
# batch 693 has been shortened
# Batch 693 fulltext indices saved!
# Batch 693 fulltext embeddings saved!
# Processing batch 694
# batch 694 has been shortened
# Batch 694 fulltext indices saved!
# Batch 694 fulltext embeddings saved!
# Processing batch 695
# batch 695 has been shortened
# Batch 695 fulltext indices saved!
# Batch 695 fulltext embeddings saved!
# Processing batch 696
# batch 696 has been shortened
# Batch 696 fulltext indices saved!
# Batch 696 fulltext embeddings saved!
# Processing batch 697
# batch 697 has been shortened
# Batch 697 fulltext indices saved!
# Batch 697 fulltext embeddings saved!
# Processing batch 698
# batch 698 has been shortened
# Batch 698 fulltext indices saved!
# Batch 698 fulltext embeddings saved!
# Processing batch 699
# batch 699 has been shortened
# Batch 699 fulltext indices saved!
# Batch 699 fulltext embeddings saved!
# Processing batch 700
# batch 700 has been shortened
# Batch 700 fulltext indices saved!
# Batch 700 fulltext embeddings saved!
# Processing batch 701
# batch 701 has been shortened
# Batch 701 fulltext indices saved!
# Batch 701 fulltext embeddings saved!
# Processing batch 702
# batch 702 has been shortened
# Batch 702 fulltext indices saved!
# Batch 702 fulltext embeddings saved!
# Processing batch 703
# batch 703 has been shortened
# Batch 703 fulltext indices saved!
# Batch 703 fulltext embeddings saved!
# Processing batch 704
# batch 704 has been shortened
# Batch 704 fulltext indices saved!
# Batch 704 fulltext embeddings saved!
# Processing batch 705
# batch 705 has been shortened
# Batch 705 fulltext indices saved!
# Batch 705 fulltext embeddings saved!
# Processing batch 706
# batch 706 has been shortened
# Batch 706 fulltext indices saved!
# Batch 706 fulltext embeddings saved!
# Processing batch 707
# batch 707 has been shortened
# Batch 707 fulltext indices saved!
# Batch 707 fulltext embeddings saved!
# Processing batch 708
# batch 708 has been shortened
# Batch 708 fulltext indices saved!
# Batch 708 fulltext embeddings saved!
# Processing batch 709
# batch 709 has been shortened
# Batch 709 fulltext indices saved!
# Batch 709 fulltext embeddings saved!
# Processing batch 710
# batch 710 has been shortened
# Batch 710 fulltext indices saved!
# Batch 710 fulltext embeddings saved!
# Processing batch 711
# batch 711 has been shortened
# Batch 711 fulltext indices saved!
# Batch 711 fulltext embeddings saved!
# Processing batch 712
# batch 712 has been shortened
# Batch 712 fulltext indices saved!
# Batch 712 fulltext embeddings saved!
# Processing batch 713
# batch 713 has been shortened
# Batch 713 fulltext indices saved!
# Batch 713 fulltext embeddings saved!
# Processing batch 714
# batch 714 has been shortened
# Batch 714 fulltext indices saved!
# Batch 714 fulltext embeddings saved!
# Processing batch 715
# batch 715 has been shortened
# Batch 715 fulltext indices saved!
# Batch 715 fulltext embeddings saved!
# Processing batch 716
# batch 716 has been shortened
# Batch 716 fulltext indices saved!
# Batch 716 fulltext embeddings saved!
# Processing batch 717
# batch 717 has been shortened
# Batch 717 fulltext indices saved!
# Batch 717 fulltext embeddings saved!
# Processing batch 718
# batch 718 has been shortened
# Batch 718 fulltext indices saved!
# Batch 718 fulltext embeddings saved!
# Processing batch 719
# batch 719 has been shortened
# Batch 719 fulltext indices saved!
# Batch 719 fulltext embeddings saved!
# Processing batch 720
# batch 720 has been shortened
# Batch 720 fulltext indices saved!
# Batch 720 fulltext embeddings saved!
# Processing batch 721
# batch 721 has been shortened
# Batch 721 fulltext indices saved!
# Batch 721 fulltext embeddings saved!
# Processing batch 722
# batch 722 has been shortened
# Batch 722 fulltext indices saved!
# Batch 722 fulltext embeddings saved!
# Processing batch 723
# batch 723 has been shortened
# Batch 723 fulltext indices saved!
# Batch 723 fulltext embeddings saved!
# Processing batch 724
# batch 724 has been shortened
# Batch 724 fulltext indices saved!
# Batch 724 fulltext embeddings saved!
# Processing batch 725
# batch 725 has been shortened
# Batch 725 fulltext indices saved!
# Batch 725 fulltext embeddings saved!
# Processing batch 726
# batch 726 has been shortened
# Batch 726 fulltext indices saved!
# Batch 726 fulltext embeddings saved!
# Processing batch 727
# batch 727 has been shortened
# Batch 727 fulltext indices saved!
# Batch 727 fulltext embeddings saved!
# Processing batch 728
# batch 728 has been shortened
# Batch 728 fulltext indices saved!
# Batch 728 fulltext embeddings saved!
# Processing batch 729
# batch 729 has been shortened
# Batch 729 fulltext indices saved!
# Batch 729 fulltext embeddings saved!
# Processing batch 730
# batch 730 has been shortened
# Batch 730 fulltext indices saved!
# Batch 730 fulltext embeddings saved!
# Processing batch 731
# batch 731 has been shortened
# Batch 731 fulltext indices saved!
# Batch 731 fulltext embeddings saved!
# Processing batch 732
# batch 732 has been shortened
# Batch 732 fulltext indices saved!
# Batch 732 fulltext embeddings saved!
# Processing batch 733
# batch 733 has been shortened
# Batch 733 fulltext indices saved!
# Batch 733 fulltext embeddings saved!
# Processing batch 734
# batch 734 has been shortened
# Batch 734 fulltext indices saved!
# Batch 734 fulltext embeddings saved!
# Processing batch 735
# batch 735 has been shortened
# Batch 735 fulltext indices saved!
# Batch 735 fulltext embeddings saved!
# Processing batch 736
# batch 736 has been shortened
# Batch 736 fulltext indices saved!
# Batch 736 fulltext embeddings saved!
# Processing batch 737
# batch 737 has been shortened
# Batch 737 fulltext indices saved!
# Batch 737 fulltext embeddings saved!
# Processing batch 738
# batch 738 has been shortened
# Batch 738 fulltext indices saved!
# Batch 738 fulltext embeddings saved!
# Processing batch 739
# batch 739 has been shortened
# Batch 739 fulltext indices saved!
# Batch 739 fulltext embeddings saved!
# Processing batch 740
# batch 740 has been shortened
# Batch 740 fulltext indices saved!
# Batch 740 fulltext embeddings saved!
# Processing batch 741
# batch 741 has been shortened
# Batch 741 fulltext indices saved!
# Batch 741 fulltext embeddings saved!
# Processing batch 742
# batch 742 has been shortened
# Batch 742 fulltext indices saved!
# Batch 742 fulltext embeddings saved!
# Processing batch 743
# batch 743 has been shortened
# Batch 743 fulltext indices saved!
# Batch 743 fulltext embeddings saved!
# Processing batch 744
# batch 744 has been shortened
# Batch 744 fulltext indices saved!
# Batch 744 fulltext embeddings saved!
# Processing batch 745
# batch 745 has been shortened
# Batch 745 fulltext indices saved!
# Batch 745 fulltext embeddings saved!
# Processing batch 746
# batch 746 has been shortened
# Batch 746 fulltext indices saved!
# Batch 746 fulltext embeddings saved!
# Processing batch 747
# batch 747 has been shortened
# Batch 747 fulltext indices saved!
# Batch 747 fulltext embeddings saved!
# Processing batch 748
# batch 748 has been shortened
# Batch 748 fulltext indices saved!
# Batch 748 fulltext embeddings saved!
# Processing batch 749
# batch 749 has been shortened
# Batch 749 fulltext indices saved!
# Batch 749 fulltext embeddings saved!
